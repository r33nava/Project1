# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats

# %%
# Read in data
file = pd.read_csv("winedata_coord_type.csv")


grade = file["Grade"]
year = file["Year"]
price = file["Price"]

# %%
# Run the t-test
(t_stat, p) = stats.ttest_ind(year, price, equal_var=False)

# %%
# Report the data
#print("The mean height of WBA players is {}.".format(wba_heights.mean()))
#print("The mean height of women sampled is {}.".format(
#    general_heights.values.mean()))

#print("p is {}.".format(p[0]))

if p < 0.05:
    print("The difference in sample means is significant.")
else:
    print("The difference in sample means is not significant.")
# Out:
# The difference in sample means is significant.

# %%
# Plot sample means with error bars

yearsrange=list(range(2004,2017))


pricesrange=list(range(43, 65))


tick_labels = [yearsrange, pricesrange]

# %%
#mean_list = []
#sem_list =[]

#for foo in yearsrange:
 #   yeardf= file.loc[file["Year"] == foo]
  #  mean_list.append(yeardf["Grade"].mean())  

#for foo in yearsrange:
 #   yeardf= file.loc[file["Year"] == foo]
  #  sem_list.append(yeardf["Grade"].sem())
#sem_list

# %%
new_df = pd.DataFrame({"Year":file["Year"],
               "Price":file["Price"]}) 
new_df.head(5)
# Out:
#    Year  Price
# 0  2011   15.0
# 1  2012   15.0
# 2  2013   80.0
# 3  2008   32.0
# 4  2012   12.0

# %%
#x_axis = np.arange(0, len(yearsrange))

# %%
#new_df = new_df.loc[new_df["Year"]==2009]
#new_df.head()

# %%
fig, ax = plt.subplots()
plt.boxplot(new_df["Price"], showmeans=True)
plt.grid()
fig.suptitle("Price Distribution of All Wines",
             fontsize=12, fontweight="bold")
ax.set_ylabel("Price")
ax.set_xlabel("Wines")
plt.show()
plt.savefig("allwine_boxplot_price_25to75Q.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Plot mean height of players
#fig, ax = plt.subplots()

#fig.suptitle("Grade Distribution of All Wines",
#             fontsize=12, fontweight="bold")

#ax.errorbar(x_axis, mean_list, yerr=sem_list, fmt="o")

#ax.set_xlim(-0.5, 1.5)
#ax.set_ylim(64, 73)

#ax.set_xticklabels(yearsrange, gradesrange)
#ax.set_xticks([0, 1])

#ax.set_ylabel("Grade")

#plt.show()# Read in data
#file = pd.read_csv("winedata_coord_type.csv")

#grade = file["Grade"]
#year = file["Year"]
