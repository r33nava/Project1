# %%
# Dependencies
import requests
import json
import pandas as pd

from pprint import pprint

# Google developer API key
import sys
sys.path.append('../..')
from config import gkey


file = pd.read_csv("winedata_edited.csv")

file.head(30)
# Out:
#     Unnamed: 0                                              Title  \
# 0            1      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1            2      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2            3  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3            4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4            5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 5            6   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 6            7              Trimbach 2012 Gewurztraminer (Alsace)
# 7            8  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...
# 8            9  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
# 9           10  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 10          11            Leon Beyer 2012 Gewurztraminer (Alsace)
# 11          12  Louis M. Martini 2012 Cabernet Sauvignon (Alex...
# 12          14           Mirassou 2012 Chardonnay (Central Coast)
# 13          15        Richard Böcking 2013 Devon Riesling (Mosel)
# 14          16         Felix Lavaque 2010 Felix Malbec (Cafayate)
# 15          17  Gaucho Andino 2011 Winemaker Selection Malbec ...
# 16          18  Pradorey 2010 Vendimia Seleccionada Finca Vald...
# 17          19               Quiévremont 2012 Meritage (Virginia)
# 18          20      Quiévremont 2012 Vin de Maison Red (Virginia)
# 19          21                   Acrobat 2013 Pinot Noir (Oregon)
# 20          22  Baglio di Pianetto 2007 Ficiligno White (Sicilia)
# 21          23  Bianchi 2011 Signature Selection Merlot (Paso ...
# 22          24        Canicattì 2009 Aynat Nero d'Avola (Sicilia)
# 23          25  Castello di Amorosa 2011 King Ridge Vineyard P...
# 24          26       Stemmari 2013 Dalila White (Terre Siciliane)
# 25          27       Stemmari 2013 Nero d'Avola (Terre Siciliane)
# 26          28  Terre di Giurfo 2011 Mascaria Barricato  (Cera...
# 27          29  Clarksburg Wine Company 2010 Chenin Blanc (Cla...
# 28          33  Envolve 2010 Puma Springs Vineyard Red (Dry Cr...
# 29          34       Envolve 2011 Sauvignon Blanc (Sonoma Valley)
#
#                Variety  Year  Price  Grade                   Winery  \
# 0       Portuguese Red  2011   15.0     87      Quinta dos Avidagos
# 1           Pinot Gris  2013   14.0     87                Rainstorm
# 2             Riesling  2013   13.0     87               St. Julian
# 3           Pinot Noir  2012   65.0     87             Sweet Cheeks
# 4   Tempranillo-Merlot  2011   15.0     87                   Tandem
# 5             Frappato  2013   16.0     87          Terre di Giurfo
# 6       Gewürztraminer  2012   24.0     87                 Trimbach
# 7       Gewürztraminer  2013   12.0     87              Heinz Eifel
# 8           Pinot Gris  2012   27.0     87       Jean-Baptiste Adam
# 9   Cabernet Sauvignon  2011   19.0     87       Kirkland Signature
# 10      Gewürztraminer  2012   30.0     87               Leon Beyer
# 11  Cabernet Sauvignon  2012   34.0     87         Louis M. Martini
# 12          Chardonnay  2012   12.0     87                 Mirassou
# 13            Riesling  2013   24.0     87          Richard Böcking
# 14              Malbec  2010   30.0     87            Felix Lavaque
# 15              Malbec  2011   13.0     87            Gaucho Andino
# 16   Tempranillo Blend  2010   28.0     87                 Pradorey
# 17            Meritage  2012   32.0     87              Quiévremont
# 18           Red Blend  2012   23.0     87              Quiévremont
# 19          Pinot Noir  2013   20.0     87                  Acrobat
# 20         White Blend  2007   19.0     87       Baglio di Pianetto
# 21              Merlot  2011   22.0     87                  Bianchi
# 22        Nero d'Avola  2009   35.0     87                Canicattì
# 23          Pinot Noir  2011   69.0     87      Castello di Amorosa
# 24         White Blend  2013   13.0     87                 Stemmari
# 25        Nero d'Avola  2013   10.0     87                 Stemmari
# 26           Red Blend  2011   17.0     87          Terre di Giurfo
# 27        Chenin Blanc  2010   16.0     86  Clarksburg Wine Company
# 28           Red Blend  2010   50.0     86                  Envolve
# 29     Sauvignon Blanc  2011   20.0     86                  Envolve
#
#              Province                 Region    Country              Taster  \
# 0               Douro                    NaN   Portugal          Roger Voss
# 1              Oregon      Willamette Valley         US        Paul Gregutt
# 2            Michigan    Lake Michigan Shore         US  Alexander Peartree
# 3              Oregon      Willamette Valley         US        Paul Gregutt
# 4      Northern Spain                Navarra      Spain   Michael Schachner
# 27        @vboone  Clarksburg is becoming a haven for Chenin Blan...
# 28            NaN  Rustic and dry, this has flavors of berries, c...
# 29            NaN  This shows a tart, green gooseberry flavor tha...

# %%
#drop lines with too vague location
file = file.loc[file["Province"] != "America"]

# %%
province = []

for p in file["Province"]:
    if p not in province:
        province.append(p)

# %%
# Target location

province_response =[]

# Run API calls for each winery in list
for prov in province:

    target_location = prov
    
    # Build the endpoint URL
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_location, gkey)
    
    # Run a request to endpoint and convert result to json
    geo_data = requests.get(target_url).json()
   
    # Add response to our list
    province_response.append(geo_data)

# %%
pprint(province_response)
# Out:
# [{'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'results': [{'address_components': [{'long_name': 'Mosel',
#                                        'short_name': 'Mosel',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Mosel',
#                                        'short_name': 'Mosel',
#                                        'types': ['administrative_area_level_3',
#                                                  'political']},
#                                       {'long_name': 'Sheboygan County',
#                                        'short_name': 'Sheboygan County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Wisconsin',
#                                        'short_name': 'WI',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '53083',
#                                        'short_name': '53083',
#                                        'types': ['postal_code']}],
#                'formatted_address': 'Mosel, WI 53083, USA',
#                'geometry': {'location': {'lat': 43.8055502, 'lng': -87.740364},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': 43.8136023,
#                                                        'lng': -87.7243566},
#                                          'southwest': {'lat': 43.797497,
#                                                        'lng': -87.75637139999999}}},
#                'place_id': 'ChIJ7d7LQP5YA4gRmZc4f0sbVZQ',
#                'types': ['locality', 'political']},
#               {'address_components': [{'long_name': 'Mosel & Laredo',
#                                        'short_name': 'Mosel & Laredo',
#                                        'types': ['bus_station',
#                                                  'establishment',
#                                                  'point_of_interest',
#                                                  'transit_station']},
#                                       {'long_name': 'Burke Acres',
#                                        'short_name': 'Burke Acres',
#                                        'types': ['neighborhood', 'political']},
#                                       {'long_name': 'Kalamazoo Township',
#                                        'short_name': 'Kalamazoo Twp',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Kalamazoo County',
#                                        'short_name': 'Kalamazoo County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Michigan',
#                                        'short_name': 'MI',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '49004',
#                                        'short_name': '49004',
#                                        'types': ['postal_code']}],
#                'formatted_address': 'Mosel & Laredo, Kalamazoo Twp, MI 49004, '
#                                     'USA',
#                'geometry': {'location': {'lat': 42.317795, 'lng': -85.566261},
#                             'location_type': 'GEOMETRIC_CENTER',
#                             'viewport': {'northeast': {'lat': 42.31914398029149,
#                                                        'lng': -85.56491201970849},
#                                          'southwest': {'lat': 42.3164460197085,
#                                                        'lng': -85.5676099802915}}},
#                'place_id': 'ChIJ0zhrU9eCF4gRhJIdrrqfmKY',
#                'plus_code': {'compound_code': '8C9M+4F Kalamazoo Township, '
#                                               'Michigan, United States',
#                              'global_code': '86JP8C9M+4F'},
#                'types': ['bus_station',
#                          'establishment',
#                          'point_of_interest',
#                          'transit_station']},
#               {'address_components': [{'long_name': '3910',
#                                        'short_name': '3910',
#                                        'types': ['street_number']},
#                                       {'long_name': 'North 1st Street',
#                                        'short_name': 'N 1st St',
#                                        'types': ['route']},
#                                       {'long_name': 'North San Jose',
#                                        'short_name': 'North San Jose',
#                                        'types': ['neighborhood', 'political']},
#                                       {'long_name': 'San Jose',
#                                        'short_name': 'San Jose',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Santa Clara County',
#                                        'short_name': 'Santa Clara County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'California',
#                                        'short_name': 'CA',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '95134',
#                                        'short_name': '95134',
#                                        'types': ['postal_code']},
#                                       {'long_name': '1501',
#                                        'short_name': '1501',
#                                        'types': ['postal_code_suffix']}],
#                'formatted_address': '3910 N 1st St, San Jose, CA 95134, USA',
#                'geometry': {'location': {'lat': 37.4131088,
#                                          'lng': -121.9493552},
#                             'location_type': 'ROOFTOP',
#                             'viewport': {'northeast': {'lat': 37.41445778029149,
#                                                        'lng': -121.9480062197085},
#                                          'southwest': {'lat': 37.4117598197085,
#                                                        'lng': -121.9507041802915}}},
#                'place_id': 'ChIJoaIBJarJj4ARtumq9cXDywg',
#                'plus_code': {'compound_code': 'C372+67 San Jose, California, '
#                                               'United States',
#                              'global_code': '849WC372+67'},
#                'types': ['electronics_store',
#                          'establishment',
#                          'point_of_interest',
#                          'store']},
#               {'address_components': [{'long_name': 'Mosel',
#                                        'short_name': 'Mosel',
#                                        'types': ['administrative_area_level_3',
#                                                  'political']},
#                                       {'long_name': 'Sheboygan County',
#                                        'short_name': 'Sheboygan County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Wisconsin',
#                                        'short_name': 'WI',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Mosel, WI, USA',
#                'geometry': {'bounds': {'northeast': {'lat': 43.89237,
#                                                      'lng': -87.724226},
#                                        'southwest': {'lat': 43.804769,
#                                                      'lng': -87.801492}},
#                             'location': {'lat': 43.864475, 'lng': -87.7566513},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': 43.89237,
#                                                        'lng': -87.724226},
#                                          'southwest': {'lat': 43.804769,
#                                                        'lng': -87.801492}}},
#                'place_id': 'ChIJlQRkuONbA4gRzAn4lh9Y2kg',
#                'types': ['administrative_area_level_3', 'political']},
#               {'address_components': [{'long_name': 'W982 County Road Ff',
#                                        'short_name': 'W982 County Road Ff',
#                                        'types': ['route']},
#                                       {'long_name': 'Sheboygan',
#                                        'short_name': 'Sheboygan',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Mosel',
#                                        'short_name': 'Mosel',
#                                        'types': ['administrative_area_level_3',
#                                                  'political']},
#                                       {'long_name': 'Sheboygan County',
#                                        'short_name': 'Sheboygan County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Wisconsin',
#                                        'short_name': 'WI',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '53083',
#                                        'short_name': '53083',
#                                        'types': ['postal_code']},
#                                       {'long_name': '5136',
#                                        'short_name': '5136',
#                                        'types': ['postal_code_suffix']}],
#                'formatted_address': 'W982 County Road Ff, Sheboygan, WI 53083, '
#                                     'USA',
#                'geometry': {'location': {'lat': 43.8492891,
#                                          'lng': -87.74485570000002},
#                             'location_type': 'GEOMETRIC_CENTER',
#                             'viewport': {'northeast': {'lat': 43.8506380802915,
#                                                        'lng': -87.74350671970852},
#                                          'southwest': {'lat': 43.8479401197085,
#                                                        'lng': -87.74620468029153}}},
#                'place_id': 'ChIJK_ZYzNBbA4gR26Lok8EzQ94',
#                'plus_code': {'compound_code': 'R7X4+P3 Haven, Mosel, WI, '
#                                               'United States',
#                              'global_code': '86MJR7X4+P3'},
#                'types': ['city_hall',
#                          'establishment',
#                          'local_government_office',
#                          'point_of_interest']},
#               {'address_components': [{'long_name': 'Mosel Avenue & Virginia '
#                                                     'Avenue',
#                                        'short_name': 'Mosel Avenue & Virginia '
#                                                      'Avenue',
#                                        'types': ['bus_station',
#                                                  'establishment',
#                                                  'point_of_interest',
#                                                  'transit_station']},
#                                       {'long_name': 'Burke Acres',
#                                        'short_name': 'Burke Acres',
#                                        'types': ['neighborhood', 'political']},
#                                       {'long_name': 'Kalamazoo',
#                                        'short_name': 'Kalamazoo',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Kalamazoo County',
#                                        'short_name': 'Kalamazoo County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Michigan',
#                                        'short_name': 'MI',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '49004',
#                                        'short_name': '49004',
#                                        'types': ['postal_code']}],
#                'formatted_address': 'Mosel Avenue & Virginia Avenue, '
#                                     'Kalamazoo, MI 49004, USA',
#                'geometry': {'location': {'lat': 42.31777200000001,
#                                          'lng': -85.559914},
#                             'location_type': 'GEOMETRIC_CENTER',
#                             'viewport': {'northeast': {'lat': 42.31912098029151,
#                                                        'lng': -85.55856501970851},
#                                          'southwest': {'lat': 42.31642301970851,
#                                                        'lng': -85.56126298029152}}},
#                'place_id': 'ChIJ13TVdCiDF4gRnxTQT0iP-00',
#                'plus_code': {'compound_code': '8C9R+42 Kalamazoo, Michigan, '
#                                               'United States',
#                              'global_code': '86JP8C9R+42'},
#                'types': ['bus_station',
#                          'establishment',
#                          'point_of_interest',
#                          'transit_station']},
#               {'address_components': [{'long_name': '125',
#                                        'short_name': '125',
#                                        'types': ['street_number']},
#                                       {'long_name': 'U.S. 46',
#                                        'short_name': 'US-46',
#                                        'types': ['route']},
#                                       {'long_name': 'Totowa',
#                                        'short_name': 'Totowa',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Passaic County',
#                                        'short_name': 'Passaic County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'New Jersey',
#                                        'short_name': 'NJ',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '07512',
#                                        'short_name': '07512',
#                                        'types': ['postal_code']}],
#                'formatted_address': '125 US-46, Totowa, NJ 07512, USA',
#                'geometry': {'location': {'lat': 40.8927426, 'lng': -74.2239548},
#                             'location_type': 'ROOFTOP',
#                             'viewport': {'northeast': {'lat': 40.89409158029149,
#                                                        'lng': -74.2226058197085},
#                                          'southwest': {'lat': 40.8913936197085,
#                                                        'lng': -74.22530378029151}}},
#                'place_id': 'ChIJ5Y4R-OUBw4kR9nYo4ItsMhU',
#                'plus_code': {'compound_code': 'VQVG+3C Totowa, New Jersey, '
#                                               'United States',
#                              'global_code': '87G7VQVG+3C'},
#                'types': ['establishment', 'health', 'point_of_interest']},
#               {'address_components': [{'long_name': 'Suite E',
#                                        'short_name': 'Suite E',
#                                        'types': ['subpremise']},
#                                       {'long_name': '2509',
#                                        'short_name': '2509',
#                                        'types': ['street_number']},
#                                       {'long_name': 'Halligan Drive',
#                                        'short_name': 'Halligan Dr',
#                                        'types': ['route']},
#                                       {'long_name': 'North Platte',
#                                        'short_name': 'North Platte',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'North Platte',
#                                        'short_name': 'North Platte',
#                                        'types': ['administrative_area_level_3',
#                                                  'political']},
#                                       {'long_name': 'Lincoln County',
#                                        'short_name': 'Lincoln County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Nebraska',
#                                        'short_name': 'NE',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '69101',
#                                        'short_name': '69101',
#                                        'types': ['postal_code']},
#                                       {'long_name': '7858',
#                                        'short_name': '7858',
#                                        'types': ['postal_code_suffix']}],
#                'formatted_address': '2509 Halligan Dr Suite E, North Platte, '
#                                     'NE 69101, USA',
#                'geometry': {'location': {'lat': 41.109821, 'lng': -100.7329442},
#                             'location_type': 'ROOFTOP',
#                             'viewport': {'northeast': {'lat': 41.1111699802915,
#                                                        'lng': -100.7315952197085},
#                                          'southwest': {'lat': 41.1084720197085,
#                                                        'lng': -100.7342931802915}}},
#                'place_id': 'ChIJx6rObWMidocRbB4ZyCu5T9A',
#                'plus_code': {'compound_code': '4758+WR North Platte, NE, '
#                                               'United States',
#                              'global_code': '85HX4758+WR'},
#                'types': ['doctor',
#                          'establishment',
#                          'health',
#                          'point_of_interest']},
#               {'address_components': [{'long_name': 'Mosel',
#                                        'short_name': 'Mosel',
#                                        'types': ['colloquial_area',
#                                                  'political']},
#                                       {'long_name': 'Lander County',
#                                        'short_name': 'Lander County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Nevada',
#                                        'short_name': 'NV',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '89820',
#                                        'short_name': '89820',
#                                        'types': ['postal_code']}],
#                'formatted_address': 'Mosel, NV 89820, USA',
#                'geometry': {'location': {'lat': 40.6738009,
#                                          'lng': -116.6492582},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': 40.6822629,
#                                                        'lng': -116.6332508},
#                                          'southwest': {'lat': 40.6653378,
#                                                        'lng': -116.6652656}}},
#                'place_id': 'ChIJr2hVKHqbpoARPy6JWBFEcrw',
#                'types': ['colloquial_area', 'political']},
#               {'address_components': [{'long_name': '18980',
#                                        'short_name': '18980',
#                                        'types': ['street_number']},
#                                       {'long_name': 'Redland Road',
#                                        'short_name': 'Redland Rd',
#                                        'types': ['route']},
#                                       {'long_name': 'Far North Central',
#                                        'short_name': 'Far North Central',
#                                        'types': ['neighborhood', 'political']},
#                                       {'long_name': 'San Antonio',
#                                        'short_name': 'San Antonio',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Bexar County',
#                                        'short_name': 'Bexar County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Texas',
#                                        'short_name': 'TX',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '78259',
#                                        'short_name': '78259',
#                                        'types': ['postal_code']},
#                                       {'long_name': '3572',
#                                        'short_name': '3572',
#                                        'types': ['postal_code_suffix']}],
#                'formatted_address': '18980 Redland Rd, San Antonio, TX 78259, '
#                                     'USA',
#                'geometry': {'location': {'lat': 29.6187911, 'lng': -98.4550723},
#                             'location_type': 'ROOFTOP',
#                             'viewport': {'northeast': {'lat': 29.6201400802915,
#                                                        'lng': -98.45372331970849},
#                                          'southwest': {'lat': 29.6174421197085,
#                                                        'lng': -98.4564212802915}}},
#                'place_id': 'ChIJZYA3wo6JXIYRaz0mZakXP08',
#                'plus_code': {'compound_code': 'JG9V+GX San Antonio, Texas, '
#                                               'United States',
#                              'global_code': '76X3JG9V+GX'},
#                'types': ['establishment',
#                          'general_contractor',
#                          'point_of_interest']}],
#   'status': 'OK'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'results': [{'address_components': [{'long_name': 'Virginia',
#                                        'short_name': 'VA',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Virginia, USA',
#                'geometry': {'bounds': {'northeast': {'lat': 39.466012,
#                                                      'lng': -75.1664349},
#                                        'southwest': {'lat': 36.5407589,
#                                                      'lng': -83.675415}},
#                             'location': {'lat': 37.4315734, 'lng': -78.6568942},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': 39.466012,
#                                                        'lng': -75.1664349},
#                                          'southwest': {'lat': 36.5407589,
#                                                        'lng': -83.675415}}},
#                'place_id': 'ChIJzbK8vXDWTIgRlaZGt0lBTsA',
#                'types': ['administrative_area_level_1', 'political']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': '298',
#                                        'short_name': '298',
#                                        'types': ['street_number']},
#                                       {'long_name': 'Plaza de Armas',
#                                        'short_name': 'Plaza de Armas',
#                                        'types': ['route']},
#                                       {'long_name': 'Santa Cruz',
#                                        'short_name': 'Santa Cruz',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Santa Cruz',
#                                        'short_name': 'Santa Cruz',
#                                        'types': ['administrative_area_level_3',
#                                                  'political']},
#                                       {'long_name': 'Colchagua',
#                                        'short_name': 'Colchagua',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Región del Libertador '
#                                                     'General Bernardo '
#                                                     'O’Higgins',
#                                        'short_name': 'Región del Libertador '
#                                                      'Gral. Bernardo O’Higgins',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'Chile',
#                                        'short_name': 'CL',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Plaza de Armas 298, Santa Cruz, Región '
#                                     'del Libertador Gral. Bernardo O’Higgins, '
#                                     'Chile',
#                'geometry': {'location': {'lat': -34.6403625,
#                                          'lng': -71.3654431},
#                             'location_type': 'ROOFTOP',
#                             'viewport': {'northeast': {'lat': -34.63901351970851,
#                                                        'lng': -71.36409411970848},
#                                          'southwest': {'lat': -34.64171148029151,
#                                                        'lng': -71.3667920802915}}},
#                'place_id': 'ChIJ_8fwxU5lZJYR4f-GagZ15CQ',
#                'plus_code': {'compound_code': '9J5M+VR Santa Cruz, Chile',
#                              'global_code': '47QC9J5M+VR'},
#                'types': ['establishment',
#                          'point_of_interest',
#                          'travel_agency']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': '# 222',
#                                        'short_name': '# 222',
#                                        'types': ['subpremise']},
#                                       {'long_name': '951',
#                                        'short_name': '951',
#                                        'types': ['street_number']},
#                                       {'long_name': 'Kimball Lane',
#                                        'short_name': 'Kimball Ln',
#                                        'types': ['route']},
#                                       {'long_name': 'Verona',
#                                        'short_name': 'Verona',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Dane County',
#                                        'short_name': 'Dane County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Wisconsin',
#                                        'short_name': 'WI',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '53593',
#                                        'short_name': '53593',
#                                        'types': ['postal_code']},
#                                       {'long_name': '1786',
#                                        'short_name': '1786',
#                                        'types': ['postal_code_suffix']}],
#                'formatted_address': '951 Kimball Ln # 222, Verona, WI 53593, '
#                                     'USA',
#                'geometry': {'location': {'lat': 42.9790964,
#                                          'lng': -89.51445369999999},
#                             'location_type': 'ROOFTOP',
#                             'viewport': {'northeast': {'lat': 42.98044538029149,
#                                                        'lng': -89.51310471970848},
#                                          'southwest': {'lat': 42.9777474197085,
#                                                        'lng': -89.5158026802915}}},
#                'place_id': 'ChIJAYWd1viwB4gR3xrtLGgl7RM',
#                'plus_code': {'compound_code': 'XFHP+J6 Verona, WI, United '
#                                               'States',
#                              'global_code': '86JGXFHP+J6'},
#                'types': ['car_dealer',
#                          'establishment',
#                          'point_of_interest',
#                          'store']}],
#   'status': 'OK'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'results': [{'address_components': [{'long_name': 'Maule Valley',
#                                        'short_name': 'Maule Valley',
#                                        'types': ['administrative_area_level_3',
#                                                  'political']},
#                                       {'long_name': 'Linares Province',
#                                        'short_name': 'Linares Province',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Maule Region',
#                                        'short_name': 'Maule Region',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'Chile',
#                                        'short_name': 'CL',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Maule Valley, Maule Region, Chile',
#                'geometry': {'location': {'lat': -36, 'lng': -72},
#                             'location_type': 'GEOMETRIC_CENTER',
#                             'viewport': {'northeast': {'lat': -35.9986510197085,
#                                                        'lng': -71.99865101970849},
#                                          'southwest': {'lat': -36.0013489802915,
#                                                        'lng': -72.00134898029151}}},
#                'place_id': 'ChIJIRCDAoKraJYRS2QFi1f-C8g',
#                'types': ['establishment',
#                          'food',
#                          'point_of_interest',
#                          'restaurant']}],
#   'status': 'OK'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'results': [{'address_components': [{'long_name': 'Maipo Valley Wine Tours',
#                                        'short_name': 'Maipo Valley Wine Tours',
#                                        'types': ['establishment',
#                                                  'food',
#                                                  'park',
#                                                  'point_of_interest',
#                                                  'travel_agency']},
#                                       {'long_name': '70',
#                                        'short_name': '70',
#                                        'types': ['street_number']},
#                                       {'long_name': 'Calle Londres',
#                                        'short_name': 'Calle Londres',
#                                        'types': ['route']},
#                                       {'long_name': 'Santiago',
#                                        'short_name': 'Santiago',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Santiago',
#                                        'short_name': 'Santiago',
#                                        'types': ['administrative_area_level_3',
#                                                  'political']},
#                                       {'long_name': 'Santiago',
#                                        'short_name': 'Santiago',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Región Metropolitana',
#                                        'short_name': 'Región Metropolitana',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'Chile',
#                                        'short_name': 'CL',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Maipo Valley Wine Tours - Calle Londres '
#                                     '70, Santiago, Región Metropolitana, Chile',
#                'geometry': {'location': {'lat': -33.444962,
#                                          'lng': -70.64828299999999},
#                             'location_type': 'ROOFTOP',
#                             'viewport': {'northeast': {'lat': -33.44361301970849,
#                                                        'lng': -70.6469340197085},
#                                          'southwest': {'lat': -33.44631098029149,
#                                                        'lng': -70.6496319802915}}},
#                'place_id': 'ChIJw_64ZyCWYpYRJ-4eZ3AJE-s',
#                'plus_code': {'compound_code': 'H942+2M Santiago, Chile',
#                              'global_code': '47RFH942+2M'},
#                'types': ['establishment',
#                          'food',
#                          'park',
#                          'point_of_interest',
#                          'travel_agency']}],
#   'status': 'OK'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'results': [{'address_components': [{'long_name': 'New York',
#                                        'short_name': 'New York',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'New York',
#                                        'short_name': 'NY',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'New York, NY, USA',
#                'geometry': {'bounds': {'northeast': {'lat': 40.9175771,
#                                                      'lng': -73.70027209999999},
#                                        'southwest': {'lat': 40.4773991,
#                                                      'lng': -74.25908989999999}},
#                             'location': {'lat': 40.7127753, 'lng': -74.0059728},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': 40.9175771,
#                                                        'lng': -73.70027209999999},
#                                          'southwest': {'lat': 40.4773991,
#                                                        'lng': -74.25908989999999}}},
#                'place_id': 'ChIJOwg_06VPwokRYv534QaPC8g',
#                'types': ['locality', 'political']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': 'Leyda',
#                                        'short_name': 'Leyda',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'San Antonio',
#                                        'short_name': 'San Antonio',
#                                        'types': ['administrative_area_level_3',
#                                                  'political']},
#                                       {'long_name': 'San Antonio',
#                                        'short_name': 'San Antonio',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Región de Valparaíso',
#                                        'short_name': 'Región de Valparaíso',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'Chile',
#                                        'short_name': 'CL',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Leyda, San Antonio, Región de Valparaíso, '
#                                     'Chile',
#                'geometry': {'location': {'lat': -33.61315740000001,
#                                          'lng': -71.4501843},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': -33.6038646,
#                                                        'lng': -71.4341769},
#                                          'southwest': {'lat': -33.6224492,
#                                                        'lng': -71.4661917}}},
#                'partial_match': True,
#                'place_id': 'ChIJqylxUYpFYpYR0NxseBj0goM',
#                'types': ['locality', 'political']}],
#   'status': 'OK'},
#  {'error_message': 'This API project is not authorized to use this API.',
#   'results': [],
#   'status': 'REQUEST_DENIED'},
#  {'results': [{'address_components': [{'long_name': 'Piedmont',
#                                        'short_name': 'Piedmont',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Alameda County',
#                                        'short_name': 'Alameda County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'California',
#                                        'short_name': 'CA',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Piedmont, CA, USA',
#                'geometry': {'bounds': {'northeast': {'lat': 37.8330259,
#                                                      'lng': -122.2101779},
#                                        'southwest': {'lat': 37.812627,
#                                                      'lng': -122.25018}},
#                             'location': {'lat': 37.8243715, 'lng': -122.231635},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': 37.8330259,
#                                                        'lng': -122.2101779},
#                                          'southwest': {'lat': 37.812627,
#                                                        'lng': -122.25018}}},
#                'place_id': 'ChIJ9cUZf399hYARP70kjNztjQs',
#                'types': ['locality', 'political']},
#               {'address_components': [{'long_name': 'Piedmont',
#                                        'short_name': 'Piedmont',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Canadian County',
#                                        'short_name': 'Canadian County',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Oklahoma',
#                                        'short_name': 'OK',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'United States',
#                                        'short_name': 'US',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '73078',
#                                        'short_name': '73078',
#                                        'types': ['postal_code']}],
#                'formatted_address': 'Piedmont, OK 73078, USA',
#                'geometry': {'bounds': {'northeast': {'lat': 35.7475669,
# ...
#                'place_id': 'ChIJKRItNmTbHg0RdvK2ql2pxhs',
#                'types': ['locality', 'political']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': 'Casablanca',
#                                        'short_name': 'Casablanca',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Casablanca-Settat',
#                                        'short_name': 'Casablanca-Settat',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'Morocco',
#                                        'short_name': 'MA',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Casablanca, Morocco',
#                'geometry': {'bounds': {'northeast': {'lat': 33.649296,
#                                                      'lng': -7.457460999999999},
#                                        'southwest': {'lat': 33.495279,
#                                                      'lng': -7.716523999999999}},
#                             'location': {'lat': 33.5731104,
#                                          'lng': -7.589843399999999},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': 33.649296,
#                                                        'lng': -7.457460999999999},
#                                          'southwest': {'lat': 33.495279,
#                                                        'lng': -7.716523999999999}}},
#                'place_id': 'ChIJOxGqeEfNpw0R0w8xT9jBBgs',
#                'types': ['locality', 'political']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': '2',
#                                        'short_name': '2',
#                                        'types': ['street_number']},
#                                       {'long_name': 'Wienerstraße',
#                                        'short_name': 'Wienerstraße',
#                                        'types': ['route']},
#                                       {'long_name': 'Oberwart',
#                                        'short_name': 'Oberwart',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Oberwart',
#                                        'short_name': 'Oberwart',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Burgenland',
#                                        'short_name': 'Burgenland',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'Austria',
#                                        'short_name': 'AT',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '7400',
#                                        'short_name': '7400',
#                                        'types': ['postal_code']}],
#                'formatted_address': 'Wienerstraße 2, 7400 Oberwart, Austria',
#                'geometry': {'location': {'lat': 47.28909400000001,
#                                          'lng': 16.2107977},
#                             'location_type': 'ROOFTOP',
#                             'viewport': {'northeast': {'lat': 47.29044298029151,
#                                                        'lng': 16.2121466802915},
#                                          'southwest': {'lat': 47.28774501970851,
#                                                        'lng': 16.2094487197085}}},
#                'place_id': 'ChIJM6TPUJ6NbkcReQZ1WnV9O34',
#                'plus_code': {'compound_code': '76Q6+J8 Oberwart, Austria',
#                              'global_code': '8FVR76Q6+J8'},
#                'types': ['establishment', 'point_of_interest']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': 'Cape Peninsula',
#                                        'short_name': 'Cape Peninsula',
#                                        'types': ['political',
#                                                  'sublocality',
#                                                  'sublocality_level_2']},
#                                       {'long_name': 'Cape Town',
#                                        'short_name': 'Cape Town',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Cape Town',
#                                        'short_name': 'Cape Town',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Western Cape',
#                                        'short_name': 'WC',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'South Africa',
#                                        'short_name': 'ZA',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Cape Peninsula, Cape Town, South Africa',
#                'geometry': {'bounds': {'northeast': {'lat': -34.129108,
#                                                      'lng': 18.4983618},
#                                        'southwest': {'lat': -34.3598059,
#                                                      'lng': 18.319103}},
#                             'location': {'lat': -34.2500139, 'lng': 18.4157357},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': -34.129108,
#                                                        'lng': 18.4983618},
#                                          'southwest': {'lat': -34.3598059,
#                                                        'lng': 18.319103}}},
#                'place_id': 'ChIJ25w6pMpqzB0RlQq1rTcH7lE',
#                'types': ['political', 'sublocality', 'sublocality_level_2']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': '5938',
#                                        'short_name': '5938',
#                                        'types': ['street_number']},
#                                       {'long_name': 'Rue Saint-Hubert',
#                                        'short_name': 'Rue St-Hubert',
#                                        'types': ['route']},
#                                       {'long_name': 'Rosemont—La Petite-Patrie',
#                                        'short_name': 'Rosemont—La '
#                                                      'Petite-Patrie',
#                                        'types': ['political',
#                                                  'sublocality',
#                                                  'sublocality_level_1']},
#                                       {'long_name': 'Montréal',
#                                        'short_name': 'Montréal',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Communauté-Urbaine-de-Montréal',
#                                        'short_name': 'Communauté-Urbaine-de-Montréal',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Québec',
#                                        'short_name': 'QC',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'Canada',
#                                        'short_name': 'CA',
#                                        'types': ['country', 'political']},
#                                       {'long_name': 'H2S 2L7',
#                                        'short_name': 'H2S 2L7',
#                                        'types': ['postal_code']}],
#                'formatted_address': '5938 Rue St-Hubert, Montréal, QC H2S 2L7, '
#                                     'Canada',
#                'geometry': {'location': {'lat': 45.5337847, 'lng': -73.5983869},
#                             'location_type': 'ROOFTOP',
#                             'viewport': {'northeast': {'lat': 45.53513368029149,
#                                                        'lng': -73.5970379197085},
#                                          'southwest': {'lat': 45.5324357197085,
#                                                        'lng': -73.5997358802915}}},
#                'partial_match': True,
#                'place_id': 'ChIJ01X2z2UZyUwR6oXqvx0XkcI',
#                'plus_code': {'compound_code': 'GCM2+GJ Montreal, Quebec, '
#                                               'Canada',
#                              'global_code': '87Q8GCM2+GJ'},
#                'types': ['establishment',
#                          'food',
#                          'point_of_interest',
#                          'restaurant']}],
#   'status': 'OK'},
#  {'results': [], 'status': 'ZERO_RESULTS'},
#  {'results': [{'address_components': [{'long_name': 'Malgas',
#                                        'short_name': 'Malgas',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Malagas',
#                                        'short_name': 'Malagas',
#                                        'types': ['political',
#                                                  'sublocality',
#                                                  'sublocality_level_1']},
#                                       {'long_name': 'Overberg District '
#                                                     'Municipality',
#                                        'short_name': 'Overberg District '
#                                                      'Municipality',
#                                        'types': ['administrative_area_level_2',
#                                                  'political']},
#                                       {'long_name': 'Western Cape',
#                                        'short_name': 'WC',
#                                        'types': ['administrative_area_level_1',
#                                                  'political']},
#                                       {'long_name': 'South Africa',
#                                        'short_name': 'ZA',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '7441',
#                                        'short_name': '7441',
#                                        'types': ['postal_code']}],
#                'formatted_address': 'Malagas, Malgas, 7441, South Africa',
#                'geometry': {'bounds': {'northeast': {'lat': -34.2704848,
#                                                      'lng': 20.6224899},
#                                        'southwest': {'lat': -34.3733499,
#                                                      'lng': 20.538719}},
#                             'location': {'lat': -34.3204182, 'lng': 20.5811363},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': -34.2704848,
#                                                        'lng': 20.6224899},
#                                          'southwest': {'lat': -34.3733499,
#                                                        'lng': 20.538719}}},
#                'place_id': 'ChIJJe7cx49l0R0R4QEJAkErVsg',
#                'types': ['locality', 'political']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': 'Cape Agulhas',
#                                        'short_name': 'Cape Agulhas',
#                                        'types': ['establishment',
#                                                  'natural_feature']},
#                                       {'long_name': 'South Africa',
#                                        'short_name': 'ZA',
#                                        'types': ['country', 'political']}],
#                'formatted_address': 'Cape Agulhas, South Africa',
#                'geometry': {'location': {'lat': -34.8311111, 'lng': 20.0130556},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': -34.8219517,
#                                                        'lng': 20.029063},
#                                          'southwest': {'lat': -34.8402695,
#                                                        'lng': 19.9970482}}},
#                'place_id': 'ChIJ6SEYvZ220R0RwalsH9Efl1A',
#                'types': ['establishment', 'natural_feature']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': 'Dálvares',
#                                        'short_name': 'Dálvares',
#                                        'types': ['locality', 'political']},
#                                       {'long_name': 'Portugal',
#                                        'short_name': 'PT',
#                                        'types': ['country', 'political']},
#                                       {'long_name': '3610-013',
#                                        'short_name': '3610-013',
#                                        'types': ['postal_code']}],
#                'formatted_address': 'Casa do Paço, 3610-013 Dálvares, Portugal',
#                'geometry': {'location': {'lat': 41.038893, 'lng': -7.758375},
#                             'location_type': 'GEOMETRIC_CENTER',
#                             'viewport': {'northeast': {'lat': 41.0402419802915,
#                                                        'lng': -7.757026019708498},
#                                          'southwest': {'lat': 41.03754401970851,
#                                                        'lng': -7.759723980291502}}},
#                'place_id': 'ChIJrz0KXGtVOw0Rcus_C7p74kE',
#                'plus_code': {'compound_code': '26QR+HJ Dálvares, Portugal',
#                              'global_code': '8CHJ26QR+HJ'},
#                'types': ['establishment', 'food', 'point_of_interest']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': 'Rhine River',
#                                        'short_name': 'Rhine River',
#                                        'types': ['establishment',
#                                                  'natural_feature']}],
#                'formatted_address': 'Rhine River',
#                'geometry': {'bounds': {'northeast': {'lat': 51.8761681,
#                                                      'lng': 9.7693388},
#                                        'southwest': {'lat': 46.81673180000001,
#                                                      'lng': 6.0380274}},
#                             'location': {'lat': 49.34645, 'lng': 7.9036831},
#                             'location_type': 'APPROXIMATE',
#                             'viewport': {'northeast': {'lat': 51.8761681,
#                                                        'lng': 9.7693388},
#                                          'southwest': {'lat': 46.81673180000001,
#                                                        'lng': 6.0380274}}},
#                'partial_match': True,
#                'place_id': 'ChIJCxXf94vrlkcRgjwcduZFybs',
#                'types': ['establishment', 'natural_feature']}],
#   'status': 'OK'}]

# %%
# Collect and store latitude and longitude for each province

lat = []
lng = []
county = []

i=0

# Loop through wineries and append coordinate lists
for response in province_response:
    try:
        latitude = province_response[i]["results"][0]["geometry"]["location"]["lat"]
        longitude = province_response[i]["results"][0]["geometry"]["location"]["lng"]
        county_name = province_response[i]["results"][0]["address_components"][1]["long_name"]

        lat.append(latitude)
        lng.append(longitude)
        county.append(county_name)
        
        i = i+1
    except:
        lat.append("lat error")
        lng.append("lng error")
        county.append("county error")
        
        i = i+1

# %%
province_df= pd.DataFrame({"Province" : province,
                          "Latitude" : lat,
                          "Longitude" : lng,
                          "County" : county})

# %%
# Drop rows without location data
province_df = province_df.loc[province_df["Latitude"] != "lat error"]

# %%
# Add coordinates to primary dataframe by merging
complete_df = pd.merge(file, province_df, on="Province")
complete_df
# Out:
#        Unnamed: 0                                              Title  \
# 0              15        Richard Böcking 2013 Devon Riesling (Mosel)
# 1             156  Carl Graff 2014 Graacher Himmelreich Spätlese ...
# 2             170  Fritz Haag 2014 Brauneberger Feinherb Riesling...
# 3             171                   Fritz Haag 2014 Riesling (Mosel)
# 4             468  Dr. Loosen 2011 Ürziger Würzgarten Alte Reben ...
# 5             469  Dr. Loosen 2011 Wehlener Sonnenuhr Kabinett Ri...
# 6             535   Maximin Grünhäuser 2015 Trocken Riesling (Mosel)
# 7             648  Reichsgraf von Kesselstatt 2014 Brauneberger J...
# 8             789    Von Schleinitz 2015 Apollo Dry Riesling (Mosel)
# 9             853  Dr. H. Thanisch (Erben Thanisch) 2014 Thanisch...
# 10           1304  Dr. Fischer 2013 Ockfener Bockstein Kabinett R...
# 11           1385            S.A. Prüm 2014 Essence Riesling (Mosel)
# 12           1398  C. von Nell-Breuning 2014 Kaseler Dominikaner ...
# 13           1410        Peter Mertes 2014 Platinum Riesling (Mosel)
# 14           1457  Fritz Haag 2015 Brauneberg Juffer Sonnenuhr Tr...
# 15           2597  Peter Nicolay 2011 Bernkasteler Badstube Spätl...
# 7            Reichsgraf von Kesselstatt                       Mosel    NaN
# 8                        Von Schleinitz                       Mosel    NaN
# 9      Dr. H. Thanisch (Erben Thanisch)                       Mosel    NaN
# 10                          Dr. Fischer                       Mosel    NaN
# 11                            S.A. Prüm                       Mosel    NaN
# 12                 C. von Nell-Breuning                       Mosel    NaN
# 13                         Peter Mertes                       Mosel    NaN
# 14                           Fritz Haag                       Mosel    NaN
# 15                        Peter Nicolay                       Mosel    NaN
# 16                          Karl Kaspar                       Mosel    NaN
# 17                   Maximin Grünhäuser                       Mosel    NaN
# 18           Reichsgraf von Kesselstatt                       Mosel    NaN
# 19            Dr. Heidemanns-Bergweiler                       Mosel    NaN
# 20            Dr. Heidemanns-Bergweiler                       Mosel    NaN
# 21                           Dr. Loosen                       Mosel    NaN
# 22                           Dr. Loosen                       Mosel    NaN
# 23            Dr. Heidemanns-Bergweiler                       Mosel    NaN
# 24                      St. Christopher                       Mosel    NaN
# 25                              Bastgen                       Mosel    NaN
# 26     Dr. H. Thanisch (Erben Thanisch)                       Mosel    NaN
# 27                           Fritz Haag                       Mosel    NaN
# 28                            S.A. Prüm                       Mosel    NaN
# 29     Dr. H. Thanisch (Erben Thanisch)                       Mosel    NaN
# ...                                 ...                         ...    ...
# 21904                  Hamilton Russell              Hemel en Aarde    NaN
# 21905                  Hamilton Russell              Hemel en Aarde    NaN
# 21906                        De Martino                     Coelemu    NaN
# 21907                Catherine Marshall            Cape South Coast    NaN
# 21908         Orange River Wine Cellars               Northern Cape    NaN
# 21909                          Trizanne                        Elim    NaN
# 21910                          Trizanne                        Elim    NaN
# 21911                Stellenbosch Hills            Polkadraai Hills    NaN
# 21912                Stellenbosch Hills            Polkadraai Hills    NaN
# 21913                Stellenbosch Hills            Polkadraai Hills    NaN
# 21914                        Wildekrans                   Bot River    NaN
# 21915                          Beaumont                   Bot River    NaN
# 21916                          Beaumont                   Bot River    NaN
# 21917                        Wildekrans                   Bot River    NaN
# 21918                    Cossart Gordon                     Madeira    NaN
# 21919                    Cossart Gordon                     Madeira    NaN
# 21920                             Urlar                   Gladstone    NaN
# 21921                 Adega Viuva Gomes                     Colares    NaN
# 21922                            Carmen  Casablanca & Leyda Valleys    NaN
# 21923                   Kingston Family  Casablanca & Leyda Valleys    NaN
# 21924                            Montes  Casablanca & Leyda Valleys    NaN
# 21925                            Jalits               Südburgenland    NaN
# 21926                          Krutzler               Südburgenland    NaN
# 21927              Cape Point Vineyards              Cape Peninsula    NaN
# 21928              Cape Point Vineyards              Cape Peninsula    NaN
# 21929              Cape Point Vineyards              Cape Peninsula    NaN
# 21930        Adega Cooperativa de Borba                     Alenteo    NaN
# 21931                             Sijnn                      Malgas    NaN
# 21932                            Lomond                Cape Agulhas    NaN
# 21933                       Casca Wines               Távora-Varosa    NaN
#
#             Country              Taster Taster_Twitter  \
# 0           Germany  Anna Lee C. Iijima            NaN
# 1           Germany  Anna Lee C. Iijima            NaN
# 2           Germany  Anna Lee C. Iijima            NaN
# 3           Germany  Anna Lee C. Iijima            NaN
# 4           Germany  Anna Lee C. Iijima            NaN
# 21920  Fig, nectarine and grapefruit notes mark this ...  39.2039  -94.5547
# 21921  While the small coastal appellation of Colares...  38.8066  -9.44269
# 21922  Early on this smells strained, like a haystack...  33.5731  -7.58984
# 21923  Plum and cherry aromas turn herbal and piney w...  33.5731  -7.58984
# 21924  Like many Chilean Pinots, this starts out funk...  33.5731  -7.58984
# 21925  Tar and smoke add a note of intrigue to dark, ...  47.2891   16.2108
# 21926  Elderberry with edges of tar and smoke, a flor...  47.2891   16.2108
# 21927  This is a stunning Bordeaux-style white wine, ...   -34.25   18.4157
# 21928  Despite the age, this is still crisp, lively a...   -34.25   18.4157
# 21929  A tropical tone of grilled pineapple adds brea...   -34.25   18.4157
# 21930  With the normally more northern Alvarinho in t...  45.5338  -73.5984
# 21931  This blend of 57% Chenin Blanc and 43% Viognie... -34.3204   20.5811
# 21932  A delicious Sauv Blanc from one of the coolest... -34.8311   20.0131
# 21933  Coming from the north-eastern Beiras region, c...  41.0389  -7.75838
#
#                   County
# 0                  Mosel
# 1                  Mosel
# 2                  Mosel
# 3                  Mosel
# 4                  Mosel
# 5                  Mosel
# 6                  Mosel
# 7                  Mosel
# 8                  Mosel
# 9                  Mosel
# 10                 Mosel
# 11                 Mosel
# 12                 Mosel
# 13                 Mosel
# 14                 Mosel
# 15                 Mosel
# 16                 Mosel
# 17                 Mosel
# 18                 Mosel
# 19                 Mosel
# 20                 Mosel
# 21                 Mosel
# 22                 Mosel
# 23                 Mosel
# 24                 Mosel
# 25                 Mosel
# 26                 Mosel
# 27                 Mosel
# 28                 Mosel
# 29                 Mosel
# ...                  ...
# 21904           Hermanus
# 21905           Hermanus
# 21906              Nuble
# 21907  South Coast Drive
# 21908       South Africa
# 21909     Central Avenue
# 21910     Central Avenue
# 21911       Stellenbosch
# 21912       Stellenbosch
# 21913       Stellenbosch
# 21914          Bot River
# 21915          Bot River
# 21916          Bot River
# 21917          Bot River
# 21918           Portugal
# 21919           Portugal
# 21920  Gallatin Township
# 21921             Lisboa
# 21922  Casablanca-Settat
# 21923  Casablanca-Settat
# 21924  Casablanca-Settat
# 21925       Wienerstraße
# 21926       Wienerstraße
# 21927          Cape Town
# 21928          Cape Town
# 21929          Cape Town
# 21930   Rue Saint-Hubert
# 21931            Malagas
# 21932       South Africa
# 21933           Portugal
#
# [21934 rows x 16 columns]

# %%
for index, row in complete_df.iterrows():
#blush wines
    if "Zinfandel" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Blush"
    elif "Rosa" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Blush"
    elif "Rosé" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Blush"
#sparkling wines
    elif "Sparkling" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Sparkling"
    elif "Champagne" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Sparkling"
    elif "Prosecco" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Sparkling"
    elif "Lambrusco" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Sparkling" 
    #red wines
    elif "Red" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Noir" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Tint" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Cabernet" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Syrah" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Sirah" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Malbec" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Gamay" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Merlot" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Barbera" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif "Shiraz" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"
    elif row["Variety"] == "Port":
        complete_df.loc[index,"Type"] = "Red"
    elif "Nero" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"        
    elif "Negro" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"   
    elif "Sangiovese" in row["Variety"]:
        complete_df.loc[index,"Type"] = "Red"        
    elif row["Variety"] == "Grenache":
        complete_df.loc[index,"Type"] = "Red"     
    elif row["Variety"] == "Tempranillo":
        complete_df.loc[index,"Type"] = "Red" 
#White wines        
    elif "White" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Chardonnay" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Riesling" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Grigio" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Gris" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Blanc" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Gewürztraminer" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Moscato" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Musca" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Semillon" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Viognier" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Cortese" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
    elif "Bianco" in row["Variety"]:
        complete_df.loc[index,"Type"] = "White"
      
    else:
        complete_df.loc[index,"Type"] = "Other"

# %%
complete_df.head(30)
# Out:
#     Unnamed: 0                                              Title   Variety  \
# 0           15        Richard Böcking 2013 Devon Riesling (Mosel)  Riesling
# 1          156  Carl Graff 2014 Graacher Himmelreich Spätlese ...  Riesling
# 2          170  Fritz Haag 2014 Brauneberger Feinherb Riesling...  Riesling
# 3          171                   Fritz Haag 2014 Riesling (Mosel)  Riesling
# 4          468  Dr. Loosen 2011 Ürziger Würzgarten Alte Reben ...  Riesling
# 5          469  Dr. Loosen 2011 Wehlener Sonnenuhr Kabinett Ri...  Riesling
# 6          535   Maximin Grünhäuser 2015 Trocken Riesling (Mosel)  Riesling
# 7          648  Reichsgraf von Kesselstatt 2014 Brauneberger J...  Riesling
# 8          789    Von Schleinitz 2015 Apollo Dry Riesling (Mosel)  Riesling
# 9          853  Dr. H. Thanisch (Erben Thanisch) 2014 Thanisch...  Riesling
# 10        1304  Dr. Fischer 2013 Ockfener Bockstein Kabinett R...  Riesling
# 11        1385            S.A. Prüm 2014 Essence Riesling (Mosel)  Riesling
# 12        1398  C. von Nell-Breuning 2014 Kaseler Dominikaner ...  Riesling
# 13        1410        Peter Mertes 2014 Platinum Riesling (Mosel)  Riesling
# 14        1457  Fritz Haag 2015 Brauneberg Juffer Sonnenuhr Tr...  Riesling
# 15        2597  Peter Nicolay 2011 Bernkasteler Badstube Spätl...  Riesling
# 16        2613         Karl Kaspar 2010 Kabinett Riesling (Mosel)  Riesling
# 17        2912  Maximin Grünhäuser 2012 Herrenberg Alte Reben ...  Riesling
# 18        2988  Reichsgraf von Kesselstatt 2015 RK Riesling (M...  Riesling
# 19        3000  Dr. Heidemanns-Bergweiler 2015 Dry Mineral Rie...  Riesling
# 20        3381  Dr. Heidemanns-Bergweiler 2015 Bernkasteler Ba...  Riesling
# 21        3382  Dr. Loosen 2012 Ürziger Würzgarten GG Réserve ...  Riesling
# 22        3495  Dr. Loosen 2009 Ürziger Würzgarten Alte Reben ...  Riesling
# 23        3552  Dr. Heidemanns-Bergweiler 2011 Graacher Himmel...  Riesling
# 24        3569  St. Christopher 2016 Piesporter Goldtröpfchen ...  Riesling
# 25        3583  Bastgen 2015 Kestener Paulinsberg Kabinett Rie...  Riesling
# 26        3702  Dr. H. Thanisch (Erben Thanisch) 2012 Berncast...  Riesling
# 27        3706  Fritz Haag 2012 Brauneberger Juffer Trocken GG...  Riesling
# 28        3850  S.A. Prüm 2009 Graacher Himmelreich Spätlese R...  Riesling
# 29        3871  Dr. H. Thanisch (Erben Thanisch) 2009 Berncast...  Riesling
#
#     Year  Price  Grade                            Winery Province Region  \
# 0   2013   24.0     87                   Richard Böcking    Mosel    NaN
# 1   2014   14.0     91                        Carl Graff    Mosel    NaN
# 2   2014   30.0     91                        Fritz Haag    Mosel    NaN
# 3   2014   22.0     91                        Fritz Haag    Mosel    NaN
# 4   2011   42.0     92                        Dr. Loosen    Mosel    NaN
# 5   2011   27.0     92                        Dr. Loosen    Mosel    NaN
# 6   2015   22.0     91                Maximin Grünhäuser    Mosel    NaN
# 7   2014   34.0     92        Reichsgraf von Kesselstatt    Mosel    NaN
# 8   2015   29.0     90                    Von Schleinitz    Mosel    NaN
# 9   2014   30.0     90  Dr. H. Thanisch (Erben Thanisch)    Mosel    NaN
# 10  2013   20.0     89                       Dr. Fischer    Mosel    NaN
# 11  2014   14.0     88                         S.A. Prüm    Mosel    NaN
# 12  2014   16.0     88              C. von Nell-Breuning    Mosel    NaN
# 13  2014    9.0     88                      Peter Mertes    Mosel    NaN
# 14  2015   56.0     94                        Fritz Haag    Mosel    NaN
# 15  2011   29.0     90                     Peter Nicolay    Mosel    NaN
# 16  2010   13.0     90                       Karl Kaspar    Mosel    NaN
# 17  2012   42.0     86                Maximin Grünhäuser    Mosel    NaN
# 18  2015   16.0     91        Reichsgraf von Kesselstatt    Mosel    NaN
# 19  2015   20.0     91         Dr. Heidemanns-Bergweiler    Mosel    NaN
# 20  2015   33.0     92         Dr. Heidemanns-Bergweiler    Mosel    NaN
# 21  2012   92.0     92                        Dr. Loosen    Mosel    NaN
# 22  2009   42.0     87                        Dr. Loosen    Mosel    NaN
# 23  2011   30.0     92         Dr. Heidemanns-Bergweiler    Mosel    NaN
# 24  2016   12.0     89                   St. Christopher    Mosel    NaN
# 25  2015   19.0     89                           Bastgen    Mosel    NaN
# 26  2012   95.0     91  Dr. H. Thanisch (Erben Thanisch)    Mosel    NaN
# 27  2012   42.0     91                        Fritz Haag    Mosel    NaN
# 28  2009   31.0     92                         S.A. Prüm    Mosel    NaN
# 29  2009   84.0     91  Dr. H. Thanisch (Erben Thanisch)    Mosel    NaN
#
#     Country              Taster Taster_Twitter  \
# 0   Germany  Anna Lee C. Iijima            NaN
# 1   Germany  Anna Lee C. Iijima            NaN
# 2   Germany  Anna Lee C. Iijima            NaN
# 3   Germany  Anna Lee C. Iijima            NaN
# 4   Germany  Anna Lee C. Iijima            NaN
# 5   Germany  Anna Lee C. Iijima            NaN
# 6   Germany  Anna Lee C. Iijima            NaN
# 7   Germany  Anna Lee C. Iijima            NaN
# 8   Germany  Anna Lee C. Iijima            NaN
# 9   Germany  Anna Lee C. Iijima            NaN
# 10  Germany  Anna Lee C. Iijima            NaN
# 11  Germany  Anna Lee C. Iijima            NaN
# 12  Germany  Anna Lee C. Iijima            NaN
# 13  Germany  Anna Lee C. Iijima            NaN
# 14  Germany  Anna Lee C. Iijima            NaN
# 15  Germany  Anna Lee C. Iijima            NaN
# 16  Germany  Anna Lee C. Iijima            NaN
# 17  Germany  Anna Lee C. Iijima            NaN
# 18  Germany  Anna Lee C. Iijima            NaN
# 19  Germany  Anna Lee C. Iijima            NaN
# 20  Germany  Anna Lee C. Iijima            NaN
# 21  Germany  Anna Lee C. Iijima            NaN
# 22  Germany      Joe Czerwinski         @JoeCz
# 23  Germany  Anna Lee C. Iijima            NaN
# 24  Germany  Anna Lee C. Iijima            NaN
# 25  Germany  Anna Lee C. Iijima            NaN
# 26  Germany  Anna Lee C. Iijima            NaN
# 27  Germany  Anna Lee C. Iijima            NaN
# 28  Germany      Joe Czerwinski         @JoeCz
# 29  Germany      Joe Czerwinski         @JoeCz
#
#                                           Description Latitude Longitude  \
# 0   Zesty orange peels and apple notes abound in t...  43.8056  -87.7404
# 1   Approachably fruity yet nuanced and electrifyi...  43.8056  -87.7404
# 2   Fresh and fragrant of blossoms, tart yellow pe...  43.8056  -87.7404
# 3   Just a touch of honey-lemon sweetness is enoug...  43.8056  -87.7404
# 4   The nose of this powerfully fruity yet dry Rie...  43.8056  -87.7404
# 5   Lanolin and honeycomb notes lend a minerally f...  43.8056  -87.7404
# 6   Fresh green apple and grapefruit aromas are bo...  43.8056  -87.7404
# 7   A spray of rose petals perfumes this aromatic ...  43.8056  -87.7404
# 8   Fragrant notes of tangerine and yuzu peel abou...  43.8056  -87.7404
# 9   A dusting of crushed slate and saffron accents...  43.8056  -87.7404
# 10  Spine-tingling acidity runs throughout this of...  43.8056  -87.7404
# 11  Crisp, cutting lime and lemon lend verve to cr...  43.8056  -87.7404
# 12  Flavors of pressed apple and pears are uncompl...  43.8056  -87.7404
# 13  Aromas of pressed apples and pears turn fleshi...  43.8056  -87.7404
# 14  Initial whiffs of smoke and struck flint fade ...  43.8056  -87.7404
# 15  Wet stone and earth notes add a distinct miner...  43.8056  -87.7404
# 16  Tantalizing spice notes mix with aromas of qui...  43.8056  -87.7404
# 17  Dust and pollen notes linger from nose to fini...  43.8056  -87.7404
# 18  Superbly warm weather in 2015 gave an extra bo...  43.8056  -87.7404
# 19  Whiffs of candlestick and honeycomb lend subtl...  43.8056  -87.7404
# 20  Dusty minerals, pollen and spice notes lend co...  43.8056  -87.7404
# 21  Layers of exotic spice and crushed earth perme...  43.8056  -87.7404
# 22  Loosen's Grosses Gewächs bottling from old vin...  43.8056  -87.7404
# 23  There's an intense punch of sweet yellow peach...  43.8056  -87.7404
# 24  Pristine peach, tangerine and blossom notes fo...  43.8056  -87.7404
# 25  Earthy notes of pollen accent robust yellow pe...  43.8056  -87.7404
# 26  Scents of honey and freshly pressed apples waf...  43.8056  -87.7404
# 27  Smoke and crushed mineral notes open this dry,...  43.8056  -87.7404
# 28  A lovely effort from proprietor Raimund Prüm, ...  43.8056  -87.7404
# 29  The Thanisch wines from the Doctor vineyard ra...  43.8056  -87.7404
#
#    County   Type
# 0   Mosel  White
# 1   Mosel  White
# 2   Mosel  White
# 3   Mosel  White
# 4   Mosel  White
# 5   Mosel  White
# 6   Mosel  White
# 7   Mosel  White
# 8   Mosel  White
# 9   Mosel  White
# 10  Mosel  White
# 11  Mosel  White
# 12  Mosel  White
# 13  Mosel  White
# 14  Mosel  White
# 15  Mosel  White
# 16  Mosel  White
# 17  Mosel  White
# 18  Mosel  White
# 19  Mosel  White
# 20  Mosel  White
# 21  Mosel  White
# 22  Mosel  White
# 23  Mosel  White
# 24  Mosel  White
# 25  Mosel  White
# 26  Mosel  White
# 27  Mosel  White
# 28  Mosel  White
# 29  Mosel  White

# %%
complete_df.to_csv('winedata_coord_type.csv')
