# %%
# %matplotlib notebook

# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
#Load Data
df = pd.read_csv("winedata_coord.csv")
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             1
# 1           1           608
#
#                                                Title           Variety  Year  \
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)    Portuguese Red  2011
# 1  Quinta do Portal 2012 Verdelho and Sauvignon B...  Portuguese White  2012
#
#    Price  Grade               Winery Province Region   Country      Taster  \
# 0     15     87  Quinta dos Avidagos    Douro    NaN  Portugal  Roger Voss
# 1     15     87     Quinta do Portal    Douro    NaN  Portugal  Roger Voss
#
#   Taster_Twitter                                        Description  \
# 0     @vossroger  This is ripe and fruity, a wine that is smooth...
# 1     @vossroger  Verdelho and Sauvignon Blanc hangs together ea...
#
#     Latitude  Longitude
# 0  41.512019  -5.492255
# 1  41.512019  -5.492255

# %%
#Locate 'Year' in Data Set
year = df.iloc[:,4]

# %%
# Grab wine prices
violent_crime_rate = df.iloc[:, 5]
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(
    year, violent_crime_rate)
vc_fit = vc_slope * year + vc_int

# %%
# Grab wine grades
murder_rate = df.iloc[:, 6]
m_slope, m_int, m_r, m_p, m_std_err = stats.linregress(year, murder_rate)
m_fit = m_slope * year + m_int

# %%
# Plot
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)
fig.suptitle("Prices and Grades Over Time", fontsize=16, fontweight="bold")

ax1.set_xlim(min(year), max(year))
ax1.plot(year, violent_crime_rate, linewidth=1, marker="o")
ax1.plot(year, vc_fit, "b--", linewidth=1)
ax1.set_ylabel("Price Rate")

ax2.plot(year, murder_rate, linewidth=1, marker="o", color="r")
ax2.plot(year, m_fit, "r--", linewidth=1)
ax2.set_ylabel("Grade Rate")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Grade Rate')

# %%
# Print results and save image
year = 2013
print("The wine price in 2013 will be " +
      str(vc_slope * year + vc_int) + ".")
print("The wine grade in 2013 will be " + str(m_slope * year + m_int) + ".")

#plt.savefig("../Images/18-final-plot.png")
# Out:
# The wine price in 2013 will be 33.48358886182223.
# The wine grade in 2013 will be 88.6043818536091.
