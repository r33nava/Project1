# %%
# Dependencies
import requests
import json
import pandas as pd

from pprint import pprint

# Google developer API key
import sys
sys.path.append('../..')
from config import gkey


file = pd.read_csv("winedata_coord_type.csv")

file= file.loc[file["Country"]=="US"]

file = file.groupby("Province").first()

#file= file.loc[file["Province"]=="New Jersey"]
file.head(50)
# Out:
#                    Unnamed: 0  Unnamed: 0.1  \
# Province
# Arizona                100444          5389
# California              12503            10
# Colorado               100219          5071
# Connecticut            101036         33322
# Idaho                   94920           622
# Iowa                   100961         16542
# Kentucky               101028         28589
# Massachusetts          100540          6527
# Michigan                 5704             3
# Missouri                99451          2922
# Nevada                  99515          2936
# New Jersey              99249          1850
# New Mexico              99475          2931
# New York                74659            97
# North Carolina         100870         13402
# Ohio                   100545          6539
# Oregon                   1031             2
# Pennsylvania            98542          1371
# Texas                   96902           724
# Vermont                100986         21687
# Virginia                48629            19
# Washington              56352            59
# Washington-Oregon      100839         12542
#
#                                                                Title  \
# Province
# Arizona            Arizona Stronghold 2011 Site Archive Norte Mal...
# California         Kirkland Signature 2011 Mountain Cuvée Caberne...
# Colorado           The Infinite Monkey Theorem 2012 The Hundreth ...
# Connecticut        Hopkins Vineyard 2006 Duet White (Western Conn...
# Idaho                                     Coiled 2009 Sidewinder Red
# Iowa                                 Jasper 2007 Seyval Blanc (Iowa)
# Kentucky           Elk Creek Vineyards 2007 Estate Cabernet Franc...
# Massachusetts      Truro 2007 Estate Grown Cabernet Franc (Southe...
# Michigan           St. Julian 2013 Reserve Late Harvest Riesling ...
# Missouri                  Augusta Winery 2008 Seyval Blanc (Augusta)
# Nevada             Pahrump Valley Winery 2005 Nevada Ridge First ...
# New Jersey         Heritage 2013 Estate Reserve Barrel Fermented ...
# New Mexico         La Chiripada 2007 Artist Series 1 Dolcetto (Ne...
# New York           Heron Hill 2015 Ingle Vineyard Riesling (Finge...
# North Carolina            Raffaldini 2007 Montepulciano (Swan Creek)
# Ohio                Debonné 2009 Cabernet Franc (Grand River Valley)
# Oregon                 Rainstorm 2013 Pinot Gris (Willamette Valley)
# Pennsylvania                    Chaddsford 2005 Syrah (Pennsylvania)
# Texas              Mont Sec 2015 Mont Sec Vineyards Viognier (Texas)
# Vermont                 Snow Farm 2007 Icewine Vidal Blanc (Vermont)
# Virginia                        Quiévremont 2012 Meritage (Virginia)
# Washington              Mellisoni 2014 Malbec (Columbia Valley (WA))
# Washington-Oregon  J. Scott Cellars 2012 56% Washington/44% Orego...
#
#                               Variety  Year  Price  Grade  \
# Province
# Arizona                      Malvasia  2011   28.0     85
# California         Cabernet Sauvignon  2011   19.0     87
# Colorado                    Red Blend  2012   50.0     87
# Connecticut               White Blend  2006   11.0     84
# Idaho                       Red Blend  2009   25.0     87
# Iowa                     Seyval Blanc  2007   16.0     84
# Kentucky               Cabernet Franc  2007   35.0     83
# Massachusetts          Cabernet Franc  2007   36.0     83
# Michigan                     Riesling  2013   13.0     87
# Missouri                 Seyval Blanc  2008    9.0     84
# Nevada                      Zinfandel  2005   75.0     84
# New Jersey                 Chardonnay  2013   25.0     83
# New Mexico                   Dolcetto  2007   35.0     84
# New York                     Riesling  2015   20.0     88
# North Carolina          Montepulciano  2007   17.0     86
# Ohio                   Cabernet Franc  2009   15.0     83
# Oregon                     Pinot Gris  2013   14.0     87
# Pennsylvania                    Syrah  2005   28.0     86
# Texas                        Viognier  2015   14.0     85
# Vermont                   Vidal Blanc  2007   45.0     85
# Virginia                     Meritage  2012   32.0     87
# Washington                     Malbec  2014   55.0     86
# Washington-Oregon     Sauvignon Blanc  2012   17.0     88
#
#                                         Winery                         Region  \
# Province
# Arizona                     Arizona Stronghold                 Cochise County
# California                  Kirkland Signature                    Napa Valley
# Colorado           The Infinite Monkey Theorem                   Grand Valley
# Connecticut                   Hopkins Vineyard  Western Connecticut Highlands
# Idaho                                   Coiled                          Idaho
# Iowa                                    Jasper                           Iowa
# Kentucky                   Elk Creek Vineyards                       Kentucky
# Massachusetts                            Truro       Southeastern New England
# Michigan                            St. Julian            Lake Michigan Shore
# Missouri                        Augusta Winery                        Augusta
# Nevada                   Pahrump Valley Winery                         Nevada
# New Jersey                            Heritage            Outer Coastal Plain
# New Mexico                        La Chiripada                     New Mexico
# New York                            Heron Hill                   Finger Lakes
# North Carolina                      Raffaldini                     Swan Creek
# Ohio                                   Debonné             Grand River Valley
# Oregon                               Rainstorm              Willamette Valley
# Pennsylvania                        Chaddsford                   Pennsylvania
# Texas                                 Mont Sec                          Texas
# Vermont                              Snow Farm                        Vermont
# Virginia                           Quiévremont                       Virginia
# Washington                           Mellisoni           Columbia Valley (WA)
# Washington-Oregon             J. Scott Cellars                            NaN
#
#                   Country              Taster Taster_Twitter  \
# Province
# Arizona                US  Alexander Peartree  @suskostrzewa
# California             US      Virginie Boone        @vboone
# Colorado               US  Alexander Peartree       @bkfiona
# Connecticut            US     Susan Kostrzewa  @suskostrzewa
# Idaho                  US    Sean P. Sullivan  @wawinereport
# Iowa                   US  Anna Lee C. Iijima            NaN
# Kentucky               US     Susan Kostrzewa  @suskostrzewa
# Massachusetts          US  Anna Lee C. Iijima            NaN
# Michigan               US  Alexander Peartree  @suskostrzewa
# Missouri               US  Alexander Peartree  @suskostrzewa
# Nevada                 US  Alexander Peartree            NaN
# New Jersey             US  Alexander Peartree  @suskostrzewa
# New Mexico             US     Susan Kostrzewa  @suskostrzewa
# New York               US  Anna Lee C. Iijima  @suskostrzewa
# North Carolina         US  Anna Lee C. Iijima            NaN
# Ohio                   US     Susan Kostrzewa  @suskostrzewa
# Oregon                 US        Paul Gregutt    @paulgwine
# Pennsylvania           US     Susan Kostrzewa  @suskostrzewa
# Texas                  US  Alexander Peartree       @bkfiona
# Vermont                US     Susan Kostrzewa  @suskostrzewa
# Virginia               US  Alexander Peartree  @suskostrzewa
# Washington             US    Sean P. Sullivan  @wawinereport
# Washington-Oregon      US        Paul Gregutt    @paulgwine
#
#                                                          Description  \
# Province
# Arizona            Effusive aromas of lychee, lemon drop and oran...
# California         Soft, supple plum envelopes an oaky structure ...
# Colorado           Plush and mouthfilling, this blend of Petit Si...
# Connecticut        This Connecticut white starts out with a succe...
# Idaho              Mostly Syrah, with just a dash of Petite Sirah...
# Iowa               Sweet butter and caramel notes linger amidst s...
# Kentucky           Black fruit, pepper and spice lead this likeab...
# Massachusetts      The acidity is the prominent attribute of this...
# Michigan           Pineapple rind, lemon pith and orange blossom ...
# Missouri           A pretty, grapey wine with tones of pine and l...
# Nevada             A luxurious mouthfeel and good concentration a...
# New Jersey         Toasted sourdough bread and briny lemon show o...
# New Mexico         The nose is honest and bright but not terribly...
# New York           A wisp of bramble extends a savory tone from n...
# North Carolina     Clove and pepper spice the dark red cherry aro...
# Ohio               Chewy tannins and tart acids buttress the midp...
# Oregon             Tart and snappy, the flavors of lime flesh and...
# Pennsylvania       Intriguing all around, this displays earthy no...
# Texas              Peach, banana peel and a slight petrol note sh...
# Vermont            Luscious aromas of lemon, sweet orange and hon...
# Virginia           Red fruit aromas pervade on the nose, with cig...
# Washington         Aromas of cranberry, barrel spice and herb are...
# Washington-Oregon  A blend of grapes from Washington and Oregon, ...
#
#                     Latitude   Longitude   Type
# Province
# Arizona            34.048928 -111.093731  Other
# California         36.778261 -119.417932    Red
# Colorado           39.550051 -105.782067    Red
# Connecticut        41.603221  -73.087749  White
# Idaho              44.068202 -114.742041    Red
# Iowa               41.878003  -93.097702  White
# Kentucky           37.839333  -84.270018    Red
# Massachusetts      42.407211  -71.382437    Red
# Michigan           44.314844  -85.602364  White
# Missouri           37.964253  -91.831833  White
# Nevada             38.802610 -116.419389  Blush
# New Jersey         40.058324  -74.405661  White
# New Mexico         34.519940 -105.870090  Other
# New York           40.712775  -74.005973  White
# North Carolina     35.759573  -79.019300  Other
# Ohio               40.417287  -82.907123    Red
# Oregon             43.804133 -120.554201  White
# Pennsylvania       41.203322  -77.194525    Red
# Texas              31.968599  -99.901813  White
# Vermont            44.558803  -72.577841  White
# Virginia           37.431573  -78.656894  Other
# Washington         47.751074 -120.740139    Red
# Washington-Oregon  45.546962 -123.138602  White

# %%
import gmaps
import numpy as np


# Configure gmaps with API key
gmaps.configure(api_key=gkey)


# Store 'Lat' and 'Lng' into  locations 
locations = file[["Latitude", "Longitude"]].astype(float)
unique_locations = locations.drop_duplicates()
len(unique_locations)
# Out:
# 23

# %%
from config import weather_api

weather_url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx?q="

# %%
# Loop through wineries and append weather lists

weather_response = []

for index, row in unique_locations.iterrows():
#    try:
        if row["Latitude"] > 0:
            lat = (row["Latitude"])
            lng = (row["Longitude"])
        
 # Run a request to endpoint and convert result to json
            jul_weather = requests.get(f"{weather_url}{lat},{lng}&key={weather_api}&date=2011-07-01&enddate=2011-07-31&tp=24&format=json").json()
            aug_weather = requests.get(f"{weather_url}{lat},{lng}&key={weather_api}&date=2011-08-01&enddate=2011-08-31&tp=24&format=json").json()
            sep_weather = requests.get(f"{weather_url}{lat},{lng}&key={weather_api}&date=2011-09-01&enddate=2011-09-30&tp=24&format=json").json()
            
            # Northern hemisphere growing season weather lists
            
            location_response = []
            
            location_response.append(jul_weather)
            location_response.append(aug_weather)
            location_response.append(sep_weather)
            
            weather_response.append(location_response)

# %%
weather_response
# Out:
# [[{'data': {'request': [{'type': 'LatLon',
#       'query': 'Lat 34.05 and Lon -111.09'}],
#     'weather': [{'date': '2011-07-01',
#       'astronomy': [{'sunrise': '05:17 AM',
#         'sunset': '07:40 PM',
#         'moonrise': '05:35 AM',
#         'moonset': '08:03 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '48'}],
#       'maxtempC': '36',
#       'maxtempF': '96',
#       'mintempC': '19',
#       'mintempF': '67',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '36',
#         'tempF': '96',
#         'windspeedMiles': '5',
#         'windspeedKmph': '8',
#         'winddirDegree': '177',
#         'winddir16Point': 'S',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '16',
#         'visibility': '10',
#         'pressure': '1010',
#         'cloudcover': '0',
#         'HeatIndexC': '26',
#         'HeatIndexF': '79',
#         'DewPointC': '-3',
#         'DewPointF': '27',
#         'WindChillC': '27',
#         'WindChillF': '80',
#         'WindGustMiles': '8',
#         'WindGustKmph': '13',
#         'FeelsLikeC': '26',
#         'FeelsLikeF': '79'}]},
#      {'date': '2011-07-02',
#       'astronomy': [{'sunrise': '05:17 AM',
#         'sunset': '07:40 PM',
#         'moonrise': '06:39 AM',
#         'moonset': '08:45 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '41'}],
#       'maxtempC': '36',
#       'maxtempF': '96',
#       'mintempC': '20',
#       'mintempF': '68',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '36',
#         'tempF': '96',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '154',
#         'winddir16Point': 'SSE',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.8',
#         'humidity': '19',
#         'visibility': '10',
#         'pressure': '1009',
#         'cloudcover': '7',
#         'HeatIndexC': '27',
#         'HeatIndexF': '81',
#         'DewPointC': '1',
#         'DewPointF': '35',
#         'WindChillC': '28',
#         'WindChillF': '83',
#         'WindGustMiles': '11',
#         'WindGustKmph': '17',
#         'FeelsLikeC': '27',
#         'FeelsLikeF': '81'}]},
#      {'date': '2011-07-03',
#       'astronomy': [{'sunrise': '05:18 AM',
#         'sunset': '07:40 PM',
#         'moonrise': '07:46 AM',
#         'moonset': '09:24 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '34'}],
#       'maxtempC': '33',
#       'maxtempF': '91',
#       'mintempC': '22',
#       'mintempF': '71',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '33',
#         'tempF': '91',
#         'windspeedMiles': '4',
#         'windspeedKmph': '6',
#         'winddirDegree': '124',
#         'winddir16Point': 'ESE',
#         'weatherCode': '356',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0010_heavy_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Moderate or heavy rain shower'}],
#         'precipMM': '3.6',
#         'humidity': '32',
#         'visibility': '10',
#         'pressure': '1010',
#         'cloudcover': '11',
#         'HeatIndexC': '27',
#         'HeatIndexF': '81',
#         'DewPointC': '9',
#         'DewPointF': '48',
#         'WindChillC': '27',
#         'WindChillF': '81',
#         'WindGustMiles': '7',
#         'WindGustKmph': '11',
#         'FeelsLikeC': '27',
#         'FeelsLikeF': '81'}]},
#      {'date': '2011-07-04',
#       'astronomy': [{'sunrise': '05:18 AM',
#         'sunset': '07:40 PM',
#         'moonrise': '08:52 AM',
#         'moonset': '09:59 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '28'}],
#       'maxtempC': '33',
#       'maxtempF': '91',
#       'mintempC': '20',
#       'mintempF': '67',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '33',
#         'tempF': '91',
#         'windspeedMiles': '4',
#         'windspeedKmph': '7',
#         'winddirDegree': '253',
#         'winddir16Point': 'WSW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '2.4',
#         'humidity': '41',
#         'visibility': '10',
#         'pressure': '1011',
#         'cloudcover': '9',
#         'HeatIndexC': '27',
#         'HeatIndexF': '80',
#         'DewPointC': '11',
#         'DewPointF': '53',
#         'WindChillC': '26',
#         'WindChillF': '79',
#         'WindGustMiles': '7',
#         'WindGustKmph': '12',
#         'FeelsLikeC': '27',
#         'FeelsLikeF': '80'}]},
#      {'date': '2011-07-05',
#       'astronomy': [{'sunrise': '05:19 AM',
#         'sunset': '07:40 PM',
#         'moonrise': '09:58 AM',
#         'moonset': '10:32 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '21'}],
#       'maxtempC': '32',
#       'maxtempF': '89',
#       'mintempC': '20',
#       'mintempF': '67',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '32',
#         'tempF': '89',
#         'windspeedMiles': '5',
#         'windspeedKmph': '8',
#         'winddirDegree': '166',
#         'winddir16Point': 'SSE',
#         'weatherCode': '353',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Light rain shower'}],
#         'precipMM': '4.8',
#         'humidity': '55',
#         'visibility': '10',
#         'pressure': '1012',
#         'cloudcover': '23',
#         'HeatIndexC': '25',
#         'HeatIndexF': '78',
#         'DewPointC': '15',
#         'DewPointF': '58',
#         'WindChillC': '25',
#         'WindChillF': '77',
#         'WindGustMiles': '7',
#         'WindGustKmph': '12',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '78'}]},
#      {'date': '2011-07-06',
#       'astronomy': [{'sunrise': '05:19 AM',
#         'sunset': '07:39 PM',
#         'moonrise': '11:05 AM',
#         'moonset': '11:07 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '14'}],
#       'maxtempC': '32',
#       'maxtempF': '89',
#       'mintempC': '18',
#       'mintempF': '65',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '32',
#         'tempF': '89',
#         'windspeedMiles': '5',
#         'windspeedKmph': '8',
#         'winddirDegree': '216',
#         'winddir16Point': 'SW',
#         'weatherCode': '386',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0016_thundery_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy light rain with thunder'}],
#         'precipMM': '3.2',
#         'humidity': '57',
#         'visibility': '10',
#         'pressure': '1014',
#         'cloudcover': '13',
#         'HeatIndexC': '25',
#         'HeatIndexF': '77',
#         'DewPointC': '15',
#         'DewPointF': '59',
#         'WindChillC': '25',
#         'WindChillF': '77',
#         'WindGustMiles': '7',
#         'WindGustKmph': '12',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '77'}]},
#      {'date': '2011-07-07',
#       'astronomy': [{'sunrise': '05:20 AM',
#         'sunset': '07:39 PM',
#         'moonrise': '12:11 PM',
#         'moonset': '11:42 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '7'}],
#       'maxtempC': '34',
#       'maxtempF': '93',
#       'mintempC': '20',
#       'mintempF': '67',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '34',
#         'tempF': '93',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '261',
#         'winddir16Point': 'W',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.2',
#         'humidity': '36',
#         'visibility': '10',
#         'pressure': '1012',
#         'cloudcover': '5',
#         'HeatIndexC': '27',
#         'HeatIndexF': '80',
#         'DewPointC': '9',
#         'DewPointF': '49',
#         'WindChillC': '27',
#         'WindChillF': '80',
#         'WindGustMiles': '10',
#         'WindGustKmph': '16',
#         'FeelsLikeC': '27',
#         'FeelsLikeF': '80'}]},
#      {'date': '2011-07-08',
#       'astronomy': [{'sunrise': '05:20 AM',
#         'sunset': '07:39 PM',
#         'moonrise': '01:19 PM',
#         'moonset': 'No moonset',
#         'moon_phase': 'New Moon',
#         'moon_illumination': '0'}],
#       'maxtempC': '30',
#       'maxtempF': '86',
#       'mintempC': '20',
#       'mintempF': '68',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '30',
#         'tempF': '86',
#         'windspeedMiles': '6',
#         'windspeedKmph': '9',
#         'winddirDegree': '229',
#         'winddir16Point': 'SW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '1.6',
#         'humidity': '37',
#         'visibility': '10',
#         'pressure': '1010',
#         'cloudcover': '8',
#         'HeatIndexC': '25',
#         'HeatIndexF': '77',
#         'DewPointC': '9',
#         'DewPointF': '49',
#         'WindChillC': '25',
#         'WindChillF': '78',
#         'WindGustMiles': '9',
#         'WindGustKmph': '15',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '77'}]},
#      {'date': '2011-07-09',
#       'astronomy': [{'sunrise': '05:21 AM',
#         'sunset': '07:39 PM',
#         'moonrise': '02:26 PM',
#         'moonset': '12:20 AM',
#         'moon_phase': 'Waxing Crescent',
#         'moon_illumination': '0'}],
#       'maxtempC': '33',
#       'maxtempF': '92',
#       'mintempC': '21',
#       'mintempF': '70',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '33',
#         'tempF': '92',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '231',
#         'winddir16Point': 'SW',
#         'weatherCode': '116',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#         'weatherDesc': [{'value': 'Partly cloudy'}],
#         'precipMM': '0.3',
#         'humidity': '33',
#         'visibility': '10',
#         'pressure': '1010',
#         'cloudcover': '20',
#         'HeatIndexC': '27',
#         'HeatIndexF': '80',
#         'DewPointC': '8',
#         'DewPointF': '47',
#         'WindChillC': '27',
#         'WindChillF': '80',
#         'WindGustMiles': '10',
#         'WindGustKmph': '16',
#         'FeelsLikeC': '27',
#         'FeelsLikeF': '80'}]},
#      {'date': '2011-07-10',
#       'astronomy': [{'sunrise': '05:21 AM',
#         'sunset': '07:39 PM',
#         'moonrise': '03:33 PM',
#         'moonset': '01:03 AM',
#         'moon_phase': 'Waxing Crescent',
#         'moon_illumination': '7'}],
#       'maxtempC': '28',
#       'maxtempF': '83',
#       'mintempC': '21',
#       'mintempF': '69',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '28',
#         'tempF': '83',
#         'windspeedMiles': '5',
#         'windspeedKmph': '8',
#         'winddirDegree': '214',
#         'winddir16Point': 'SW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '3.0',
#         'humidity': '48',
#         'visibility': '10',
#         'pressure': '1011',
#         'cloudcover': '23',
#         'HeatIndexC': '25',
#         'HeatIndexF': '77',
#         'DewPointC': '13',
#         'DewPointF': '55',
#         'WindChillC': '24',
#         'WindChillF': '76',
#         'WindGustMiles': '9',
#         'WindGustKmph': '14',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '77'}]},
#      {'date': '2011-07-11',
#       'astronomy': [{'sunrise': '05:22 AM',
#         'sunset': '07:38 PM',
#         'moonrise': '04:37 PM',
#         'moonset': '01:51 AM',
#         'moon_phase': 'Waxing Crescent',
#         'moon_illumination': '14'}],
#       'maxtempC': '25',
#       'maxtempF': '77',
#       'mintempC': '18',
#       'mintempF': '65',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '25',
#         'tempF': '77',
#         'windspeedMiles': '4',
#         'windspeedKmph': '6',
#         'winddirDegree': '256',
#         'winddir16Point': 'WSW',
#         'weatherCode': '386',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0016_thundery_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy light rain with thunder'}],
#         'precipMM': '4.6',
#         'humidity': '61',
#         'visibility': '9',
#         'pressure': '1014',
#         'cloudcover': '34',
#         'HeatIndexC': '23',
#         'HeatIndexF': '73',
#         'DewPointC': '14',
#         'DewPointF': '56',
#         'WindChillC': '21',
#         'WindChillF': '71',
#         'WindGustMiles': '7',
#         'WindGustKmph': '11',
#         'FeelsLikeC': '21',
#         'FeelsLikeF': '71'}]},
#      {'date': '2011-07-12',
#       'astronomy': [{'sunrise': '05:22 AM',
#         'sunset': '07:38 PM',
#         'moonrise': '05:37 PM',
#         'moonset': '02:45 AM',
#         'moon_phase': 'Waxing Crescent',
#         'moon_illumination': '21'}],
#       'maxtempC': '29',
#       'maxtempF': '83',
#       'mintempC': '20',
#       'mintempF': '68',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '29',
#         'tempF': '83',
#         'windspeedMiles': '4',
#         'windspeedKmph': '7',
#         'winddirDegree': '276',
#         'winddir16Point': 'W',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '49',
#         'visibility': '10',
#         'pressure': '1013',
#         'cloudcover': '17',
#         'HeatIndexC': '24',
#         'HeatIndexF': '74',
#         'DewPointC': '11',
#         'DewPointF': '53',
#         'WindChillC': '23',
#         'WindChillF': '73',
#         'WindGustMiles': '6',
#         'WindGustKmph': '10',
#         'FeelsLikeC': '24',
#         'FeelsLikeF': '74'}]},
#      {'date': '2011-07-13',
#       'astronomy': [{'sunrise': '05:23 AM',
#         'sunset': '07:38 PM',
#         'moonrise': '06:30 PM',
#         'moonset': '03:45 AM',
#         'moon_phase': 'First Quarter',
#         'moon_illumination': '28'}],
#       'maxtempC': '30',
#       'maxtempF': '86',
#       'mintempC': '18',
#       'mintempF': '65',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '30',
#         'tempF': '86',
#         'windspeedMiles': '7',
#         'windspeedKmph': '11',
#         'winddirDegree': '215',
#         'winddir16Point': 'SW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '37',
#         'visibility': '10',
#         'pressure': '1011',
#         'cloudcover': '6',
#         'HeatIndexC': '23',
#         'HeatIndexF': '74',
#         'DewPointC': '7',
#         'DewPointF': '45',
#         'WindChillC': '24',
#         'WindChillF': '75',
#         'WindGustMiles': '10',
#         'WindGustKmph': '16',
#         'FeelsLikeC': '23',
#         'FeelsLikeF': '74'}]},
#      {'date': '2011-07-14',
#       'astronomy': [{'sunrise': '05:24 AM',
#         'sunset': '07:37 PM',
#         'moonrise': '07:16 PM',
#         'moonset': '04:47 AM',
#         'moon_phase': 'First Quarter',
#         'moon_illumination': '34'}],
#       'maxtempC': '30',
#       'maxtempF': '85',
#       'mintempC': '19',
#       'mintempF': '65',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '30',
#         'tempF': '85',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '195',
#         'winddir16Point': 'SSW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '19',
#         'visibility': '10',
#         'pressure': '1011',
#         'cloudcover': '0',
#         'HeatIndexC': '22',
#         'HeatIndexF': '72',
#         'DewPointC': '-3',
#         'DewPointF': '27',
#         'WindChillC': '23',
#         'WindChillF': '73',
#         'WindGustMiles': '9',
#         'WindGustKmph': '14',
#         'FeelsLikeC': '22',
#         'FeelsLikeF': '72'}]},
#      {'date': '2011-07-15',
#       'astronomy': [{'sunrise': '05:24 AM',
#         'sunset': '07:37 PM',
#         'moonrise': '07:56 PM',
#         'moonset': '05:49 AM',
#         'moon_phase': 'First Quarter',
#         'moon_illumination': '41'}],
#       'maxtempC': '30',
#       'maxtempF': '86',
#       'mintempC': '18',
#       'mintempF': '65',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '30',
#         'tempF': '86',
#         'windspeedMiles': '6',
#         'windspeedKmph': '9',
#         'winddirDegree': '189',
#         'winddir16Point': 'S',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '16',
#         'visibility': '10',
#         'pressure': '1011',
#         'cloudcover': '0',
#         'HeatIndexC': '22',
#         'HeatIndexF': '72',
#         'DewPointC': '-5',
#         'DewPointF': '24',
#         'WindChillC': '23',
#         'WindChillF': '73',
#         'WindGustMiles': '9',
#         'WindGustKmph': '14',
#         'FeelsLikeC': '22',
#         'FeelsLikeF': '72'}]},
#      {'date': '2011-07-16',
#       'astronomy': [{'sunrise': '05:25 AM',
#         'sunset': '07:36 PM',
#         'moonrise': '08:30 PM',
#         'moonset': '06:51 AM',
#         'moon_phase': 'First Quarter',
#         'moon_illumination': '48'}],
#       'maxtempC': '34',
#       'maxtempF': '93',
#       'mintempC': '19',
#       'mintempF': '65',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '34',
#         'tempF': '93',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '184',
#         'winddir16Point': 'S',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '16',
#         'visibility': '10',
#         'pressure': '1009',
#         'cloudcover': '6',
#         'HeatIndexC': '25',
#         'HeatIndexF': '77',
#         'DewPointC': '-3',
#         'DewPointF': '27',
#         'WindChillC': '26',
#         'WindChillF': '78',
#         'WindGustMiles': '9',
#         'WindGustKmph': '15',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '77'}]},
#      {'date': '2011-07-17',
#       'astronomy': [{'sunrise': '05:26 AM',
#         'sunset': '07:36 PM',
#         'moonrise': '09:01 PM',
#         'moonset': '07:50 AM',
#         'moon_phase': 'Waxing Gibbous',
#         'moon_illumination': '55'}],
#       'maxtempC': '34',
#       'maxtempF': '94',
#       'mintempC': '22',
#       'mintempF': '71',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '34',
#         'tempF': '94',
#         'windspeedMiles': '7',
#         'windspeedKmph': '12',
#         'winddirDegree': '143',
#         'winddir16Point': 'SE',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.8',
#         'humidity': '26',
#         'visibility': '10',
#         'pressure': '1009',
#         'cloudcover': '9',
#         'HeatIndexC': '27',
#         'HeatIndexF': '81',
#         'DewPointC': '6',
#         'DewPointF': '43',
#         'WindChillC': '28',
#         'WindChillF': '82',
#         'WindGustMiles': '11',
#         'WindGustKmph': '17',
#         'FeelsLikeC': '27',
#         'FeelsLikeF': '81'}]},
#      {'date': '2011-07-18',
#       'astronomy': [{'sunrise': '05:26 AM',
#         'sunset': '07:35 PM',
#         'moonrise': '09:31 PM',
#         'moonset': '08:48 AM',
#         'moon_phase': 'Waxing Gibbous',
#         'moon_illumination': '62'}],
#       'maxtempC': '35',
#       'maxtempF': '94',
#       'mintempC': '21',
#       'mintempF': '70',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '35',
#         'tempF': '94',
#         'windspeedMiles': '9',
#         'windspeedKmph': '14',
#         'winddirDegree': '155',
#         'winddir16Point': 'SSE',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '1.2',
#         'humidity': '31',
#         'visibility': '10',
#         'pressure': '1012',
#         'cloudcover': '11',
#         'HeatIndexC': '28',
#         'HeatIndexF': '82',
#         'DewPointC': '8',
#         'DewPointF': '47',
#         'WindChillC': '28',
#         'WindChillF': '82',
#         'WindGustMiles': '13',
#         'WindGustKmph': '21',
#         'FeelsLikeC': '28',
#         'FeelsLikeF': '82'}]},
#      {'date': '2011-07-19',
#       'astronomy': [{'sunrise': '05:27 AM',
#         'sunset': '07:35 PM',
#         'moonrise': '09:59 PM',
#         'moonset': '09:44 AM',
#         'moon_phase': 'Waxing Gibbous',
#         'moon_illumination': '69'}],
#       'maxtempC': '32',
#       'maxtempF': '90',
#       'mintempC': '18',
#       'mintempF': '64',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '32',
#         'tempF': '90',
#         'windspeedMiles': '5',
#         'windspeedKmph': '9',
#         'winddirDegree': '219',
#         'winddir16Point': 'SW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '4.9',
#         'humidity': '43',
#         'visibility': '10',
#         'pressure': '1014',
#         'cloudcover': '10',
#         'HeatIndexC': '25',
#         'HeatIndexF': '76',
#         'DewPointC': '11',
#         'DewPointF': '51',
#         'WindChillC': '25',
#         'WindChillF': '77',
#         'WindGustMiles': '9',
#         'WindGustKmph': '14',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '76'}]},
#      {'date': '2011-07-20',
#       'astronomy': [{'sunrise': '05:27 AM',
#         'sunset': '07:34 PM',
#         'moonrise': '10:26 PM',
#         'moonset': '10:38 AM',
#         'moon_phase': 'Full Moon',
#         'moon_illumination': '98'}],
#       'maxtempC': '32',
#       'maxtempF': '90',
#       'mintempC': '19',
#       'mintempF': '66',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '32',
#         'tempF': '90',
#         'windspeedMiles': '5',
#         'windspeedKmph': '9',
#         'winddirDegree': '259',
#         'winddir16Point': 'WSW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.5',
#         'humidity': '39',
#         'visibility': '10',
#         'pressure': '1012',
#         'cloudcover': '8',
#         'HeatIndexC': '26',
#         'HeatIndexF': '78',
#         'DewPointC': '11',
#         'DewPointF': '51',
#         'WindChillC': '26',
#         'WindChillF': '79',
#         'WindGustMiles': '8',
#         'WindGustKmph': '13',
#         'FeelsLikeC': '26',
#         'FeelsLikeF': '78'}]},
#      {'date': '2011-07-21',
#       'astronomy': [{'sunrise': '05:28 AM',
#         'sunset': '07:34 PM',
#         'moonrise': '10:56 PM',
#         'moonset': '11:34 AM',
#         'moon_phase': 'Full Moon',
#         'moon_illumination': '98'}],
#       'maxtempC': '33',
#       'maxtempF': '92',
#       'mintempC': '20',
#       'mintempF': '69',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '33',
#         'tempF': '92',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '240',
#         'winddir16Point': 'WSW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '34',
#         'visibility': '10',
#         'pressure': '1010',
#         'cloudcover': '11',
#         'HeatIndexC': '27',
#         'HeatIndexF': '80',
#         'DewPointC': '10',
#         'DewPointF': '49',
#         'WindChillC': '27',
#         'WindChillF': '81',
#         'WindGustMiles': '9',
#         'WindGustKmph': '14',
#         'FeelsLikeC': '27',
#         'FeelsLikeF': '80'}]},
#      {'date': '2011-07-22',
#       'astronomy': [{'sunrise': '05:29 AM',
#         'sunset': '07:33 PM',
#         'moonrise': '11:28 PM',
#         'moonset': '12:28 PM',
#         'moon_phase': 'Full Moon',
#         'moon_illumination': '98'}],
#       'maxtempC': '33',
#       'maxtempF': '91',
#       'mintempC': '21',
#       'mintempF': '69',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '33',
#         'tempF': '91',
#         'windspeedMiles': '7',
#         'windspeedKmph': '11',
#         'winddirDegree': '240',
#         'winddir16Point': 'WSW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '21',
#         'visibility': '10',
#         'pressure': '1010',
#         'cloudcover': '11',
#         'HeatIndexC': '26',
#         'HeatIndexF': '78',
#         'DewPointC': '3',
#         'DewPointF': '37',
#         'WindChillC': '27',
#         'WindChillF': '81',
#         'WindGustMiles': '10',
#         'WindGustKmph': '16',
#         'FeelsLikeC': '26',
#         'FeelsLikeF': '78'}]},
#      {'date': '2011-07-23',
#       'astronomy': [{'sunrise': '05:30 AM',
#         'sunset': '07:32 PM',
#         'moonrise': 'No moonrise',
#         'moonset': '01:25 PM',
#         'moon_phase': 'Full Moon',
#         'moon_illumination': '98'}],
#       'maxtempC': '30',
#       'maxtempF': '87',
#       'mintempC': '19',
#       'mintempF': '66',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '30',
#         'tempF': '87',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '254',
#         'winddir16Point': 'WSW',
#         'weatherCode': '116',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#         'weatherDesc': [{'value': 'Partly cloudy'}],
#         'precipMM': '0.1',
#         'humidity': '45',
#         'visibility': '10',
#         'pressure': '1014',
#         'cloudcover': '29',
#         'HeatIndexC': '25',
#         'HeatIndexF': '77',
#         'DewPointC': '12',
#         'DewPointF': '53',
#         'WindChillC': '25',
#         'WindChillF': '77',
#         'WindGustMiles': '9',
#         'WindGustKmph': '15',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '77'}]},
#      {'date': '2011-07-24',
#       'astronomy': [{'sunrise': '05:30 AM',
#         'sunset': '07:32 PM',
#         'moonrise': '12:03 AM',
#         'moonset': '02:21 PM',
#         'moon_phase': 'Waning Gibbous',
#         'moon_illumination': '97'}],
#       'maxtempC': '30',
#       'maxtempF': '86',
#       'mintempC': '18',
#       'mintempF': '65',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '30',
#         'tempF': '86',
#         'windspeedMiles': '7',
#         'windspeedKmph': '12',
#         'winddirDegree': '263',
#         'winddir16Point': 'W',
#         'weatherCode': '200',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0016_thundery_showers.png'}],
#         'weatherDesc': [{'value': 'Thundery outbreaks possible'}],
#         'precipMM': '0.0',
#         'humidity': '54',
#         'visibility': '10',
#         'pressure': '1015',
#         'cloudcover': '25',
#         'HeatIndexC': '25',
#         'HeatIndexF': '77',
#         'DewPointC': '14',
#         'DewPointF': '57',
#         'WindChillC': '24',
#         'WindChillF': '76',
#         'WindGustMiles': '10',
#         'WindGustKmph': '16',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '77'}]},
#      {'date': '2011-07-25',
#       'astronomy': [{'sunrise': '05:31 AM',
#         'sunset': '07:31 PM',
#         'moonrise': '12:43 AM',
#         'moonset': '03:18 PM',
#         'moon_phase': 'Waning Gibbous',
#         'moon_illumination': '90'}],
#       'maxtempC': '32',
#       'maxtempF': '89',
#       'mintempC': '19',
#       'mintempF': '67',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '32',
#         'tempF': '89',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '233',
#         'winddir16Point': 'SW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.3',
#         'humidity': '44',
#         'visibility': '10',
#         'pressure': '1014',
#         'cloudcover': '19',
#         'HeatIndexC': '25',
#         'HeatIndexF': '77',
#         'DewPointC': '11',
#         'DewPointF': '53',
#         'WindChillC': '25',
#         'WindChillF': '77',
#         'WindGustMiles': '9',
#         'WindGustKmph': '15',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '77'}]},
#      {'date': '2011-07-26',
#       'astronomy': [{'sunrise': '05:32 AM',
#         'sunset': '07:30 PM',
#         'moonrise': '01:29 AM',
#         'moonset': '04:13 PM',
#         'moon_phase': 'Waning Gibbous',
#         'moon_illumination': '83'}],
#       'maxtempC': '27',
#       'maxtempF': '80',
#       'mintempC': '20',
#       'mintempF': '68',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '27',
#         'tempF': '80',
#         'windspeedMiles': '5',
#         'windspeedKmph': '9',
#         'winddirDegree': '239',
#         'winddir16Point': 'WSW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '1.2',
#         'humidity': '52',
#         'visibility': '10',
#         'pressure': '1012',
#         'cloudcover': '29',
#         'HeatIndexC': '24',
#         'HeatIndexF': '76',
#         'DewPointC': '13',
#         'DewPointF': '55',
#         'WindChillC': '23',
#         'WindChillF': '74',
#         'WindGustMiles': '8',
#         'WindGustKmph': '13',
#         'FeelsLikeC': '24',
#         'FeelsLikeF': '76'}]},
#      {'date': '2011-07-27',
#       'astronomy': [{'sunrise': '05:32 AM',
#         'sunset': '07:30 PM',
#         'moonrise': '02:21 AM',
#         'moonset': '05:06 PM',
#         'moon_phase': 'Waning Gibbous',
#         'moon_illumination': '76'}],
#       'maxtempC': '30',
#       'maxtempF': '85',
#       'mintempC': '20',
#       'mintempF': '68',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '30',
#         'tempF': '85',
#         'windspeedMiles': '4',
#         'windspeedKmph': '6',
#         'winddirDegree': '241',
#         'winddir16Point': 'WSW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '1.5',
#         'humidity': '52',
#         'visibility': '10',
#         'pressure': '1012',
#         'cloudcover': '24',
#         'HeatIndexC': '25',
#         'HeatIndexF': '77',
#         'DewPointC': '14',
#         'DewPointF': '57',
#         'WindChillC': '25',
#         'WindChillF': '76',
#         'WindGustMiles': '5',
#         'WindGustKmph': '9',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '77'}]},
#      {'date': '2011-07-28',
#       'astronomy': [{'sunrise': '05:33 AM',
#         'sunset': '07:29 PM',
#         'moonrise': '03:20 AM',
#         'moonset': '05:55 PM',
#         'moon_phase': 'Last Quarter',
#         'moon_illumination': '69'}],
#       'maxtempC': '32',
#       'maxtempF': '89',
#       'mintempC': '21',
#       'mintempF': '70',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '32',
#         'tempF': '89',
#         'windspeedMiles': '4',
#         'windspeedKmph': '6',
#         'winddirDegree': '228',
#         'winddir16Point': 'SW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '3.7',
#         'humidity': '33',
#         'visibility': '10',
#         'pressure': '1011',
#         'cloudcover': '21',
#         'HeatIndexC': '26',
#         'HeatIndexF': '79',
#         'DewPointC': '9',
#         'DewPointF': '48',
#         'WindChillC': '26',
#         'WindChillF': '80',
#         'WindGustMiles': '7',
#         'WindGustKmph': '11',
#         'FeelsLikeC': '26',
#         'FeelsLikeF': '79'}]},
#      {'date': '2011-07-29',
#       'astronomy': [{'sunrise': '05:34 AM',
#         'sunset': '07:28 PM',
#         'moonrise': '04:23 AM',
#         'moonset': '06:39 PM',
#         'moon_phase': 'Last Quarter',
#         'moon_illumination': '62'}],
#       'maxtempC': '34',
#       'maxtempF': '93',
#       'mintempC': '20',
#       'mintempF': '67',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '34',
#         'tempF': '93',
#         'windspeedMiles': '5',
#         'windspeedKmph': '8',
#         'winddirDegree': '197',
#         'winddir16Point': 'SSW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '36',
#         'visibility': '10',
#         'pressure': '1012',
#         'cloudcover': '21',
#         'HeatIndexC': '27',
#         'HeatIndexF': '81',
#         'DewPointC': '10',
#         'DewPointF': '50',
#         'WindChillC': '27',
#         'WindChillF': '81',
#         'WindGustMiles': '7',
#         'WindGustKmph': '12',
#         'FeelsLikeC': '27',
#         'FeelsLikeF': '81'}]},
#      {'date': '2011-07-30',
#       'astronomy': [{'sunrise': '05:34 AM',
#         'sunset': '07:27 PM',
#         'moonrise': '05:30 AM',
#         'moonset': '07:20 PM',
#         'moon_phase': 'Last Quarter',
#         'moon_illumination': '55'}],
#       'maxtempC': '32',
#       'maxtempF': '89',
#       'mintempC': '21',
#       'mintempF': '70',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '32',
#         'tempF': '89',
#         'windspeedMiles': '4',
#         'windspeedKmph': '6',
#         'winddirDegree': '157',
#         'winddir16Point': 'SSE',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '3.2',
#         'humidity': '44',
#         'visibility': '10',
#         'pressure': '1014',
#         'cloudcover': '17',
#         'HeatIndexC': '27',
#         'HeatIndexF': '80',
#         'DewPointC': '12',
#         'DewPointF': '54',
#         'WindChillC': '26',
#         'WindChillF': '79',
#         'WindGustMiles': '6',
#         'WindGustKmph': '10',
#         'FeelsLikeC': '27',
#         'FeelsLikeF': '80'}]},
#      {'date': '2011-07-31',
#       'astronomy': [{'sunrise': '05:35 AM',
#         'sunset': '07:27 PM',
#         'moonrise': '06:37 AM',
#         'moonset': '07:58 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '48'}],
#       'maxtempC': '31',
#       'maxtempF': '88',
#       'mintempC': '20',
#       'mintempF': '68',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '31',
#         'tempF': '88',
#         'windspeedMiles': '7',
#         'windspeedKmph': '12',
#         'winddirDegree': '165',
#         'winddir16Point': 'SSE',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '0.4',
#         'humidity': '45',
#         'visibility': '10',
#         'pressure': '1014',
#         'cloudcover': '20',
#         'HeatIndexC': '25',
#         'HeatIndexF': '78',
#         'DewPointC': '12',
#         'DewPointF': '54',
#         'WindChillC': '25',
#         'WindChillF': '78',
#         'WindGustMiles': '12',
#         'WindGustKmph': '19',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '78'}]}]}},
#   {'data': {'request': [{'type': 'LatLon',
#       'query': 'Lat 34.05 and Lon -111.09'}],
#     'weather': [{'date': '2011-08-01',
#       'astronomy': [{'sunrise': '05:36 AM',
#         'sunset': '07:26 PM',
#         'moonrise': '07:46 AM',
#         'moonset': '08:33 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '41'}],
#       'maxtempC': '28',
#       'maxtempF': '82',
#       'mintempC': '20',
#       'mintempF': '68',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '28',
#         'tempF': '82',
#         'windspeedMiles': '3',
#         'windspeedKmph': '5',
#         'winddirDegree': '212',
#         'winddir16Point': 'SSW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '4.0',
#         'humidity': '53',
#         'visibility': '10',
#         'pressure': '1016',
#         'cloudcover': '18',
#         'HeatIndexC': '25',
#         'HeatIndexF': '78',
#         'DewPointC': '14',
#         'DewPointF': '57',
#         'WindChillC': '24',
#         'WindChillF': '76',
#         'WindGustMiles': '6',
#         'WindGustKmph': '9',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '78'}]},
#      {'date': '2011-08-02',
#       'astronomy': [{'sunrise': '05:37 AM',
#         'sunset': '07:25 PM',
#         'moonrise': '08:54 AM',
#         'moonset': '09:08 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '34'}],
#       'maxtempC': '34',
#       'maxtempF': '93',
#       'mintempC': '21',
#       'mintempF': '69',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '34',
#         'tempF': '93',
#         'windspeedMiles': '4',
#         'windspeedKmph': '6',
#         'winddirDegree': '177',
#         'winddir16Point': 'S',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.4',
#         'humidity': '38',
#         'visibility': '10',
#         'pressure': '1012',
#         'cloudcover': '8',
#         'HeatIndexC': '28',
#         'HeatIndexF': '82',
#         'DewPointC': '11',
#         'DewPointF': '53',
#         'WindChillC': '28',
#         'WindChillF': '82',
#         'WindGustMiles': '6',
#         'WindGustKmph': '9',
#         'FeelsLikeC': '28',
#         'FeelsLikeF': '82'}]},
#      {'date': '2011-08-03',
#       'astronomy': [{'sunrise': '05:37 AM',
#         'sunset': '07:24 PM',
#         'moonrise': '10:02 AM',
#         'moonset': '09:44 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '28'}],
#       'maxtempC': '35',
#       'maxtempF': '94',
#       'mintempC': '22',
#       'mintempF': '72',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '35',
#         'tempF': '94',
#         'windspeedMiles': '5',
#         'windspeedKmph': '8',
#         'winddirDegree': '193',
#         'winddir16Point': 'SSW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '31',
#         'visibility': '10',
#         'pressure': '1010',
#         'cloudcover': '6',
#         'HeatIndexC': '29',
#         'HeatIndexF': '83',
#         'DewPointC': '10',
#         'DewPointF': '49',
#         'WindChillC': '29',
#         'WindChillF': '84',
#         'WindGustMiles': '7',
#         'WindGustKmph': '12',
#         'FeelsLikeC': '29',
#         'FeelsLikeF': '83'}]},
#      {'date': '2011-08-04',
#       'astronomy': [{'sunrise': '05:38 AM',
#         'sunset': '07:23 PM',
#         'moonrise': '11:10 AM',
#         'moonset': '10:21 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '21'}],
#       'maxtempC': '33',
#       'maxtempF': '91',
#       'mintempC': '22',
#       'mintempF': '72',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '33',
#         'tempF': '91',
#         'windspeedMiles': '3',
#         'windspeedKmph': '5',
#         'winddirDegree': '204',
#         'winddir16Point': 'SSW',
#         'weatherCode': '389',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0024_thunderstorms.png'}],
#         'weatherDesc': [{'value': 'Moderate or heavy rain with thunder'}],
#         'precipMM': '3.4',
#         'humidity': '41',
#         'visibility': '9',
#         'pressure': '1012',
#         'cloudcover': '18',
#         'HeatIndexC': '28',
#         'HeatIndexF': '82',
#         'DewPointC': '12',
#         'DewPointF': '54',
#         'WindChillC': '27',
#         'WindChillF': '81',
#         'WindGustMiles': '6',
#         'WindGustKmph': '9',
#         'FeelsLikeC': '28',
#         'FeelsLikeF': '82'}]},
#      {'date': '2011-08-05',
#       'astronomy': [{'sunrise': '05:39 AM',
#         'sunset': '07:22 PM',
#         'moonrise': '12:18 PM',
#         'moonset': '11:03 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '14'}],
#       'maxtempC': '34',
#       'maxtempF': '93',
#       'mintempC': '22',
#       'mintempF': '71',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '34',
#         'tempF': '93',
#         'windspeedMiles': '6',
#         'windspeedKmph': '9',
#         'winddirDegree': '209',
#         'winddir16Point': 'SSW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '0.0',
#         'humidity': '30',
#         'visibility': '10',
#         'pressure': '1012',
#         'cloudcover': '1',
#         'HeatIndexC': '28',
#         'HeatIndexF': '82',
#         'DewPointC': '8',
#         'DewPointF': '46',
#         'WindChillC': '28',
#         'WindChillF': '83',
#         'WindGustMiles': '8',
#         'WindGustKmph': '13',
#         'FeelsLikeC': '28',
#         'FeelsLikeF': '82'}]},
#      {'date': '2011-08-06',
#       'astronomy': [{'sunrise': '05:39 AM',
#         'sunset': '07:21 PM',
#         'moonrise': '01:26 PM',
#         'moonset': '11:49 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '7'}],
#       'maxtempC': '33',
#       'maxtempF': '91',
#       'mintempC': '21',
#       'mintempF': '70',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '33',
#         'tempF': '91',
#         'windspeedMiles': '5',
#         'windspeedKmph': '9',
#         'winddirDegree': '231',
#         'winddir16Point': 'SW',
#         'weatherCode': '176',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Patchy rain possible'}],
#         'precipMM': '0.0',
#         'humidity': '26',
#         'visibility': '10',
#         'pressure': '1014',
#         'cloudcover': '1',
#         'HeatIndexC': '26',
#         'HeatIndexF': '79',
#         'DewPointC': '6',
#         'DewPointF': '42',
#         'WindChillC': '27',
#         'WindChillF': '81',
#         'WindGustMiles': '7',
#         'WindGustKmph': '12',
#         'FeelsLikeC': '26',
#         'FeelsLikeF': '79'}]},
#      {'date': '2011-08-07',
#       'astronomy': [{'sunrise': '05:40 AM',
#         'sunset': '07:20 PM',
#         'moonrise': '02:30 PM',
#         'moonset': 'No moonset',
#         'moon_phase': 'New Moon',
#         'moon_illumination': '0'}],
#       'maxtempC': '32',
#       'maxtempF': '89',
#       'mintempC': '19',
#       'mintempF': '66',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '32',
#         'tempF': '89',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '200',
#         'winddir16Point': 'SSW',
#         'weatherCode': '305',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0010_heavy_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Heavy rain at times'}],
#         'precipMM': '0.0',
#         'humidity': '53',
#         'visibility': '8',
#         'pressure': '1014',
#         'cloudcover': '27',
#         'HeatIndexC': '25',
#         'HeatIndexF': '76',
#         'DewPointC': '13',
#         'DewPointF': '55',
#         'WindChillC': '25',
#         'WindChillF': '77',
#         'WindGustMiles': '8',
#         'WindGustKmph': '13',
#         'FeelsLikeC': '25',
#         'FeelsLikeF': '76'}]},
#      {'date': '2011-08-08',
#       'astronomy': [{'sunrise': '05:41 AM',
#         'sunset': '07:19 PM',
#         'moonrise': '03:31 PM',
#         'moonset': '12:41 AM',
#         'moon_phase': 'Waxing Crescent',
# ...
#         'moon_illumination': '98'}],
#       'maxtempC': '20',
#       'maxtempF': '68',
#       'mintempC': '11',
#       'mintempF': '52',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '20',
#         'tempF': '68',
#         'windspeedMiles': '5',
#         'windspeedKmph': '8',
#         'winddirDegree': '252',
#         'winddir16Point': 'WSW',
#         'weatherCode': '353',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Light rain shower'}],
#         'precipMM': '2.4',
#         'humidity': '88',
#         'visibility': '10',
#         'pressure': '1020',
#         'cloudcover': '72',
#         'HeatIndexC': '15',
#         'HeatIndexF': '59',
#         'DewPointC': '13',
#         'DewPointF': '55',
#         'WindChillC': '15',
#         'WindChillF': '59',
#         'WindGustMiles': '8',
#         'WindGustKmph': '13',
#         'FeelsLikeC': '15',
#         'FeelsLikeF': '59'}]},
#      {'date': '2011-09-19',
#       'astronomy': [{'sunrise': '05:56 AM',
#         'sunset': '06:16 PM',
#         'moonrise': '10:08 PM',
#         'moonset': '01:11 PM',
#         'moon_phase': 'Full Moon',
#         'moon_illumination': '98'}],
#       'maxtempC': '23',
#       'maxtempF': '73',
#       'mintempC': '12',
#       'mintempF': '53',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '23',
#         'tempF': '73',
#         'windspeedMiles': '4',
#         'windspeedKmph': '7',
#         'winddirDegree': '38',
#         'winddir16Point': 'NE',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '68',
#         'visibility': '9',
#         'pressure': '1021',
#         'cloudcover': '31',
#         'HeatIndexC': '17',
#         'HeatIndexF': '63',
#         'DewPointC': '10',
#         'DewPointF': '49',
#         'WindChillC': '17',
#         'WindChillF': '62',
#         'WindGustMiles': '7',
#         'WindGustKmph': '11',
#         'FeelsLikeC': '17',
#         'FeelsLikeF': '62'}]},
#      {'date': '2011-09-20',
#       'astronomy': [{'sunrise': '05:57 AM',
#         'sunset': '06:14 PM',
#         'moonrise': '11:06 PM',
#         'moonset': '01:59 PM',
#         'moon_phase': 'Full Moon',
#         'moon_illumination': '98'}],
#       'maxtempC': '27',
#       'maxtempF': '81',
#       'mintempC': '13',
#       'mintempF': '55',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '27',
#         'tempF': '81',
#         'windspeedMiles': '3',
#         'windspeedKmph': '5',
#         'winddirDegree': '229',
#         'winddir16Point': 'SW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '55',
#         'visibility': '10',
#         'pressure': '1018',
#         'cloudcover': '0',
#         'HeatIndexC': '18',
#         'HeatIndexF': '64',
#         'DewPointC': '8',
#         'DewPointF': '47',
#         'WindChillC': '18',
#         'WindChillF': '64',
#         'WindGustMiles': '6',
#         'WindGustKmph': '10',
#         'FeelsLikeC': '18',
#         'FeelsLikeF': '64'}]},
#      {'date': '2011-09-21',
#       'astronomy': [{'sunrise': '05:58 AM',
#         'sunset': '06:12 PM',
#         'moonrise': 'No moonrise',
#         'moonset': '02:42 PM',
#         'moon_phase': 'Waning Gibbous',
#         'moon_illumination': '97'}],
#       'maxtempC': '29',
#       'maxtempF': '84',
#       'mintempC': '14',
#       'mintempF': '58',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '29',
#         'tempF': '84',
#         'windspeedMiles': '4',
#         'windspeedKmph': '6',
#         'winddirDegree': '213',
#         'winddir16Point': 'SSW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '58',
#         'visibility': '10',
#         'pressure': '1016',
#         'cloudcover': '23',
#         'HeatIndexC': '20',
#         'HeatIndexF': '67',
#         'DewPointC': '10',
#         'DewPointF': '51',
#         'WindChillC': '20',
#         'WindChillF': '68',
#         'WindGustMiles': '6',
#         'WindGustKmph': '9',
#         'FeelsLikeC': '20',
#         'FeelsLikeF': '68'}]},
#      {'date': '2011-09-22',
#       'astronomy': [{'sunrise': '05:59 AM',
#         'sunset': '06:10 PM',
#         'moonrise': '12:11 AM',
#         'moonset': '03:20 PM',
#         'moon_phase': 'Waning Gibbous',
#         'moon_illumination': '90'}],
#       'maxtempC': '27',
#       'maxtempF': '80',
#       'mintempC': '15',
#       'mintempF': '58',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '27',
#         'tempF': '80',
#         'windspeedMiles': '4',
#         'windspeedKmph': '7',
#         'winddirDegree': '216',
#         'winddir16Point': 'SW',
#         'weatherCode': '116',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#         'weatherDesc': [{'value': 'Partly cloudy'}],
#         'precipMM': '0.0',
#         'humidity': '76',
#         'visibility': '10',
#         'pressure': '1016',
#         'cloudcover': '18',
#         'HeatIndexC': '20',
#         'HeatIndexF': '68',
#         'DewPointC': '15',
#         'DewPointF': '59',
#         'WindChillC': '20',
#         'WindChillF': '67',
#         'WindGustMiles': '7',
#         'WindGustKmph': '11',
#         'FeelsLikeC': '20',
#         'FeelsLikeF': '67'}]},
#      {'date': '2011-09-23',
#       'astronomy': [{'sunrise': '06:01 AM',
#         'sunset': '06:08 PM',
#         'moonrise': '01:22 AM',
#         'moonset': '03:52 PM',
#         'moon_phase': 'Waning Gibbous',
#         'moon_illumination': '83'}],
#       'maxtempC': '28',
#       'maxtempF': '83',
#       'mintempC': '16',
#       'mintempF': '62',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '28',
#         'tempF': '83',
#         'windspeedMiles': '5',
#         'windspeedKmph': '8',
#         'winddirDegree': '227',
#         'winddir16Point': 'SW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.1',
#         'humidity': '78',
#         'visibility': '8',
#         'pressure': '1015',
#         'cloudcover': '23',
#         'HeatIndexC': '21',
#         'HeatIndexF': '70',
#         'DewPointC': '16',
#         'DewPointF': '60',
#         'WindChillC': '20',
#         'WindChillF': '69',
#         'WindGustMiles': '7',
#         'WindGustKmph': '12',
#         'FeelsLikeC': '20',
#         'FeelsLikeF': '69'}]},
#      {'date': '2011-09-24',
#       'astronomy': [{'sunrise': '06:02 AM',
#         'sunset': '06:06 PM',
#         'moonrise': '02:36 AM',
#         'moonset': '04:22 PM',
#         'moon_phase': 'Waning Gibbous',
#         'moon_illumination': '76'}],
#       'maxtempC': '28',
#       'maxtempF': '82',
#       'mintempC': '14',
#       'mintempF': '58',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '28',
#         'tempF': '82',
#         'windspeedMiles': '6',
#         'windspeedKmph': '9',
#         'winddirDegree': '216',
#         'winddir16Point': 'SW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '63',
#         'visibility': '10',
#         'pressure': '1009',
#         'cloudcover': '11',
#         'HeatIndexC': '20',
#         'HeatIndexF': '68',
#         'DewPointC': '12',
#         'DewPointF': '53',
#         'WindChillC': '20',
#         'WindChillF': '67',
#         'WindGustMiles': '8',
#         'WindGustKmph': '13',
#         'FeelsLikeC': '20',
#         'FeelsLikeF': '67'}]},
#      {'date': '2011-09-25',
#       'astronomy': [{'sunrise': '06:03 AM',
#         'sunset': '06:05 PM',
#         'moonrise': '03:53 AM',
#         'moonset': '04:50 PM',
#         'moon_phase': 'Last Quarter',
#         'moon_illumination': '69'}],
#       'maxtempC': '16',
#       'maxtempF': '61',
#       'mintempC': '13',
#       'mintempF': '55',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '16',
#         'tempF': '61',
#         'windspeedMiles': '11',
#         'windspeedKmph': '17',
#         'winddirDegree': '232',
#         'winddir16Point': 'SW',
#         'weatherCode': '353',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#         'weatherDesc': [{'value': 'Light rain shower'}],
#         'precipMM': '5.5',
#         'humidity': '82',
#         'visibility': '8',
#         'pressure': '1012',
#         'cloudcover': '48',
#         'HeatIndexC': '14',
#         'HeatIndexF': '56',
#         'DewPointC': '10',
#         'DewPointF': '51',
#         'WindChillC': '13',
#         'WindChillF': '55',
#         'WindGustMiles': '16',
#         'WindGustKmph': '26',
#         'FeelsLikeC': '13',
#         'FeelsLikeF': '55'}]},
#      {'date': '2011-09-26',
#       'astronomy': [{'sunrise': '06:04 AM',
#         'sunset': '06:03 PM',
#         'moonrise': '05:12 AM',
#         'moonset': '05:19 PM',
#         'moon_phase': 'Last Quarter',
#         'moon_illumination': '62'}],
#       'maxtempC': '20',
#       'maxtempF': '68',
#       'mintempC': '10',
#       'mintempF': '50',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '20',
#         'tempF': '68',
#         'windspeedMiles': '12',
#         'windspeedKmph': '19',
#         'winddirDegree': '207',
#         'winddir16Point': 'SSW',
#         'weatherCode': '266',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0017_cloudy_with_light_rain.png'}],
#         'weatherDesc': [{'value': 'Light drizzle'}],
#         'precipMM': '9.3',
#         'humidity': '79',
#         'visibility': '7',
#         'pressure': '1014',
#         'cloudcover': '72',
#         'HeatIndexC': '14',
#         'HeatIndexF': '58',
#         'DewPointC': '10',
#         'DewPointF': '51',
#         'WindChillC': '14',
#         'WindChillF': '57',
#         'WindGustMiles': '16',
#         'WindGustKmph': '26',
#         'FeelsLikeC': '14',
#         'FeelsLikeF': '57'}]},
#      {'date': '2011-09-27',
#       'astronomy': [{'sunrise': '06:05 AM',
#         'sunset': '06:01 PM',
#         'moonrise': '06:32 AM',
#         'moonset': '05:49 PM',
#         'moon_phase': 'Last Quarter',
#         'moon_illumination': '55'}],
#       'maxtempC': '20',
#       'maxtempF': '67',
#       'mintempC': '13',
#       'mintempF': '55',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '20',
#         'tempF': '67',
#         'windspeedMiles': '7',
#         'windspeedKmph': '12',
#         'winddirDegree': '268',
#         'winddir16Point': 'W',
#         'weatherCode': '116',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#         'weatherDesc': [{'value': 'Partly cloudy'}],
#         'precipMM': '0.4',
#         'humidity': '78',
#         'visibility': '8',
#         'pressure': '1021',
#         'cloudcover': '42',
#         'HeatIndexC': '15',
#         'HeatIndexF': '59',
#         'DewPointC': '10',
#         'DewPointF': '51',
#         'WindChillC': '14',
#         'WindChillF': '58',
#         'WindGustMiles': '10',
#         'WindGustKmph': '17',
#         'FeelsLikeC': '14',
#         'FeelsLikeF': '58'}]},
#      {'date': '2011-09-28',
#       'astronomy': [{'sunrise': '06:07 AM',
#         'sunset': '05:59 PM',
#         'moonrise': '07:53 AM',
#         'moonset': '06:22 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '48'}],
#       'maxtempC': '22',
#       'maxtempF': '71',
#       'mintempC': '7',
#       'mintempF': '45',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '22',
#         'tempF': '71',
#         'windspeedMiles': '9',
#         'windspeedKmph': '14',
#         'winddirDegree': '61',
#         'winddir16Point': 'ENE',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '61',
#         'visibility': '10',
#         'pressure': '1022',
#         'cloudcover': '6',
#         'HeatIndexC': '14',
#         'HeatIndexF': '57',
#         'DewPointC': '5',
#         'DewPointF': '41',
#         'WindChillC': '13',
#         'WindChillF': '55',
#         'WindGustMiles': '14',
#         'WindGustKmph': '22',
#         'FeelsLikeC': '13',
#         'FeelsLikeF': '55'}]},
#      {'date': '2011-09-29',
#       'astronomy': [{'sunrise': '06:08 AM',
#         'sunset': '05:57 PM',
#         'moonrise': '09:14 AM',
#         'moonset': '07:01 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '41'}],
#       'maxtempC': '27',
#       'maxtempF': '80',
#       'mintempC': '10',
#       'mintempF': '50',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '27',
#         'tempF': '80',
#         'windspeedMiles': '4',
#         'windspeedKmph': '6',
#         'winddirDegree': '188',
#         'winddir16Point': 'S',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '47',
#         'visibility': '10',
#         'pressure': '1014',
#         'cloudcover': '0',
#         'HeatIndexC': '16',
#         'HeatIndexF': '61',
#         'DewPointC': '4',
#         'DewPointF': '39',
#         'WindChillC': '16',
#         'WindChillF': '60',
#         'WindGustMiles': '6',
#         'WindGustKmph': '10',
#         'FeelsLikeC': '16',
#         'FeelsLikeF': '60'}]},
#      {'date': '2011-09-30',
#       'astronomy': [{'sunrise': '06:09 AM',
#         'sunset': '05:55 PM',
#         'moonrise': '10:30 AM',
#         'moonset': '07:46 PM',
#         'moon_phase': 'Waning Crescent',
#         'moon_illumination': '34'}],
#       'maxtempC': '21',
#       'maxtempF': '70',
#       'mintempC': '10',
#       'mintempF': '50',
#       'totalSnow_cm': '0.0',
#       'sunHour': '0.0',
#       'uvIndex': '0',
#       'hourly': [{'time': '24',
#         'tempC': '21',
#         'tempF': '70',
#         'windspeedMiles': '6',
#         'windspeedKmph': '10',
#         'winddirDegree': '233',
#         'winddir16Point': 'SW',
#         'weatherCode': '113',
#         'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#         'weatherDesc': [{'value': 'Sunny'}],
#         'precipMM': '0.0',
#         'humidity': '70',
#         'visibility': '10',
#         'pressure': '1013',
#         'cloudcover': '13',
#         'HeatIndexC': '15',
#         'HeatIndexF': '59',
#         'DewPointC': '9',
#         'DewPointF': '48',
#         'WindChillC': '14',
#         'WindChillF': '57',
#         'WindGustMiles': '9',
#         'WindGustKmph': '15',
#         'FeelsLikeC': '14',
#         'FeelsLikeF': '57'}]}]}}]]

# %%
weather_response[0][0]["data"]["weather"][29]["hourly"][0]["tempF"]

#weather_response[0 through 22 unique location][month # 0 through 2]["data"]["weather"][day 0 through 29]["hourly"][0]["tempF"]
# Out:
# '89'

# %%
temp_list = []
x=0
y=0

for w in weather_response:
    temp_data = weather_response[x][0]["data"]["weather"]
    temp_day = temp_data[0]["hourly"][y]["tempF"]
    print(temp_day)
    
        
  #  x +=1
 #   temp_list.append(temp_set)
    
    
  #  temp_set = weather_response[0][1]["data"]["weather"][0]["hourly"][0]["tempF"]
 #   x +=1
# Out:
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96
# 96

# %%
temp_list
# Out:
# ['96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96',
#  '96']

# %%
#type(file[["longitude", "latitude"]])
#winery_coords = file[["longitude", "latitude"]]
#type(unique_locations.iloc[1,1])

# %%
#latitude_float = [float(x) for x in winery_coords["latitude"]]

#winery_coords["latitude"] = latitude_float

#type(winery_coords.iloc[1,1])

# %%
# Loop through wineries and append weather lists


for index, row in unique_locations.iterrows():
#    try:
        if row["Latitude"] < 0:
            latit = (row["Latitude"])
            longi = (row["Longitude"])
        
 # Run a request to endpoint and convert result to json
            jul_weather = requests.get(f"{weather_url}{lat},{lng}&key={weather_api}&date=2011-07-01&enddate=2011-07-31&tp=24&format=json").json()
            aug_weather = requests.get(f"{weather_url}{lat},{lng}&key={weather_api}&date=2011-08-01&enddate=2011-08-31&tp=24&format=json").json()
            sep_weather = requests.get(f"{weather_url}{lat},{lng}&key={weather_api}&date=2011-09-01&enddate=2011-09-30&tp=24&format=json").json()
            
            # Northern hemisphere growing season weather lists
            
            weather_response = []
            
            weather_response.append(jul_weather)
            weather_response.append(aug_weather)
            weather_response.append(sep_weather)
               
            fahrenheit = []
            x = 0
                for w in weather_response:
                fahrenheit.append(weather_response[x]["hourly"][0]["tempF"])
                x += 1

                tempdf = pd.DataFrame([fahrenheit])
                tempdf.T.mean()

            precip = []
            x = 0
            for p in weather_response:
            precip.append(weather_response[x]["hourly"][0]["precipMM"])
            x += 1
            
                precipdf = pd.DataFrame([precip])
                precipdf.T.mean()

            precipdf = pd.DataFrame([precip])
            precipdf.T.mean()

            
        else:
#            try:
                latit = (row["latitude"])
                longi = (row["longitude"])

                jan_weather = requests.get(f"{weather_url}{lat},{lng}&key={weather_api}&date=2011-01-01&enddate=2011-01-31&tp=24&format=json").json()
                feb_weather = requests.get(f"{weather_url}{lat},{lng}&key={weather_api}&date=2011-02-01&enddate=2011-02-28&tp=24&format=json").json()
                mar_weather = requests.get(f"{weather_url}{lat},{lng}&key={weather_api}&date=2011-03-01&enddate=2011-03-31&tp=24&format=json").json()
                
                # Southern hemisphere growing season weather lists
                jan = []
                feb = []
                mar = []
                
                jan.append(jul_weather)
                feb.append(aug_weather)
                mar.append(sep_weather)

                fahrenheit = []

                x = 0
                for w in testweather:
                fahrenheit.append(testweather[x]["hourly"][0]["tempF"])
                x += 1

                tempdf = pd.DataFrame([fahrenheit])
                tempdf.T.mean()

                precip = []
                x = 0
                for p in testweather:
                precip.append(testweather[x]["hourly"][0]["precipMM"])
                x += 1

                precipdf = pd.DataFrame([precip])
                precipdf.T.mean()

# %%
# Create winery symbol layer
winery_layer = gmaps.marker_layer(unique_locations)


fig = gmaps.figure()
fig.add_layer(winery_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
import numpy as np

test = requests.get(f"{weather_url}38.936866,-77.038317&key={weather_api}&date=2019-01-01&enddate=2019-01-15&tp=24&format=json").json()
pprint(test)
# Out:
# {'data': {'request': [{'query': 'Lat 38.94 and Lon -77.04', 'type': 'LatLon'}],
#           'weather': [{'astronomy': [{'moon_illumination': '34',
#                                       'moon_phase': 'Waning Crescent',
#                                       'moonrise': '03:09 AM',
#                                       'moonset': '02:03 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '04:57 PM'}],
#                        'date': '2019-01-01',
#                        'hourly': [{'DewPointC': '7',
#                                    'DewPointF': '44',
#                                    'FeelsLikeC': '11',
#                                    'FeelsLikeF': '52',
#                                    'HeatIndexC': '12',
#                                    'HeatIndexF': '53',
#                                    'WindChillC': '11',
#                                    'WindChillF': '52',
#                                    'WindGustKmph': '29',
#                                    'WindGustMiles': '18',
#                                    'cloudcover': '42',
#                                    'humidity': '72',
#                                    'precipMM': '2.0',
#                                    'pressure': '1015',
#                                    'tempC': '13',
#                                    'tempF': '56',
#                                    'time': '24',
#                                    'visibility': '10',
#                                    'weatherCode': '119',
#                                    'weatherDesc': [{'value': 'Cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#                                    'winddir16Point': 'WNW',
#                                    'winddirDegree': '303',
#                                    'windspeedKmph': '13',
#                                    'windspeedMiles': '8'}],
#                        'maxtempC': '13',
#                        'maxtempF': '56',
#                        'mintempC': '11',
#                        'mintempF': '52',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '28',
#                                       'moon_phase': 'Waning Crescent',
#                                       'moonrise': '04:10 AM',
#                                       'moonset': '02:39 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '04:57 PM'}],
#                        'date': '2019-01-02',
#                        'hourly': [{'DewPointC': '-1',
#                                    'DewPointF': '31',
#                                    'FeelsLikeC': '2',
#                                    'FeelsLikeF': '36',
#                                    'HeatIndexC': '3',
#                                    'HeatIndexF': '37',
#                                    'WindChillC': '2',
#                                    'WindChillF': '36',
#                                    'WindGustKmph': '12',
#                                    'WindGustMiles': '7',
#                                    'cloudcover': '72',
#                                    'humidity': '70',
#                                    'precipMM': '0.0',
#                                    'pressure': '1024',
#                                    'tempC': '5',
#                                    'tempF': '41',
#                                    'time': '24',
#                                    'visibility': '10',
#                                    'weatherCode': '122',
#                                    'weatherDesc': [{'value': 'Overcast'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#                                    'winddir16Point': 'SE',
#                                    'winddirDegree': '124',
#                                    'windspeedKmph': '4',
#                                    'windspeedMiles': '3'}],
#                        'maxtempC': '5',
#                        'maxtempF': '41',
#                        'mintempC': '2',
#                        'mintempF': '36',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '21',
#                                       'moon_phase': 'Waning Crescent',
#                                       'moonrise': '05:11 AM',
#                                       'moonset': '03:19 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '04:58 PM'}],
#                        'date': '2019-01-03',
#                        'hourly': [{'DewPointC': '-2',
#                                    'DewPointF': '29',
#                                    'FeelsLikeC': '3',
#                                    'FeelsLikeF': '37',
#                                    'HeatIndexC': '3',
#                                    'HeatIndexF': '38',
#                                    'WindChillC': '3',
#                                    'WindChillF': '37',
#                                    'WindGustKmph': '15',
#                                    'WindGustMiles': '9',
#                                    'cloudcover': '69',
#                                    'humidity': '69',
#                                    'precipMM': '1.8',
#                                    'pressure': '1019',
#                                    'tempC': '5',
#                                    'tempF': '41',
#                                    'time': '24',
#                                    'visibility': '8',
#                                    'weatherCode': '119',
#                                    'weatherDesc': [{'value': 'Cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#                                    'winddir16Point': 'NW',
#                                    'winddirDegree': '309',
#                                    'windspeedKmph': '6',
#                                    'windspeedMiles': '4'}],
#                        'maxtempC': '5',
#                        'maxtempF': '41',
#                        'mintempC': '2',
#                        'mintempF': '36',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '14',
#                                       'moon_phase': 'Waning Crescent',
#                                       'moonrise': '06:08 AM',
#                                       'moonset': '04:02 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '04:59 PM'}],
#                        'date': '2019-01-04',
#                        'hourly': [{'DewPointC': '-1',
#                                    'DewPointF': '30',
#                                    'FeelsLikeC': '2',
#                                    'FeelsLikeF': '35',
#                                    'HeatIndexC': '4',
#                                    'HeatIndexF': '38',
#                                    'WindChillC': '2',
#                                    'WindChillF': '35',
#                                    'WindGustKmph': '9',
#                                    'WindGustMiles': '6',
#                                    'cloudcover': '64',
#                                    'humidity': '73',
#                                    'precipMM': '1.0',
#                                    'pressure': '1009',
#                                    'tempC': '6',
#                                    'tempF': '43',
#                                    'time': '24',
#                                    'visibility': '8',
#                                    'weatherCode': '122',
#                                    'weatherDesc': [{'value': 'Overcast'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#                                    'winddir16Point': 'S',
#                                    'winddirDegree': '182',
#                                    'windspeedKmph': '10',
#                                    'windspeedMiles': '7'}],
#                        'maxtempC': '6',
#                        'maxtempF': '43',
#                        'mintempC': '0',
#                        'mintempF': '32',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '7',
#                                       'moon_phase': 'Waning Crescent',
#                                       'moonrise': '07:01 AM',
#                                       'moonset': '04:51 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '05:00 PM'}],
#                        'date': '2019-01-05',
#                        'hourly': [{'DewPointC': '1',
#                                    'DewPointF': '34',
#                                    'FeelsLikeC': '4',
#                                    'FeelsLikeF': '39',
#                                    'HeatIndexC': '6',
#                                    'HeatIndexF': '43',
#                                    'WindChillC': '4',
#                                    'WindChillF': '39',
#                                    'WindGustKmph': '23',
#                                    'WindGustMiles': '14',
#                                    'cloudcover': '62',
#                                    'humidity': '70',
#                                    'precipMM': '6.5',
#                                    'pressure': '1007',
#                                    'tempC': '9',
#                                    'tempF': '49',
#                                    'time': '24',
#                                    'visibility': '8',
#                                    'weatherCode': '266',
#                                    'weatherDesc': [{'value': 'Light drizzle'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0017_cloudy_with_light_rain.png'}],
#                                    'winddir16Point': 'NW',
#                                    'winddirDegree': '305',
#                                    'windspeedKmph': '12',
#                                    'windspeedMiles': '8'}],
#                        'maxtempC': '9',
#                        'maxtempF': '49',
#                        'mintempC': '3',
#                        'mintempF': '38',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '0',
#                                       'moon_phase': 'New Moon',
#                                       'moonrise': '07:50 AM',
#                                       'moonset': '05:43 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '05:01 PM'}],
#                        'date': '2019-01-06',
#                        'hourly': [{'DewPointC': '-1',
#                                    'DewPointF': '30',
#                                    'FeelsLikeC': '3',
#                                    'FeelsLikeF': '38',
#                                    'HeatIndexC': '5',
#                                    'HeatIndexF': '41',
#                                    'WindChillC': '3',
#                                    'WindChillF': '38',
#                                    'WindGustKmph': '22',
#                                    'WindGustMiles': '14',
#                                    'cloudcover': '12',
#                                    'humidity': '63',
#                                    'precipMM': '0.0',
#                                    'pressure': '1020',
#                                    'tempC': '8',
#                                    'tempF': '47',
#                                    'time': '24',
#                                    'visibility': '10',
#                                    'weatherCode': '116',
#                                    'weatherDesc': [{'value': 'Partly cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#                                    'winddir16Point': 'NW',
#                                    'winddirDegree': '314',
#                                    'windspeedKmph': '10',
#                                    'windspeedMiles': '7'}],
#                        'maxtempC': '8',
#                        'maxtempF': '47',
#                        'mintempC': '3',
#                        'mintempF': '38',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '0',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '08:33 AM',
#                                       'moonset': '06:37 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '05:02 PM'}],
#                        'date': '2019-01-07',
#                        'hourly': [{'DewPointC': '-4',
#                                    'DewPointF': '24',
#                                    'FeelsLikeC': '-1',
#                                    'FeelsLikeF': '30',
#                                    'HeatIndexC': '1',
#                                    'HeatIndexF': '34',
#                                    'WindChillC': '-1',
#                                    'WindChillF': '30',
#                                    'WindGustKmph': '15',
#                                    'WindGustMiles': '9',
#                                    'cloudcover': '57',
#                                    'humidity': '63',
#                                    'precipMM': '0.0',
#                                    'pressure': '1027',
#                                    'tempC': '2',
#                                    'tempF': '36',
#                                    'time': '24',
#                                    'visibility': '10',
#                                    'weatherCode': '119',
#                                    'weatherDesc': [{'value': 'Cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#                                    'winddir16Point': 'ESE',
#                                    'winddirDegree': '119',
#                                    'windspeedKmph': '8',
#                                    'windspeedMiles': '5'}],
#                        'maxtempC': '2',
#                        'maxtempF': '36',
#                        'mintempC': '-2',
#                        'mintempF': '29',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '7',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '09:12 AM',
#                                       'moonset': '07:33 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '05:03 PM'}],
#                        'date': '2019-01-08',
#                        'hourly': [{'DewPointC': '5',
#                                    'DewPointF': '41',
#                                    'FeelsLikeC': '8',
#                                    'FeelsLikeF': '46',
#                                    'HeatIndexC': '9',
#                                    'HeatIndexF': '48',
#                                    'WindChillC': '8',
#                                    'WindChillF': '46',
#                                    'WindGustKmph': '22',
#                                    'WindGustMiles': '14',
#                                    'cloudcover': '68',
#                                    'humidity': '77',
#                                    'precipMM': '6.7',
#                                    'pressure': '1012',
#                                    'tempC': '12',
#                                    'tempF': '54',
#                                    'time': '24',
#                                    'visibility': '9',
#                                    'weatherCode': '116',
#                                    'weatherDesc': [{'value': 'Partly cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#                                    'winddir16Point': 'SSW',
#                                    'winddirDegree': '209',
#                                    'windspeedKmph': '12',
#                                    'windspeedMiles': '7'}],
#                        'maxtempC': '12',
#                        'maxtempF': '54',
#                        'mintempC': '3',
#                        'mintempF': '38',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '14',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '09:46 AM',
#                                       'moonset': '08:29 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '05:04 PM'}],
#                        'date': '2019-01-09',
#                        'hourly': [{'DewPointC': '-5',
#                                    'DewPointF': '23',
#                                    'FeelsLikeC': '-1',
#                                    'FeelsLikeF': '31',
#                                    'HeatIndexC': '4',
#                                    'HeatIndexF': '39',
#                                    'WindChillC': '-1',
#                                    'WindChillF': '31',
#                                    'WindGustKmph': '33',
#                                    'WindGustMiles': '21',
#                                    'cloudcover': '56',
#                                    'humidity': '55',
#                                    'precipMM': '3.1',
#                                    'pressure': '1012',
#                                    'tempC': '5',
#                                    'tempF': '41',
#                                    'time': '24',
#                                    'visibility': '9',
#                                    'weatherCode': '317',
#                                    'weatherDesc': [{'value': 'Light sleet'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0021_cloudy_with_sleet.png'}],
#                                    'winddir16Point': 'WNW',
#                                    'winddirDegree': '297',
#                                    'windspeedKmph': '17',
#                                    'windspeedMiles': '11'}],
#                        'maxtempC': '5',
#                        'maxtempF': '41',
#                        'mintempC': '1',
#                        'mintempF': '34',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '21',
#                                       'moon_phase': 'Waxing Crescent',
#                                       'moonrise': '10:17 AM',
#                                       'moonset': '09:27 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '05:05 PM'}],
#                        'date': '2019-01-10',
#                        'hourly': [{'DewPointC': '-7',
#                                    'DewPointF': '19',
#                                    'FeelsLikeC': '-5',
#                                    'FeelsLikeF': '24',
#                                    'HeatIndexC': '0',
#                                    'HeatIndexF': '32',
#                                    'WindChillC': '-5',
#                                    'WindChillF': '24',
#                                    'WindGustKmph': '35',
#                                    'WindGustMiles': '22',
#                                    'cloudcover': '30',
#                                    'humidity': '54',
#                                    'precipMM': '0.0',
#                                    'pressure': '1019',
#                                    'tempC': '5',
#                                    'tempF': '41',
#                                    'time': '24',
#                                    'visibility': '10',
#                                    'weatherCode': '116',
#                                    'weatherDesc': [{'value': 'Partly cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#                                    'winddir16Point': 'NW',
#                                    'winddirDegree': '309',
#                                    'windspeedKmph': '17',
#                                    'windspeedMiles': '10'}],
#                        'maxtempC': '5',
#                        'maxtempF': '41',
#                        'mintempC': '-1',
#                        'mintempF': '31',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '28',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '10:45 AM',
#                                       'moonset': '10:23 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '05:06 PM'}],
#                        'date': '2019-01-11',
#                        'hourly': [{'DewPointC': '-9',
#                                    'DewPointF': '16',
#                                    'FeelsLikeC': '-3',
#                                    'FeelsLikeF': '27',
#                                    'HeatIndexC': '0',
#                                    'HeatIndexF': '32',
#                                    'WindChillC': '-3',
#                                    'WindChillF': '27',
#                                    'WindGustKmph': '21',
#                                    'WindGustMiles': '13',
#                                    'cloudcover': '9',
#                                    'humidity': '55',
#                                    'precipMM': '0.0',
#                                    'pressure': '1027',
#                                    'tempC': '4',
#                                    'tempF': '40',
#                                    'time': '24',
#                                    'visibility': '10',
#                                    'weatherCode': '116',
#                                    'weatherDesc': [{'value': 'Partly cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#                                    'winddir16Point': 'NW',
#                                    'winddirDegree': '319',
#                                    'windspeedKmph': '9',
#                                    'windspeedMiles': '6'}],
#                        'maxtempC': '4',
#                        'maxtempF': '40',
#                        'mintempC': '-1',
#                        'mintempF': '31',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '34',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '11:13 AM',
#                                       'moonset': '11:21 PM',
#                                       'sunrise': '07:27 AM',
#                                       'sunset': '05:07 PM'}],
#                        'date': '2019-01-12',
#                        'hourly': [{'DewPointC': '-9',
#                                    'DewPointF': '16',
#                                    'FeelsLikeC': '-2',
#                                    'FeelsLikeF': '28',
#                                    'HeatIndexC': '-2',
#                                    'HeatIndexF': '28',
#                                    'WindChillC': '-2',
#                                    'WindChillF': '28',
#                                    'WindGustKmph': '8',
#                                    'WindGustMiles': '5',
#                                    'cloudcover': '78',
#                                    'humidity': '60',
#                                    'precipMM': '2.9',
#                                    'pressure': '1032',
#                                    'tempC': '1',
#                                    'tempF': '34',
#                                    'time': '24',
#                                    'visibility': '8',
#                                    'weatherCode': '338',
#                                    'weatherDesc': [{'value': 'Heavy snow'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0020_cloudy_with_heavy_snow.png'}],
#                                    'winddir16Point': 'SSE',
#                                    'winddirDegree': '158',
#                                    'windspeedKmph': '4',
#                                    'windspeedMiles': '3'}],
#                        'maxtempC': '1',
#                        'maxtempF': '34',
#                        'mintempC': '-4',
#                        'mintempF': '25',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '2.5',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '41',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '11:41 AM',
#                                       'moonset': 'No moonset',
#                                       'sunrise': '07:26 AM',
#                                       'sunset': '05:08 PM'}],
#                        'date': '2019-01-13',
#                        'hourly': [{'DewPointC': '-5',
#                                    'DewPointF': '23',
#                                    'FeelsLikeC': '-3',
#                                    'FeelsLikeF': '26',
#                                    'HeatIndexC': '-1',
#                                    'HeatIndexF': '31',
#                                    'WindChillC': '-3',
#                                    'WindChillF': '26',
#                                    'WindGustKmph': '17',
#                                    'WindGustMiles': '10',
#                                    'cloudcover': '100',
#                                    'humidity': '73',
#                                    'precipMM': '21.0',
#                                    'pressure': '1024',
#                                    'tempC': '1',
#                                    'tempF': '34',
#                                    'time': '24',
#                                    'visibility': '2',
#                                    'weatherCode': '338',
#                                    'weatherDesc': [{'value': 'Heavy snow'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0020_cloudy_with_heavy_snow.png'}],
#                                    'winddir16Point': 'NE',
#                                    'winddirDegree': '48',
#                                    'windspeedKmph': '9',
#                                    'windspeedMiles': '6'}],
#                        'maxtempC': '1',
#                        'maxtempF': '34',
#                        'mintempC': '-4',
#                        'mintempF': '25',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '17.9',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '48',
#                                       'moon_phase': 'First Quarter',
#                                       'moonrise': '12:09 PM',
#                                       'moonset': '12:20 AM',
#                                       'sunrise': '07:26 AM',
#                                       'sunset': '05:09 PM'}],
#                        'date': '2019-01-14',
#                        'hourly': [{'DewPointC': '-8',
#                                    'DewPointF': '17',
#                                    'FeelsLikeC': '-4',
#                                    'FeelsLikeF': '24',
#                                    'HeatIndexC': '-3',
#                                    'HeatIndexF': '28',
#                                    'WindChillC': '-4',
#                                    'WindChillF': '24',
#                                    'WindGustKmph': '11',
#                                    'WindGustMiles': '7',
#                                    'cloudcover': '43',
#                                    'humidity': '65',
#                                    'precipMM': '2.1',
#                                    'pressure': '1024',
#                                    'tempC': '1',
#                                    'tempF': '34',
#                                    'time': '24',
#                                    'visibility': '9',
#                                    'weatherCode': '116',
#                                    'weatherDesc': [{'value': 'Partly cloudy'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#                                    'winddir16Point': 'SW',
#                                    'winddirDegree': '216',
#                                    'windspeedKmph': '7',
#                                    'windspeedMiles': '4'}],
#                        'maxtempC': '1',
#                        'maxtempF': '34',
#                        'mintempC': '-4',
#                        'mintempF': '25',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'},
#                       {'astronomy': [{'moon_illumination': '55',
#                                       'moon_phase': 'Waxing Gibbous',
#                                       'moonrise': '12:40 PM',
#                                       'moonset': '01:21 AM',
#                                       'sunrise': '07:26 AM',
#                                       'sunset': '05:10 PM'}],
#                        'date': '2019-01-15',
#                        'hourly': [{'DewPointC': '-6',
#                                    'DewPointF': '21',
#                                    'FeelsLikeC': '-4',
#                                    'FeelsLikeF': '25',
#                                    'HeatIndexC': '-2',
#                                    'HeatIndexF': '29',
#                                    'WindChillC': '-4',
#                                    'WindChillF': '25',
#                                    'WindGustKmph': '14',
#                                    'WindGustMiles': '9',
#                                    'cloudcover': '11',
#                                    'humidity': '71',
#                                    'precipMM': '0.0',
#                                    'pressure': '1022',
#                                    'tempC': '2',
#                                    'tempF': '36',
#                                    'time': '24',
#                                    'visibility': '9',
#                                    'weatherCode': '143',
#                                    'weatherDesc': [{'value': 'Mist'}],
#                                    'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0006_mist.png'}],
#                                    'winddir16Point': 'WNW',
#                                    'winddirDegree': '298',
#                                    'windspeedKmph': '7',
#                                    'windspeedMiles': '5'}],
#                        'maxtempC': '2',
#                        'maxtempF': '36',
#                        'mintempC': '-5',
#                        'mintempF': '23',
#                        'sunHour': '0.0',
#                        'totalSnow_cm': '0.0',
#                        'uvIndex': '0'}]}}

# %%
test["data"]["request"]
# Out:
# [{'type': 'LatLon', 'query': 'Lat 38.94 and Lon -77.04'}]

# %%
testweather = test["data"]["weather"]
testweather
# Out:
# [{'date': '2019-01-01',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '04:57 PM',
#     'moonrise': '03:09 AM',
#     'moonset': '02:03 PM',
#     'moon_phase': 'Waning Crescent',
#     'moon_illumination': '34'}],
#   'maxtempC': '13',
#   'maxtempF': '56',
#   'mintempC': '11',
#   'mintempF': '52',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '13',
#     'tempF': '56',
#     'windspeedMiles': '8',
#     'windspeedKmph': '13',
#     'winddirDegree': '303',
#     'winddir16Point': 'WNW',
#     'weatherCode': '119',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#     'weatherDesc': [{'value': 'Cloudy'}],
#     'precipMM': '2.0',
#     'humidity': '72',
#     'visibility': '10',
#     'pressure': '1015',
#     'cloudcover': '42',
#     'HeatIndexC': '12',
#     'HeatIndexF': '53',
#     'DewPointC': '7',
#     'DewPointF': '44',
#     'WindChillC': '11',
#     'WindChillF': '52',
#     'WindGustMiles': '18',
#     'WindGustKmph': '29',
#     'FeelsLikeC': '11',
#     'FeelsLikeF': '52'}]},
#  {'date': '2019-01-02',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '04:57 PM',
#     'moonrise': '04:10 AM',
#     'moonset': '02:39 PM',
#     'moon_phase': 'Waning Crescent',
#     'moon_illumination': '28'}],
#   'maxtempC': '5',
#   'maxtempF': '41',
#   'mintempC': '2',
#   'mintempF': '36',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '5',
#     'tempF': '41',
#     'windspeedMiles': '3',
#     'windspeedKmph': '4',
#     'winddirDegree': '124',
#     'winddir16Point': 'SE',
#     'weatherCode': '122',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#     'weatherDesc': [{'value': 'Overcast'}],
#     'precipMM': '0.0',
#     'humidity': '70',
#     'visibility': '10',
#     'pressure': '1024',
#     'cloudcover': '72',
#     'HeatIndexC': '3',
#     'HeatIndexF': '37',
#     'DewPointC': '-1',
#     'DewPointF': '31',
#     'WindChillC': '2',
#     'WindChillF': '36',
#     'WindGustMiles': '7',
#     'WindGustKmph': '12',
#     'FeelsLikeC': '2',
#     'FeelsLikeF': '36'}]},
#  {'date': '2019-01-03',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '04:58 PM',
#     'moonrise': '05:11 AM',
#     'moonset': '03:19 PM',
#     'moon_phase': 'Waning Crescent',
#     'moon_illumination': '21'}],
#   'maxtempC': '5',
#   'maxtempF': '41',
#   'mintempC': '2',
#   'mintempF': '36',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '5',
#     'tempF': '41',
#     'windspeedMiles': '4',
#     'windspeedKmph': '6',
#     'winddirDegree': '309',
#     'winddir16Point': 'NW',
#     'weatherCode': '119',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#     'weatherDesc': [{'value': 'Cloudy'}],
#     'precipMM': '1.8',
#     'humidity': '69',
#     'visibility': '8',
#     'pressure': '1019',
#     'cloudcover': '69',
#     'HeatIndexC': '3',
#     'HeatIndexF': '38',
#     'DewPointC': '-2',
#     'DewPointF': '29',
#     'WindChillC': '3',
#     'WindChillF': '37',
#     'WindGustMiles': '9',
#     'WindGustKmph': '15',
#     'FeelsLikeC': '3',
#     'FeelsLikeF': '37'}]},
#  {'date': '2019-01-04',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '04:59 PM',
#     'moonrise': '06:08 AM',
#     'moonset': '04:02 PM',
#     'moon_phase': 'Waning Crescent',
#     'moon_illumination': '14'}],
#   'maxtempC': '6',
#   'maxtempF': '43',
#   'mintempC': '0',
#   'mintempF': '32',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '6',
#     'tempF': '43',
#     'windspeedMiles': '7',
#     'windspeedKmph': '10',
#     'winddirDegree': '182',
#     'winddir16Point': 'S',
#     'weatherCode': '122',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#     'weatherDesc': [{'value': 'Overcast'}],
#     'precipMM': '1.0',
#     'humidity': '73',
#     'visibility': '8',
#     'pressure': '1009',
#     'cloudcover': '64',
#     'HeatIndexC': '4',
#     'HeatIndexF': '38',
#     'DewPointC': '-1',
#     'DewPointF': '30',
#     'WindChillC': '2',
#     'WindChillF': '35',
#     'WindGustMiles': '6',
#     'WindGustKmph': '9',
#     'FeelsLikeC': '2',
#     'FeelsLikeF': '35'}]},
#  {'date': '2019-01-05',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '05:00 PM',
#     'moonrise': '07:01 AM',
#     'moonset': '04:51 PM',
#     'moon_phase': 'Waning Crescent',
#     'moon_illumination': '7'}],
#   'maxtempC': '9',
#   'maxtempF': '49',
#   'mintempC': '3',
#   'mintempF': '38',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '9',
#     'tempF': '49',
#     'windspeedMiles': '8',
#     'windspeedKmph': '12',
#     'winddirDegree': '305',
#     'winddir16Point': 'NW',
#     'weatherCode': '266',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0017_cloudy_with_light_rain.png'}],
#     'weatherDesc': [{'value': 'Light drizzle'}],
#     'precipMM': '6.5',
#     'humidity': '70',
#     'visibility': '8',
#     'pressure': '1007',
#     'cloudcover': '62',
#     'HeatIndexC': '6',
#     'HeatIndexF': '43',
#     'DewPointC': '1',
#     'DewPointF': '34',
#     'WindChillC': '4',
#     'WindChillF': '39',
#     'WindGustMiles': '14',
#     'WindGustKmph': '23',
#     'FeelsLikeC': '4',
#     'FeelsLikeF': '39'}]},
#  {'date': '2019-01-06',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '05:01 PM',
#     'moonrise': '07:50 AM',
#     'moonset': '05:43 PM',
#     'moon_phase': 'New Moon',
#     'moon_illumination': '0'}],
#   'maxtempC': '8',
#   'maxtempF': '47',
#   'mintempC': '3',
#   'mintempF': '38',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '8',
#     'tempF': '47',
#     'windspeedMiles': '7',
#     'windspeedKmph': '10',
#     'winddirDegree': '314',
#     'winddir16Point': 'NW',
#     'weatherCode': '116',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#     'weatherDesc': [{'value': 'Partly cloudy'}],
#     'precipMM': '0.0',
#     'humidity': '63',
#     'visibility': '10',
#     'pressure': '1020',
#     'cloudcover': '12',
#     'HeatIndexC': '5',
#     'HeatIndexF': '41',
#     'DewPointC': '-1',
#     'DewPointF': '30',
#     'WindChillC': '3',
#     'WindChillF': '38',
#     'WindGustMiles': '14',
#     'WindGustKmph': '22',
#     'FeelsLikeC': '3',
#     'FeelsLikeF': '38'}]},
#  {'date': '2019-01-07',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '05:02 PM',
#     'moonrise': '08:33 AM',
#     'moonset': '06:37 PM',
#     'moon_phase': 'Waxing Crescent',
#     'moon_illumination': '0'}],
#   'maxtempC': '2',
#   'maxtempF': '36',
#   'mintempC': '-2',
#   'mintempF': '29',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '2',
#     'tempF': '36',
#     'windspeedMiles': '5',
#     'windspeedKmph': '8',
#     'winddirDegree': '119',
#     'winddir16Point': 'ESE',
#     'weatherCode': '119',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#     'weatherDesc': [{'value': 'Cloudy'}],
#     'precipMM': '0.0',
#     'humidity': '63',
#     'visibility': '10',
#     'pressure': '1027',
#     'cloudcover': '57',
#     'HeatIndexC': '1',
#     'HeatIndexF': '34',
#     'DewPointC': '-4',
#     'DewPointF': '24',
#     'WindChillC': '-1',
#     'WindChillF': '30',
#     'WindGustMiles': '9',
#     'WindGustKmph': '15',
#     'FeelsLikeC': '-1',
#     'FeelsLikeF': '30'}]},
#  {'date': '2019-01-08',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '05:03 PM',
#     'moonrise': '09:12 AM',
#     'moonset': '07:33 PM',
#     'moon_phase': 'Waxing Crescent',
#     'moon_illumination': '7'}],
#   'maxtempC': '12',
#   'maxtempF': '54',
#   'mintempC': '3',
#   'mintempF': '38',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '12',
#     'tempF': '54',
#     'windspeedMiles': '7',
#     'windspeedKmph': '12',
#     'winddirDegree': '209',
#     'winddir16Point': 'SSW',
#     'weatherCode': '116',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#     'weatherDesc': [{'value': 'Partly cloudy'}],
#     'precipMM': '6.7',
#     'humidity': '77',
#     'visibility': '9',
#     'pressure': '1012',
#     'cloudcover': '68',
#     'HeatIndexC': '9',
#     'HeatIndexF': '48',
#     'DewPointC': '5',
#     'DewPointF': '41',
#     'WindChillC': '8',
#     'WindChillF': '46',
#     'WindGustMiles': '14',
#     'WindGustKmph': '22',
#     'FeelsLikeC': '8',
#     'FeelsLikeF': '46'}]},
#  {'date': '2019-01-09',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '05:04 PM',
#     'moonrise': '09:46 AM',
#     'moonset': '08:29 PM',
#     'moon_phase': 'Waxing Crescent',
#     'moon_illumination': '14'}],
#   'maxtempC': '5',
#   'maxtempF': '41',
#   'mintempC': '1',
#   'mintempF': '34',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '5',
#     'tempF': '41',
#     'windspeedMiles': '11',
#     'windspeedKmph': '17',
#     'winddirDegree': '297',
#     'winddir16Point': 'WNW',
#     'weatherCode': '317',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0021_cloudy_with_sleet.png'}],
#     'weatherDesc': [{'value': 'Light sleet'}],
#     'precipMM': '3.1',
#     'humidity': '55',
#     'visibility': '9',
#     'pressure': '1012',
#     'cloudcover': '56',
#     'HeatIndexC': '4',
#     'HeatIndexF': '39',
#     'DewPointC': '-5',
#     'DewPointF': '23',
#     'WindChillC': '-1',
#     'WindChillF': '31',
#     'WindGustMiles': '21',
#     'WindGustKmph': '33',
#     'FeelsLikeC': '-1',
#     'FeelsLikeF': '31'}]},
#  {'date': '2019-01-10',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '05:05 PM',
#     'moonrise': '10:17 AM',
#     'moonset': '09:27 PM',
#     'moon_phase': 'Waxing Crescent',
#     'moon_illumination': '21'}],
#   'maxtempC': '5',
#   'maxtempF': '41',
#   'mintempC': '-1',
#   'mintempF': '31',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '5',
#     'tempF': '41',
#     'windspeedMiles': '10',
#     'windspeedKmph': '17',
#     'winddirDegree': '309',
#     'winddir16Point': 'NW',
#     'weatherCode': '116',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#     'weatherDesc': [{'value': 'Partly cloudy'}],
#     'precipMM': '0.0',
#     'humidity': '54',
#     'visibility': '10',
#     'pressure': '1019',
#     'cloudcover': '30',
#     'HeatIndexC': '0',
#     'HeatIndexF': '32',
#     'DewPointC': '-7',
#     'DewPointF': '19',
#     'WindChillC': '-5',
#     'WindChillF': '24',
#     'WindGustMiles': '22',
#     'WindGustKmph': '35',
#     'FeelsLikeC': '-5',
#     'FeelsLikeF': '24'}]},
#  {'date': '2019-01-11',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '05:06 PM',
#     'moonrise': '10:45 AM',
#     'moonset': '10:23 PM',
#     'moon_phase': 'First Quarter',
#     'moon_illumination': '28'}],
#   'maxtempC': '4',
#   'maxtempF': '40',
#   'mintempC': '-1',
#   'mintempF': '31',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '4',
#     'tempF': '40',
#     'windspeedMiles': '6',
#     'windspeedKmph': '9',
#     'winddirDegree': '319',
#     'winddir16Point': 'NW',
#     'weatherCode': '116',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#     'weatherDesc': [{'value': 'Partly cloudy'}],
#     'precipMM': '0.0',
#     'humidity': '55',
#     'visibility': '10',
#     'pressure': '1027',
#     'cloudcover': '9',
#     'HeatIndexC': '0',
#     'HeatIndexF': '32',
#     'DewPointC': '-9',
#     'DewPointF': '16',
#     'WindChillC': '-3',
#     'WindChillF': '27',
#     'WindGustMiles': '13',
#     'WindGustKmph': '21',
#     'FeelsLikeC': '-3',
#     'FeelsLikeF': '27'}]},
#  {'date': '2019-01-12',
#   'astronomy': [{'sunrise': '07:27 AM',
#     'sunset': '05:07 PM',
#     'moonrise': '11:13 AM',
#     'moonset': '11:21 PM',
#     'moon_phase': 'First Quarter',
#     'moon_illumination': '34'}],
#   'maxtempC': '1',
#   'maxtempF': '34',
#   'mintempC': '-4',
#   'mintempF': '25',
#   'totalSnow_cm': '2.5',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '1',
#     'tempF': '34',
#     'windspeedMiles': '3',
#     'windspeedKmph': '4',
#     'winddirDegree': '158',
#     'winddir16Point': 'SSE',
#     'weatherCode': '338',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0020_cloudy_with_heavy_snow.png'}],
#     'weatherDesc': [{'value': 'Heavy snow'}],
#     'precipMM': '2.9',
#     'humidity': '60',
#     'visibility': '8',
#     'pressure': '1032',
#     'cloudcover': '78',
#     'HeatIndexC': '-2',
#     'HeatIndexF': '28',
#     'DewPointC': '-9',
#     'DewPointF': '16',
#     'WindChillC': '-2',
#     'WindChillF': '28',
#     'WindGustMiles': '5',
#     'WindGustKmph': '8',
#     'FeelsLikeC': '-2',
#     'FeelsLikeF': '28'}]},
#  {'date': '2019-01-13',
#   'astronomy': [{'sunrise': '07:26 AM',
#     'sunset': '05:08 PM',
#     'moonrise': '11:41 AM',
#     'moonset': 'No moonset',
#     'moon_phase': 'First Quarter',
#     'moon_illumination': '41'}],
#   'maxtempC': '1',
#   'maxtempF': '34',
#   'mintempC': '-4',
#   'mintempF': '25',
#   'totalSnow_cm': '17.9',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '1',
#     'tempF': '34',
#     'windspeedMiles': '6',
#     'windspeedKmph': '9',
#     'winddirDegree': '48',
#     'winddir16Point': 'NE',
#     'weatherCode': '338',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0020_cloudy_with_heavy_snow.png'}],
#     'weatherDesc': [{'value': 'Heavy snow'}],
#     'precipMM': '21.0',
#     'humidity': '73',
#     'visibility': '2',
#     'pressure': '1024',
#     'cloudcover': '100',
#     'HeatIndexC': '-1',
#     'HeatIndexF': '31',
#     'DewPointC': '-5',
#     'DewPointF': '23',
#     'WindChillC': '-3',
#     'WindChillF': '26',
#     'WindGustMiles': '10',
#     'WindGustKmph': '17',
#     'FeelsLikeC': '-3',
#     'FeelsLikeF': '26'}]},
#  {'date': '2019-01-14',
#   'astronomy': [{'sunrise': '07:26 AM',
#     'sunset': '05:09 PM',
#     'moonrise': '12:09 PM',
#     'moonset': '12:20 AM',
#     'moon_phase': 'First Quarter',
#     'moon_illumination': '48'}],
#   'maxtempC': '1',
#   'maxtempF': '34',
#   'mintempC': '-4',
#   'mintempF': '25',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '1',
#     'tempF': '34',
#     'windspeedMiles': '4',
#     'windspeedKmph': '7',
#     'winddirDegree': '216',
#     'winddir16Point': 'SW',
#     'weatherCode': '116',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#     'weatherDesc': [{'value': 'Partly cloudy'}],
#     'precipMM': '2.1',
#     'humidity': '65',
#     'visibility': '9',
#     'pressure': '1024',
#     'cloudcover': '43',
#     'HeatIndexC': '-3',
#     'HeatIndexF': '28',
#     'DewPointC': '-8',
#     'DewPointF': '17',
#     'WindChillC': '-4',
#     'WindChillF': '24',
#     'WindGustMiles': '7',
#     'WindGustKmph': '11',
#     'FeelsLikeC': '-4',
#     'FeelsLikeF': '24'}]},
#  {'date': '2019-01-15',
#   'astronomy': [{'sunrise': '07:26 AM',
#     'sunset': '05:10 PM',
#     'moonrise': '12:40 PM',
#     'moonset': '01:21 AM',
#     'moon_phase': 'Waxing Gibbous',
#     'moon_illumination': '55'}],
#   'maxtempC': '2',
#   'maxtempF': '36',
#   'mintempC': '-5',
#   'mintempF': '23',
#   'totalSnow_cm': '0.0',
#   'sunHour': '0.0',
#   'uvIndex': '0',
#   'hourly': [{'time': '24',
#     'tempC': '2',
#     'tempF': '36',
#     'windspeedMiles': '5',
#     'windspeedKmph': '7',
#     'winddirDegree': '298',
#     'winddir16Point': 'WNW',
#     'weatherCode': '143',
#     'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0006_mist.png'}],
#     'weatherDesc': [{'value': 'Mist'}],
#     'precipMM': '0.0',
#     'humidity': '71',
#     'visibility': '9',
#     'pressure': '1022',
#     'cloudcover': '11',
#     'HeatIndexC': '-2',
#     'HeatIndexF': '29',
#     'DewPointC': '-6',
#     'DewPointF': '21',
#     'WindChillC': '-4',
#     'WindChillF': '25',
#     'WindGustMiles': '9',
#     'WindGustKmph': '14',
#     'FeelsLikeC': '-4',
#     'FeelsLikeF': '25'}]}]

# %%
fahrenheit = []

x = 0
for w in testweather:
    fahrenheit.append(testweather[x]["hourly"][0]["tempF"])
    x += 1

    tempdf = pd.DataFrame([fahrenheit])
    tempdf.T.mean()

precip = []
x = 0
for p in testweather:
    precip.append(testweather[x]["hourly"][0]["precipMM"])
    x += 1

    precipdf = pd.DataFrame([precip])
    precipdf.T.mean()

humidity = []
x = 0
for h in testweather:
    humidity.append(testweather[x]["hourly"][0]["humidity"])
    x += 1
    precipdf.T.mean()
# Out:
# ['72',
#  '70',
#  '69',
#  '73',
#  '70',
#  '63',
#  '63',
#  '77',
#  '55',
#  '54',
#  '55',
#  '60',
#  '73',
#  '65',
#  '71']

# %%
locations = region[["lat", "lng"]]

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=avg_temps, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
