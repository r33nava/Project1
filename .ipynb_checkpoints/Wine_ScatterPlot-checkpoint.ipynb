# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("winedata_coord.csv")

df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             1
# 1           1           608
# 2           2           647
# 3           3           784
# 4           4           786
#
#                                                Title           Variety  Year  \
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)    Portuguese Red  2011
# 1  Quinta do Portal 2012 Verdelho and Sauvignon B...  Portuguese White  2012
# 2             Quinta do Monte Xisto 2013 Red (Douro)    Portuguese Red  2013
# 3          Quinta do Sagrado 2008 VT '08 Red (Douro)    Portuguese Red  2008
# 4              Sobredos 2012 Aneto Tinto Red (Douro)    Portuguese Red  2012
#
#    Price  Grade                 Winery Province Region   Country      Taster  \
# 0     15     87    Quinta dos Avidagos    Douro    NaN  Portugal  Roger Voss
# 1     15     87       Quinta do Portal    Douro    NaN  Portugal  Roger Voss
# 2     80     92  Quinta do Monte Xisto    Douro    NaN  Portugal  Roger Voss
# ...

# %%
# Reference multiple columns within a DataFrame
df[["Province", "Country","Price","Grade"]].head(5)
# Out:
#   Province   Country  Price  Grade
# 0    Douro  Portugal     15     87
# 1    Douro  Portugal     15     87
# 2    Douro  Portugal     80     92
# 3    Douro  Portugal     32     90
# 4    Douro  Portugal     12     90

# %%
# Collect only those projects that were hosted in the US
US_Wineries = df.loc[df["Country"]=="US"]

US_Wineries.head()
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 1031        1031             2
# 1032        1032             4
# 1033        1033            21
# 1034        1034            35
# 1035        1035            41
#
#                                                   Title     Variety  Year  \
# 1031      Rainstorm 2013 Pinot Gris (Willamette Valley)  Pinot Gris  2013
# 1032  Sweet Cheeks 2012 Vintner's Reserve Wild Child...  Pinot Noir  2012
# 1033                   Acrobat 2013 Pinot Noir (Oregon)  Pinot Noir  2013
# 1034         Erath 2010 Hyland Pinot Noir (McMinnville)  Pinot Noir  2010
# 1035  Hawkins Cellars 2009 Pinot Noir (Willamette Va...  Pinot Noir  2009
#
#       Price  Grade           Winery Province             Region Country  \
# 1031     14     87        Rainstorm   Oregon  Willamette Valley      US
# 1032     65     87     Sweet Cheeks   Oregon  Willamette Valley      US
# 1033     20     87          Acrobat   Oregon             Oregon      US
# ...

# %%
# Reference multiple columns within a US DataFrame
US_Wineries[["Province", "Country","Price","Grade"]].head(5)
# Out:
#      Province Country  Price  Grade
# 1031   Oregon      US     14     87
# 1032   Oregon      US     65     87
# 1033   Oregon      US     20     87
# 1034   Oregon      US     50     86
# 1035   Oregon      US     22     86

# %%
# The value_counts method counts unique values in a column
CountofGrades = df["Grade"].value_counts()
CountofGrades
# Out:
# 88     12918
# 87     12792
# 90     11807
# 86      9637
# 89      9296
# 91      9123
# 92      7734
# 85      7586
# 93      5326
# 84      5126
# 94      3167
# 83      2405
# 82      1481
# 95      1318
# 81       566
# 96       451
# 80       327
# 97       194
# 98        62
# 99        25
# 100       16
# Name: Grade, dtype: int64

# %%
# It is possible to sort based upon multiple columns
PriceGrade = df.sort_values(
    ["Grade","Price"], ascending=False)
PriceGrade.head(10)
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 55395       55395        111753
# 55396       55396        111755
# 55623       55623        122935
# 98138       98138        114972
# 94404       94404         89729
# 71399       71399         45781
# 71131       71131         39286
# 393           393         42197
# 41479       41479        118058
# 55397       55397        111756
#
#                                                    Title  \
# 55395           Château Lafite Rothschild 2010  Pauillac
# 55396           Château Cheval Blanc 2010  Saint-Émilion
# 55623            Château Haut-Brion 2014  Pessac-Léognan
# 98138      Quinta do Noval 2011 Nacional Vintage  (Port)
# 94404  Salon 2006 Le Mesnil Blanc de Blancs Brut Char...
# 71399  Biondi Santi 2010 Riserva  (Brunello di Montal...
# 71131  Tenuta dell'Ornellaia 2007 Masseto Merlot (Tos...
# 393        Casa Ferreirinha 2008 Barca-Velha Red (Douro)
# 41479            Verité 2007 La Muse Red (Sonoma County)
# ...

# %%
#Finding max price of wine in world

max_price=df["Price"].max()

max_price
# Out:
# 3300

# %%
# The value_counts method counts unique values in a column
CountofPrices = df["Price"].value_counts()
CountofPrices
# Out:
# 20      5726
# 15      4932
# 25      4859
# 30      4135
# 18      4011
# 40      3305
# 12      3257
# 35      3234
# 13      2928
# 16      2921
# 50      2810
# 10      2800
# 22      2772
# 45      2700
# 14      2643
# 28      2530
# 17      2521
# 24      2384
# 19      2305
# 60      1946
# 55      1727
# 11      1680
# 32      1664
# 38      1508
# 26      1467
# 23      1395
# 65      1386
# 75      1231
# 42      1226
# 36      1198
#         ...
# 419        1
# 355        1
# 206        1
# 1000       1
# 612        1
# 281        1
# 247        1
# 172        1
# 445        1
# 171        1
# 203        1
# 395        1
# 317        1
# 426        1
# 204        1
# 268        1
# 234        1
# 780        1
# 226        1
# 189        1
# 183        1
# 617        1
# 205        1
# 269        1
# 569        1
# 525        1
# 973        1
# 425        1
# 757        1
# 767        1
# Name: Price, Length: 375, dtype: int64

# %%
#Finding max price of wine in world

min_price=df["Price"].min()

min_price
# Out:
# 4

# %%
# The maximum x value for our chart will be 3300
x_limit = max_price

x_limit
# Out:
# 3300

# %%
#Finding max price of wine in world

max_grade=df["Grade"].max()

max_grade
# Out:
# 100

# %%
# List of values from 0 to 100 each value being 1 greater than the last
x_axis = np.arange(3, x_limit, 158)

x_axis
# Out:
# array([   3,  161,  319,  477,  635,  793,  951, 1109, 1267, 1425, 1583,
#        1741, 1899, 2057, 2215, 2373, 2531, 2689, 2847, 3005, 3163],
#       dtype=int64)

# %%
grade =df["Grade"]

price = df["Price"]

# %%
# who can help us come up with the 10th and 90th percentile??
ten_pctille_PRICE = print(np.percentile(price,10))
ninety_pctille_PRICE = print(np.percentile(price,99))

#ten_pctille_GRADE = print(np.percentile(grade,1))
#ninety_pctille_GRADE = print(np.percentile(grade,90))
# Out:
# 13.0
# 156.0

# %%
countWineUnder156 = df["Price"]<156
countWineUnder156.value_counts()
# Out:
# True     100342
# False      1015
# Name: Price, dtype: int64

# %%
countWineOver156 = df["Price"]>=156
countWineOver156.value_counts()
# Out:
# False    100342
# True       1015
# Name: Price, dtype: int64

# %%
df_CheapWine = df.loc[df["Price"]<156]

df_CheapWine.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             1
# 1           1           608
# 2           2           647
# 3           3           784
# 4           4           786
#
#                                                Title           Variety  Year  \
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)    Portuguese Red  2011
# 1  Quinta do Portal 2012 Verdelho and Sauvignon B...  Portuguese White  2012
# 2             Quinta do Monte Xisto 2013 Red (Douro)    Portuguese Red  2013
# 3          Quinta do Sagrado 2008 VT '08 Red (Douro)    Portuguese Red  2008
# 4              Sobredos 2012 Aneto Tinto Red (Douro)    Portuguese Red  2012
#
#    Price  Grade                 Winery Province Region   Country      Taster  \
# 0     15     87    Quinta dos Avidagos    Douro    NaN  Portugal  Roger Voss
# 1     15     87       Quinta do Portal    Douro    NaN  Portugal  Roger Voss
# 2     80     92  Quinta do Monte Xisto    Douro    NaN  Portugal  Roger Voss
# ...

# %%
#numbers = [3, 3, 4, 5, 5, 6, 7, 7, 8, 8, 9]
#numbers = [3, 3, 4, 5, 5, 6, 7, 7, 8, 8, 90]

lower_quartile = print(np.percentile(price,25))
median = print(np.percentile(price,50))
upper_quartile = print(np.percentile(price,75))
# Out:
# 17.0
# 26.0
# 43.0

# %%
print(np.mean(price))
print(np.median(price))
print("--------")
print(np.mean(grade))
print(np.median(grade))
# Out:
# 35.89593220004539
# 26.0
# --------
# 88.49031640636562
# 88.0

# %%
# Tells matplotlib that we want to make a scatter plot
# The size of each point on our plot is determined by their x value
plt.scatter(grade, price, marker="o", facecolors="red", edgecolors="black", alpha=0.75)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = df_CheapWine["Grade"]

y = df_CheapWine["Price"]

# %%
# Tells matplotlib that we want to make a scatter plot
# The size of each point on our plot is determined by their x value
AffordableWine=plt.scatter(x, y, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

AffordableWine
