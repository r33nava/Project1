# %%
import pandas as pd

# %%
#importing the CSV file into a DataFrame using Pandas
csv_file = pd.read_csv("winedata.csv")
csv_file.head(1)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
#parsing out a year from the title & adding a new column consisting of years. 
##Refer back to "parsing_year" Jupyter Notebook file to see the vertification for this process.

title_list = [title for title in csv_file["title"]]

def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString) 

counter = 0
year_list = []
multiple_numbers_list = []
none_years_list = []
no_numbers_list = []

for title in title_list:
    title_strings_list = []
    title_numbers_list = []
    year_numbers_list = []
    for x in title.split():
        title_strings_list.append(x)
    if hasNumbers(title_strings_list) == True:
        for y in title_strings_list:
            if y.isdigit():
                title_numbers_list.append(int(y))
        year_numbers_list = [i for i in title_numbers_list if 1970 < i < 2019]
        if len(year_numbers_list) >= 1:
            year_list.append(year_numbers_list[0]) #All but one titles have the Year listed first. 
        #elif len(year_numbers_list) > 1:
            #multiple_numbers_list.append(counter)
        elif len(year_numbers_list) == 0:
            year_list.append("N/A")
    if hasNumbers(title_strings_list) == False:
        year_list.append("N/A")
    counter = counter + 1

year_list[102843] = 2000 #this one Title is an exception, refer back to "parsing_year" file for more info

# %%
#adding the new list to the existing DataFrame. 

csv_file["year"] = year_list
csv_file_with_year = csv_file
print(f'Total number of wine review is: {len(csv_file_with_year["title"])}.')
csv_file_with_year.head(1)
# Out:
# Total number of wine review is: 129971.
#    Unnamed: 0 country                                        description  \
# 0           0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery  year
# 0  White Blend  Nicosia  2013

# %%
#cleaning data
#1. Renaming the columns

df = csv_file_with_year.rename(columns={"Unnamed: 0": "Index", "country": "Country", "description":"Description",
                                       "designation": "Designation", "points":"Grade", "province": "Province",
                                        "region_1": "Region",
                                        "taster_name": "Taster", "taster_twitter_handle": "Taster_Twitter",
                                        "title": "Title", "variety": "Variety", "winery": "Winery", "year":"Year",
                                        "price": "Price"
                                       })
#1. Dropping designation, region_1, and region_2
df = df[["Index", "Title", "Variety", "Year", "Price", "Grade", "Winery", "Province", "Region", "Country", 
         "Taster", "Taster_Twitter", "Description"]]
#df.head(3)

#2. Removing all wines that do not have year assigned
df = df.loc[df["Year"]!= "N/A"]
#print(len(df["Year"]))

#3. Removing all wines that do not have Price tags
df = df.fillna("N/A")
df = df.loc[df["Price"] != "N/A"]
print(f'Total Number of Wine Reviews for dataframe with empty Price and year removed is: {len(df["Index"])}.')

#4. Removing Duplicates, if the same Taster reviewed the same wine more than once
df_duplicates_dropped = df.drop_duplicates(subset=["Title", "Price", "Grade", "Taster", "Description"], keep='first', inplace=False)
print(f'Total Number of Wine Reviews for dataframe after duplicates removed is: {len(df_duplicates_dropped["Index"])}.')
df_duplicates_dropped.head(1)
# Out:
# Total Number of Wine Reviews for dataframe with empty Price and year removed is: 116802.
# Total Number of Wine Reviews for dataframe after duplicates removed is: 107734.
#    Index                                          Title         Variety  Year  \
# 1      1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red  2011
#
#   Price  Grade               Winery Province Region   Country      Taster  \
# 1    15     87  Quinta dos Avidagos    Douro    N/A  Portugal  Roger Voss
#
#   Taster_Twitter                                        Description
# 1     @vossroger  This is ripe and fruity, a wine that is smooth...

# %%
#Exporting to a CSV file
new_df = df_duplicates_dropped

new_df = new_df.drop(columns=["Index"])

new_df.to_csv("winedata_edited.csv")

new_df.head(1)
# Out:
#                                            Title         Variety  Year Price  \
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red  2011    15
#
#    Grade               Winery Province Region   Country      Taster  \
# 1     87  Quinta dos Avidagos    Douro    N/A  Portugal  Roger Voss
#
#   Taster_Twitter                                        Description
# 1     @vossroger  This is ripe and fruity, a wine that is smooth...

# %%
#looking at the summary of the current dataset. 

number_of_unique_wine_reviews = len(new_df['Title'].unique())
number_of_unique_country = len(new_df['Country'].unique())
number_of_unique_province = len(new_df['Province'].unique())
number_of_unique_wineries = len(new_df['Winery'].unique())
number_of_unique_years = len(new_df['Year'].unique())
number_of_unique_taster = len(new_df['Taster'].unique())

summary = pd.DataFrame({"Total Number of Wine Reviews" : [number_of_unique_wine_reviews],
                    "Total Number of Wineries": [number_of_unique_wineries],
                   "Total Number of Provinces": [number_of_unique_province],
                   "Total Number of Countries": [number_of_unique_country],
                   "Total Number of Years" : [number_of_unique_years],
                   "Total Number of Tasters": [number_of_unique_taster]
})

summary.head(1)
# Out:
#    Total Number of Wine Reviews  Total Number of Wineries  \
# 0                        107379                     15475
#
#    Total Number of Provinces  Total Number of Countries  \
# 0                        416                         43
#
#    Total Number of Years  Total Number of Tasters
# 0                     41                       20

# %%
#Compiling the list of Countries. 

list_of_countries = new_df["Country"].value_counts()

list_of_countries
# Out:
# US                        49371
# France                    15018
# Italy                     14742
# Spain                      5582
# Portugal                   4273
# Chile                      4106
# Argentina                  3462
# Austria                    2506
# Australia                  2102
# Germany                    1937
# New Zealand                1232
# South Africa               1180
# Israel                      452
# Greece                      406
# Canada                      223
# Bulgaria                    132
# Hungary                     126
# Romania                     102
# Uruguay                      97
# Turkey                       81
# Georgia                      72
# Slovenia                     69
# Mexico                       68
# Croatia                      67
# N/A                          55
# Moldova                      54
# England                      47
# Brazil                       35
# Lebanon                      32
# Morocco                      24
# Peru                         16
# Macedonia                    11
# Czech Republic               10
# Cyprus                        9
# Serbia                        8
# India                         8
# Switzerland                   6
# Ukraine                       5
# Luxembourg                    2
# Armenia                       2
# Bosnia and Herzegovina        2
# Slovakia                      1
# China                         1
# Name: Country, dtype: int64

# %%
#for i in list_of_countries:
    #print(i)
bottom_countries = []
    
for i, v in list_of_countries.items():
    if v < 1000:
        bottom_countries.append(i)
        
print(bottom_countries)
# Out:
# ['Israel', 'Greece', 'Canada', 'Bulgaria', 'Hungary', 'Romania', 'Uruguay', 'Turkey', 'Georgia', 'Slovenia', 'Mexico', 'Croatia', 'N/A', 'Moldova', 'England', 'Brazil', 'Lebanon', 'Morocco', 'Peru', 'Macedonia', 'Czech Republic', 'Cyprus', 'Serbia', 'India', 'Switzerland', 'Ukraine', 'Luxembourg', 'Armenia', 'Bosnia and Herzegovina', 'Slovakia', 'China']

# %%
new_df.head(1)
# Out:
#                                            Title         Variety  Year Price  \
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red  2011    15
#
#    Grade               Winery Province Region   Country      Taster  \
# 1     87  Quinta dos Avidagos    Douro    N/A  Portugal  Roger Voss
#
#   Taster_Twitter                                        Description
# 1     @vossroger  This is ripe and fruity, a wine that is smooth...

# %%
#Only including data from the top countries

for i in range(0, len(bottom_countries)):
    new_df = new_df.loc[new_df["Country"]!= bottom_countries[i]]

new_df.head(1)
# Out:
#                                            Title         Variety  Year Price  \
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red  2011    15
#
#    Grade               Winery Province Region   Country      Taster  \
# 1     87  Quinta dos Avidagos    Douro    N/A  Portugal  Roger Voss
#
#   Taster_Twitter                                        Description
# 1     @vossroger  This is ripe and fruity, a wine that is smooth...

# %%
#looking at the summary of the current dataset. 

number_of_unique_wine_reviews = len(new_df['Title'].unique())
number_of_unique_country = len(new_df['Country'].unique())
number_of_unique_province = len(new_df['Province'].unique())
number_of_unique_wineries = len(new_df['Winery'].unique())
number_of_unique_years = len(new_df['Year'].unique())
number_of_unique_taster = len(new_df['Taster'].unique())

summary = pd.DataFrame({"Total Number of Wine Reviews" : [number_of_unique_wine_reviews],
                    "Total Number of Wineries": [number_of_unique_wineries],
                   "Total Number of Provinces": [number_of_unique_province],
                   "Total Number of Countries": [number_of_unique_country],
                   "Total Number of Years" : [number_of_unique_years],
                   "Total Number of Tasters": [number_of_unique_taster]
})

summary.head(1)
# Out:
#    Total Number of Wine Reviews  Total Number of Wineries  \
# 0                        105159                     15000
#
#    Total Number of Provinces  Total Number of Countries  \
# 0                        240                         12
#
#    Total Number of Years  Total Number of Tasters
# 0                     41                       18

# %%
list_of_countries = new_df["Country"].value_counts()

remaining_countries = []
    
for i, v in list_of_countries.items():
    remaining_countries.append(i)
        
print(remaining_countries)
# Out:
# ['US', 'France', 'Italy', 'Spain', 'Portugal', 'Chile', 'Argentina', 'Austria', 'Australia', 'Germany', 'New Zealand', 'South Africa']

# %%
list_of_years = new_df["Year"].value_counts()

list_of_years
# Out:
# 2013    13434
# 2012    13152
# 2014    13120
# 2011    10266
# 2010    10093
# 2015     8382
# 2009     8314
# 2008     6228
# 2007     6077
# 2006     4892
# 2005     3131
# 2016     3124
# 2004     1512
# 2000      722
# 2001      653
# 1999      608
# 1998      533
# 2003      464
# 2002      318
# 1997      294
# 1996       59
# 1995       45
# 1994       23
# 1992       14
# 2017        9
# 1989        6
# 1990        5
# 1988        5
# 1985        4
# 1991        4
# 1986        3
# 1993        3
# 1987        2
# 1983        2
# 1978        2
# 1980        2
# 1984        2
# 1982        1
# 1973        1
# 1974        1
# 1976        1
# Name: Year, dtype: int64

# %%
bottom_years = []
    
for i, v in list_of_years.items():
    if v < 1500:
        bottom_years.append(i)
        
print(bottom_years)
print(len(bottom_years))
# Out:
# [2000, 2001, 1999, 1998, 2003, 2002, 1997, 1996, 1995, 1994, 1992, 2017, 1989, 1990, 1988, 1985, 1991, 1986, 1993, 1987, 1983, 1978, 1980, 1984, 1982, 1973, 1974, 1976]
# 28

# %%
#Only including data from the top 13 years

for i in range(0, len(bottom_years)):
    new_df = new_df.loc[new_df["Year"]!= bottom_years[i]]

new_df.head(1)
# Out:
#                                            Title         Variety  Year Price  \
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red  2011    15
#
#    Grade               Winery Province Region   Country      Taster  \
# 1     87  Quinta dos Avidagos    Douro    N/A  Portugal  Roger Voss
#
#   Taster_Twitter                                        Description
# 1     @vossroger  This is ripe and fruity, a wine that is smooth...

# %%
#looking at the summary of the current dataset. 

number_of_unique_wine_reviews = len(new_df['Title'].unique())
number_of_unique_country = len(new_df['Country'].unique())
number_of_unique_province = len(new_df['Province'].unique())
number_of_unique_wineries = len(new_df['Winery'].unique())
number_of_unique_years = len(new_df['Year'].unique())
number_of_unique_taster = len(new_df['Taster'].unique())

summary = pd.DataFrame({"Total Number of Wine Reviews" : [number_of_unique_wine_reviews],
                    "Total Number of Wineries": [number_of_unique_wineries],
                   "Total Number of Provinces": [number_of_unique_province],
                   "Total Number of Countries": [number_of_unique_country],
                   "Total Number of Years" : [number_of_unique_years],
                   "Total Number of Tasters": [number_of_unique_taster]
})

summary.head(1)
# Out:
#    Total Number of Wine Reviews  Total Number of Wineries  \
# 0                        101379                     14503
#
#    Total Number of Provinces  Total Number of Countries  \
# 0                        232                         12
#
#    Total Number of Years  Total Number of Tasters
# 0                     13                       18

# %%
list_of_years = new_df["Year"].value_counts()

remaining_years = []
    
for i, v in list_of_years.items():
    remaining_years.append(i)
        
print(remaining_years)
# Out:
# [2013, 2012, 2014, 2011, 2010, 2015, 2009, 2008, 2007, 2006, 2005, 2016, 2004]

# %%
new_df.to_csv("winedata_edited.csv")

# %%
new_csv_file = pd.read_csv("winedata_edited.csv")

new_csv_file.head(1)

#looking at the summary of the current dataset. 

number_of_unique_wine_reviews = len(new_df['Title'].unique())
number_of_unique_country = len(new_df['Country'].unique())
number_of_unique_province = len(new_df['Province'].unique())
number_of_unique_wineries = len(new_df['Winery'].unique())
number_of_unique_years = len(new_df['Year'].unique())
number_of_unique_taster = len(new_df['Taster'].unique())

summary = pd.DataFrame({"Total Number of Wine Reviews" : [number_of_unique_wine_reviews],
                    "Total Number of Wineries": [number_of_unique_wineries],
                   "Total Number of Provinces": [number_of_unique_province],
                   "Total Number of Countries": [number_of_unique_country],
                   "Total Number of Years" : [number_of_unique_years],
                   "Total Number of Tasters": [number_of_unique_taster]
})

summary.head(1)
# Out:
#    Total Number of Wine Reviews  Total Number of Wineries  \
# 0                        101379                     14503
#
#    Total Number of Provinces  Total Number of Countries  \
# 0                        232                         12
#
#    Total Number of Years  Total Number of Tasters
# 0                     13                       18

# %%
new_df = new_df.loc[new_df["Country"]== "US"]

# %%
us_province = new_df["Province"].value_counts()
us_province

#drop 10 or below.
# Out:
# California           31771
# Washington            7694
# Oregon                4673
# New York              2302
# Virginia               680
# Idaho                  162
# Michigan                99
# Texas                   86
# Colorado                60
# America                 46
# New Mexico              40
# Arizona                 32
# Missouri                24
# North Carolina          21
# Pennsylvania            16
# Ohio                    10
# New Jersey               8
# Washington-Oregon        6
# Massachusetts            5
# Nevada                   3
# Vermont                  2
# Iowa                     2
# Connecticut              2
# Kentucky                 1
# Name: Province, dtype: int64

# %%
us_regions = new_df["Region"].value_counts()
len(us_regions)
us_regions
# Out:
# Napa Valley                                  3894
# Columbia Valley (WA)                         3657
# Russian River Valley                         2766
# California                                   2072
# Paso Robles                                  2068
# Willamette Valley                            1997
# Finger Lakes                                 1392
# Sonoma Coast                                 1359
# Sonoma County                                1030
# Walla Walla Valley (WA)                       983
# Sta. Rita Hills                               896
# Santa Barbara County                          886
# Carneros                                      871
# Yakima Valley                                 858
# Dry Creek Valley                              828
# Lodi                                          732
# Santa Ynez Valley                             717
# Santa Lucia Highlands                         714
# Alexander Valley                              699
# Central Coast                                 662
# Red Mountain                                  656
# Santa Maria Valley                            646
# Anderson Valley                               568
# Sonoma Valley                                 565
# Horse Heaven Hills                            508
# Dundee Hills                                  507
# Santa Cruz Mountains                          491
# Virginia                                      488
# North Fork of Long Island                     483
# Livermore Valley                              409
#                                              ...
# Columbia Valley-Walla Walla Valley              2
# Monterey County-Napa County-Sonoma County       2
# Oregon Other                                    2
# Monterey-Santa Cruz                             2
# Texoma                                          1
# Ohio                                            1
# Sonoma County-Santa Barbara County              1
# Niagara Escarpment                              1
# Monterey County-Napa County                     1
# Sonoma-Mendocino                                1
# Sonoma-Napa-Mendocino                           1
# Napa-Amador                                     1
# Isle St. George                                 1
# Napa County-Lake County                         1
# Paso Robles Highlands District                  1
# Tehama County                                   1
# Mendocino-Amador                                1
# Lake-Sonoma-Napa                                1
# Sonoma-Santa Barbara-Mendocino                  1
# Sonoma-Napa-Monterey                            1
# Sierra Pelona Valley                            1
# Sonoma-Napa-Lake                                1
# Monterey-San Luis Obispo-Santa Barbara          1
# Napa-Sonoma-Marin                               1
# Santa Cruz County                               1
# Kentucky                                        1
# California-Oregon                               1
# Sonoita                                         1
# McDowell Valley                                 1
# Napa Valley-Paso Robles                         1
# Name: Region, Length: 258, dtype: int64

# %%
#Looking to see if we can eliminate certain price tags

price_list = [price for price in df_duplicates_dropped["Price"] if 0 < price < 10]

d = {}
for item in price_list:
    if item in d:
        d[item] = d.get(item)+1
    else:
        d[item] = 1
        
for k,v in d.items():
    print(str(k)+':'+str(v))
# Out:
# 9.0:1215
# 7.0:369
# 8.0:819
# 6.0:101
# 4.0:7
# 5.0:30

# %%
#df = df.loc[df["Year"]!= "N/A"]
four_dollars_wines = df_duplicates_dropped.loc[df_duplicates_dropped["Price"] == 4]

# %%
four_dollars_wines.head(2)
# Out:
#        Index                                              Title      Variety  \
# 1987    1987  Felix Solis 2013 Flirty Bird Syrah (Vino de la...        Syrah
# 20484  20484             Dancing Coyote 2015 White (Clarksburg)  White Blend
#
#        Year Price  Grade          Winery       Province  \
# 1987   2013     4     85     Felix Solis  Central Spain
# 20484  2015     4     85  Dancing Coyote     California
#
#                               Region Country             Taster  \
# 1987   Vino de la Tierra de Castilla   Spain  Michael Schachner
# 20484                     Clarksburg      US         Jim Gordon
#
#          Taster_Twitter                                        Description
# 1987        @wineschach  Berry and cherry aromas are surprisingly sturd...
# 20484  @gordone_cellars  Fruity, soft and rather sweet, this wine smell...

# %%
print(f'The new data set has {len(df_duplicates_dropped["Winery"].unique())} wineries.')
# Out:
# The new data set has 15475 wineries.

# %%
new_csv_file = pd.read_csv("winedata_edited.csv")

new_csv_file.head(50)
# Out:
#     Unnamed: 0                                              Title  \
# 0            1      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1            2      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2            3  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3            4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4            5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 5            6   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 6            7              Trimbach 2012 Gewurztraminer (Alsace)
# 7            8  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...
# 8            9  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
# 9           10  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 10          11            Leon Beyer 2012 Gewurztraminer (Alsace)
# 11          12  Louis M. Martini 2012 Cabernet Sauvignon (Alex...
# 12          14           Mirassou 2012 Chardonnay (Central Coast)
# 13          15        Richard Böcking 2013 Devon Riesling (Mosel)
# 14          16         Felix Lavaque 2010 Felix Malbec (Cafayate)
# 15          17  Gaucho Andino 2011 Winemaker Selection Malbec ...
# 16          18  Pradorey 2010 Vendimia Seleccionada Finca Vald...
# 17          19               Quiévremont 2012 Meritage (Virginia)
# 18          20      Quiévremont 2012 Vin de Maison Red (Virginia)
# 19          21                   Acrobat 2013 Pinot Noir (Oregon)
# 20          22  Baglio di Pianetto 2007 Ficiligno White (Sicilia)
# 21          23  Bianchi 2011 Signature Selection Merlot (Paso ...
# 22          24        Canicattì 2009 Aynat Nero d'Avola (Sicilia)
# 23          25  Castello di Amorosa 2011 King Ridge Vineyard P...
# 24          26       Stemmari 2013 Dalila White (Terre Siciliane)
# 25          27       Stemmari 2013 Nero d'Avola (Terre Siciliane)
# 26          28  Terre di Giurfo 2011 Mascaria Barricato  (Cera...
# 27          29  Clarksburg Wine Company 2010 Chenin Blanc (Cla...
# 28          33  Envolve 2010 Puma Springs Vineyard Red (Dry Cr...
# 29          34       Envolve 2011 Sauvignon Blanc (Sonoma Valley)
# 30          35         Erath 2010 Hyland Pinot Noir (McMinnville)
# 31          36  Estampa 2011 Estate Viognier-Chardonnay (Colch...
# 32          37  Feudi del Pisciotto 2010 Missoni Cabernet Sauv...
# 33          38  Feudi di San Marzano 2011 I Tratturi Primitivo...
# 34          39  Feudo di Santa Tresa 2011 Purato Made With Org...
# 35          40            Feudo Montoni 2011 Catarratto (Sicilia)
# 36          41  Hawkins Cellars 2009 Pinot Noir (Willamette Va...
# 37          42             Henry Fessy 2012 Nouveau  (Beaujolais)
# 38          43     Robert Hall 2011 Sauvignon Blanc (Paso Robles)
# 39          44                Sundance 2011 Merlot (Maule Valley)
# 47           Bordeaux         Bordeaux Blanc     France          Roger Voss
# 48         California            Napa Valley         US                 NaN
# 49         California            North Coast         US      Virginie Boone
#
#    Taster_Twitter                                        Description
# 0      @vossroger  This is ripe and fruity, a wine that is smooth...
# 1     @paulgwine   Tart and snappy, the flavors of lime flesh and...
# 2             NaN  Pineapple rind, lemon pith and orange blossom ...
# 3     @paulgwine   Much like the regular bottling from 2012, this...
# 4     @wineschach  Blackberry and raspberry aromas show a typical...
# 5    @kerinokeefe  Here's a bright, informal red that opens with ...
# 6      @vossroger  This dry and restrained wine offers spice in p...
# 7             NaN  Savory dried thyme notes accent sunnier flavor...
# 8      @vossroger  This has great depth of flavor with its fresh ...
# 9         @vboone  Soft, supple plum envelopes an oaky structure ...
# 10     @vossroger  This is a dry wine, very spicy, with a tight, ...
# 11        @vboone  Slightly reduced, this wine offers a chalky, t...
# 12  @mattkettmann  Building on 150 years and six generations of w...
# 13            NaN  Zesty orange peels and apple notes abound in t...
# 14    @wineschach  Baked plum, molasses, balsamic vinegar and che...
# 15    @wineschach  Raw black-cherry aromas are direct and simple ...
# 16    @wineschach  Desiccated blackberry, leather, charred wood a...
# 17            NaN  Red fruit aromas pervade on the nose, with cig...
# 18            NaN  Ripe aromas of dark berries mingle with ample ...
# 19    @paulgwine   A sleek mix of tart berry, stem and herb, alon...
# 20   @kerinokeefe  Delicate aromas recall white flower and citrus...
# 21  @mattkettmann  This wine from the Geneseo district offers aro...
# 22   @kerinokeefe  Aromas of prune, blackcurrant, toast and oak c...
# 23        @vboone  Oak and earth intermingle around robust aromas...
# 24   @kerinokeefe  Pretty aromas of yellow flower and stone fruit...
# 25   @kerinokeefe  Aromas recall ripe dark berry, toast and a whi...
# 26   @kerinokeefe  Aromas suggest mature berry, scorched earth, a...
# 27        @vboone  Clarksburg is becoming a haven for Chenin Blan...
# 28            NaN  Rustic and dry, this has flavors of berries, c...
# 29            NaN  This shows a tart, green gooseberry flavor tha...
# 30    @paulgwine   As with many of the Erath 2010 vineyard design...
# 31    @wineschach  White flower, lychee and apple aromas carry th...
# 32            NaN  This concentrated Cabernet offers aromas of cu...
# 33            NaN  Inky in color, this wine has plump aromas of r...
# 34            NaN  Part of the natural wine movement, this wine i...
# 35            NaN  Catarratto is one of Sicily's most widely farm...
# 36    @paulgwine   A stiff, tannic wine, this slowly opens and br...
# 37     @vossroger  This is a festive wine, with soft, ripe fruit ...
# 38            NaN  The clean, brisk mouthfeel gives this slightly...
# 39    @wineschach  A berry aroma comes with cola and herb notes. ...
# 40            NaN  Right out of the starting blocks this is an oa...
# 41            NaN  Spicy, fresh and clean, this would pair with f...
# 42            NaN  This is a sweet wine with flavors of white sug...
# 43            NaN  This bottling resembles the New Zealand paradi...
# 44     @vossroger  Soft and fruity, this is a generous, ripe wine...
# 45    @wineschach  This is much different than Casa Silva's 2009 ...
# 46            NaN  The Monica grape often shows a rustic or raw q...
# 47     @vossroger  Fruity and lightly herbaceous, this has fine t...
# 48            NaN  This shows jelly-like flavors of orange and pe...
# 49        @vboone  This is weighty, creamy and medium to full in ...

# %%
for index, row in new_df.iterrows():
#red wines
    if "Red" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Noir" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Tint" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Cabernet" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Syrah" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Sirah" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Malbec" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Gamay" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Merlot" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Barbera" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif "Shiraz" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"
    elif row["Variety"] == "Port":
        new_df.loc[index,"Type"] = "Red"
    elif "Nero" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"        
    elif "Negro" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"   
    elif "Sangiovese" in row["Variety"]:
        new_df.loc[index,"Type"] = "Red"        
    elif row["Variety"] == "Grenache":
        new_df.loc[index,"Type"] = "Red"     
    elif row["Variety"] == "Tempranillo":
        new_df.loc[index,"Type"] = "Red" 
#White wines        
    elif "White" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Chardonnay" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Riesling" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Grigio" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Gris" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Blanc" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Gewürztraminer" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Moscato" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Musca" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Semillon" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Viognier" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Cortese" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
    elif "Bianco" in row["Variety"]:
        new_df.loc[index,"Type"] = "White"
#blush wines
    elif "Zinfandel" in row["Variety"]:
        new_df.loc[index,"Type"] = "Blush"
    elif "Rosa" in row["Variety"]:
        new_df.loc[index,"Type"] = "Blush"
    elif "Rosé" in row["Variety"]:
        new_df.loc[index,"Type"] = "Blush"
#sparkling wines
    elif "Sparkling" in row["Variety"]:
        new_df.loc[index,"Type"] = "Sparkling"
    elif "Champagne" in row["Variety"]:
        new_df.loc[index,"Type"] = "Sparkling"
    elif "Prosecco" in row["Variety"]:
        new_df.loc[index,"Type"] = "Sparkling"
    elif "Lambrusco" in row["Variety"]:
        new_df.loc[index,"Type"] = "Sparkling"       
    else:
        new_df.loc[index,"Type"] = "Other"

# %%
new_df.to_csv('winedata_types.csv')
